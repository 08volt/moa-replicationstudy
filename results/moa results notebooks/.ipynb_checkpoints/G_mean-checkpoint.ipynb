# %%
import os
import csv
import numpy as np

# %%
main_dir ="Results_union"
old_drifts = ["sea_P(y)","sea_P(y_x)","sea_P(x_y)","sine_P(y)","sine_P(y_x)","sine_P(x_y)"]
new_drifts = ["jitter","disappearing-minority","appearing-minority","appearing-clusters",
             "shapeshift","minority-share","splitting-clusters","clusters-movement","borderline"]
type_drift = ["incremental","sudden","periodic"]
unbalance_lvls = [1,2,3,4]
stats_w = ["Recall_0","Recall_1", "F1_0", "F1_1", "Gmean"]
stats_tot =["time", "memory"]
algs = ["RebalanceStream","CSMOTE","improved_UOB","improved_OOB","WEOB1","WEOB2","ESOS_ELM","UOB","OOB"]

# %%
def import_csv(csvfilename):
    data = []
    with open(csvfilename, "r") as scraped:
        reader = csv.reader(scraped, delimiter=',')
        row_index = 0
        for row in reader:
            if row:  # avoid blank lines
                row_index += 1
                columns = [str(row_index)]+ [row[i] for i in range(len(row))]
                data.append(columns)
        #print(f"{row_index} valid rows")
        
    return data

# %% [markdown]
# # MEAN ALL ROWS

# %% [markdown]
# # OLD

# %%
final_dict = {}

for old in old_drifts:
    path = main_dir + "/" + old[old.index("P"):]   #old = sea_P(y)
    if old not in final_dict:
        final_dict[old] = {}
        
    for ds in os.listdir(path):
        #check if ds in old (directory giusta)
        if old[:3] == ds[:3]:
            path1 = path + "/" + ds
            
            unbalance = 0
            for u in unbalance_lvls:
                if str(u) in ds:
                    unbalance = u
            assert unbalance != 0
                        
            if unbalance not in final_dict[old]:
                final_dict[old][unbalance] = {}
                
            dtype = "sudden"
            if "G" in ds:
                dtype = "incremental"
                
            if dtype not in final_dict[old][unbalance]:
                final_dict[old][unbalance][dtype] = {}

            for alg in os.listdir(path1):
                if "DS_Store" in alg:
                    continue
                path2 = path1 + "/" + alg
                values = []
                
                print(f"{old} {unbalance} {dtype} {alg}")
                #prendo i valori di tutti i 10 esperimenti
                for result in os.listdir(path2):
                    if "err" not in result or "DS_Store" in result:
                        continue
                    start = False
                    data = import_csv(path2+"/"+ result)
                    val = []
                    for data_row in data:
                        if data_row[1] == "learning evaluation instances":
                            start = True
                            continue
                        if not start:
                            continue
                        
                        try:
                            val.append(float(data_row[13]))
                        except:
                            if data_row[13] == "?":
                                val.append(50)
                            else:
                                print("ZERO")
                                print(data_row)
                        
                    if len(val)>0:
                        values.append(np.mean(val))    
                        
                    
                assert len(values) > 0
                if alg == "OSHAT":
                    alg = "CSMOTE"
                final_dict[old][unbalance][dtype][alg]= np.mean(values)
                print(np.mean(values))
# Out:
# sea_P(y) 1 sudden improved_OOB
# 70.35194043770869
# sea_P(y) 1 sudden WEOB1
# 70.3467839263607
# sea_P(y) 1 sudden OOB
# 70.32735479606795
# sea_P(y) 1 sudden ESOS_ELM
# 65.32599718707182
# sea_P(y) 1 sudden improved_UOB
# 70.28360889906938
# sea_P(y) 1 sudden WEOB2
# 70.21106346302977
# sea_P(y) 1 sudden UOB
# 70.32735479606795
# sea_P(y) 1 sudden OSHAT
# 70.22543513635313
# sea_P(y) 1 sudden RebalanceStream
# 68.75269709510368
# sea_P(y) 3 incremental improved_OOB
# 64.66726516871196
# sea_P(y) 3 incremental WEOB1
# 64.68776455295958
# sea_P(y) 3 incremental OOB
# 64.62508213593722
# sea_P(y) 3 incremental ESOS_ELM
# 61.141349756833336
# sea_P(y) 3 incremental improved_UOB
# 64.58282225155952
# sea_P(y) 3 incremental WEOB2
# 64.40379927342454
# sea_P(y) 3 incremental UOB
# 64.59499764956168
# sea_P(y) 3 incremental OSHAT
# 63.49084195782807
# sea_P(y) 3 incremental RebalanceStream
# 64.2862219055536
# sea_P(y) 2 sudden improved_OOB
# 64.63206987274586
# sea_P(y) 2 sudden WEOB1
# 64.66098248466639
# sea_P(y) 2 sudden OOB
# 64.63253655479865
# sea_P(y) 2 sudden ESOS_ELM
# 60.97845897001802
# sea_P(y) 2 sudden improved_UOB
# 64.57966721824491
# sea_P(y) 2 sudden WEOB2
# 64.36556981717865
# sea_P(y) 2 sudden UOB
# 64.58845694398596
# sea_P(y) 2 sudden OSHAT
# 64.0546331285078
# sea_P(y) 2 sudden RebalanceStream
# 63.101123460073076
# sea_P(y) 4 incremental improved_OOB
# 64.65351408472245
# sea_P(y) 4 incremental WEOB1
# 64.68236628796919
# sea_P(y) 4 incremental OOB
# 64.60089044393153
# sea_P(y) 4 incremental ESOS_ELM
# 61.13721489626764
# sea_P(y) 4 incremental improved_UOB
# 64.60630170720034
# sea_P(y) 4 incremental WEOB2
# 64.40907044473684
# sea_P(y) 4 incremental UOB
# 64.56720159702652
# sea_P(y) 4 incremental OSHAT
# 64.1254178323287
# sea_P(y) 4 incremental RebalanceStream
# 64.28043722909976
# sea_P(y) 1 incremental improved_OOB
# 70.37893250807234
# sea_P(y) 1 incremental WEOB1
# 70.35681895951737
# sea_P(y) 1 incremental OOB
# 70.33583328899387
# sea_P(y) 1 incremental ESOS_ELM
# 65.53153617761798
# sea_P(y) 1 incremental improved_UOB
# 70.30404622699567
# sea_P(y) 1 incremental WEOB2
# 70.24594742649154
# sea_P(y) 1 incremental UOB
# 70.33583328899387
# sea_P(y) 1 incremental OSHAT
# 70.2150639171223
# sea_P(y) 1 incremental RebalanceStream
# 70.22553149698658
# sea_P(y) 3 sudden improved_OOB
# 64.6368984646941
# sea_P(y) 3 sudden WEOB1
# 64.66508664177272
# sea_P(y) 3 sudden OOB
# 64.61829871533901
# sea_P(y) 3 sudden ESOS_ELM
# 61.03015938952633
# sea_P(y) 3 sudden improved_UOB
# 64.59578900783663
# sea_P(y) 3 sudden WEOB2
# 64.352506765577
# sea_P(y) 3 sudden UOB
# 64.58449071397526
# sea_P(y) 3 sudden OSHAT
# 64.29709589700165
# sea_P(y) 3 sudden RebalanceStream
# 64.27453271025215
# sea_P(y) 2 incremental improved_OOB
# 64.65866731487436
# sea_P(y) 2 incremental WEOB1
# 64.68082277827105
# sea_P(y) 2 incremental OOB
# 64.62944415175681
# sea_P(y) 2 incremental ESOS_ELM
# 61.12691659804703
# sea_P(y) 2 incremental improved_UOB
# 64.57212479222073
# sea_P(y) 2 incremental WEOB2
# 64.36496512857023
# sea_P(y) 2 incremental UOB
# 64.5698342623623
# sea_P(y) 2 incremental OSHAT
# 62.49109125835164
# sea_P(y) 2 incremental RebalanceStream
# 64.30799002610239
# sea_P(y) 4 sudden improved_OOB
# 64.63466517954751
# sea_P(y) 4 sudden WEOB1
# 64.66388563446131
# sea_P(y) 4 sudden OOB
# 64.58533110460186
# sea_P(y) 4 sudden ESOS_ELM
# 61.00305220595396
# sea_P(y) 4 sudden improved_UOB
# 64.5830067841266
# sea_P(y) 4 sudden WEOB2
# 64.37238846420993
# sea_P(y) 4 sudden UOB
# 64.57589343841664
# sea_P(y) 4 sudden OSHAT
# 64.1251676874541
# sea_P(y) 4 sudden RebalanceStream
# 64.26171181870824
# sea_P(y_x) 1 sudden improved_OOB
# 63.54889262155267
# sea_P(y_x) 1 sudden WEOB1
# 63.37459605872808
# sea_P(y_x) 1 sudden OOB
# 63.867360482744026
# sea_P(y_x) 1 sudden ESOS_ELM
# 60.087345383046
# sea_P(y_x) 1 sudden improved_UOB
# 61.98413367823448
# sea_P(y_x) 1 sudden WEOB2
# 61.43358522896673
# sea_P(y_x) 1 sudden UOB
# 62.014441313778164
# sea_P(y_x) 1 sudden OSHAT
# 61.0480321300498
# sea_P(y_x) 1 sudden RebalanceStream
# 55.95967503866681
# sea_P(y_x) 3 incremental improved_OOB
# 64.03796350701904
# sea_P(y_x) 3 incremental WEOB1
# 63.9545374247282
# sea_P(y_x) 3 incremental OOB
# 64.17477256120152
# sea_P(y_x) 3 incremental ESOS_ELM
# 60.32608516237677
# sea_P(y_x) 3 incremental improved_UOB
# 63.52655165470942
# sea_P(y_x) 3 incremental WEOB2
# 62.30077330893486
# sea_P(y_x) 3 incremental UOB
# 63.28667129814139
# sea_P(y_x) 3 incremental OSHAT
# 63.44295615171192
# sea_P(y_x) 3 incremental RebalanceStream
# 62.47627871677944
# sea_P(y_x) 2 sudden improved_OOB
# 64.00450705155751
# sea_P(y_x) 2 sudden WEOB1
# 63.877742299695434
# sea_P(y_x) 2 sudden OOB
# 64.14914692160153
# sea_P(y_x) 2 sudden ESOS_ELM
# 60.066733519181675
# sea_P(y_x) 2 sudden improved_UOB
# 63.13420838441581
# sea_P(y_x) 2 sudden WEOB2
# 61.81625156771819
# sea_P(y_x) 2 sudden UOB
# 62.88944886569484
# sea_P(y_x) 2 sudden OSHAT
# 62.79959442303971
# sea_P(y_x) 2 sudden RebalanceStream
# 58.43655576279688
# sea_P(y_x) 4 incremental improved_OOB
# 64.01392742057723
# sea_P(y_x) 4 incremental WEOB1
# 63.988546774525844
# sea_P(y_x) 4 incremental OOB
# 64.18460768291088
# sea_P(y_x) 4 incremental ESOS_ELM
# 60.34515626608832
# sea_P(y_x) 4 incremental improved_UOB
# 63.82714337195652
# sea_P(y_x) 4 incremental WEOB2
# 62.001761451191626
# sea_P(y_x) 4 incremental UOB
# 63.6514760206343
# sea_P(y_x) 4 incremental OSHAT
# 63.61304295977421
# sea_P(y_x) 4 incremental RebalanceStream
# 63.42356618296925
# sea_P(y_x) 1 incremental improved_OOB
# 63.390590062854
# sea_P(y_x) 1 incremental WEOB1
# 63.33871261093236
# sea_P(y_x) 1 incremental OOB
# 63.65189038348458
# sea_P(y_x) 1 incremental ESOS_ELM
# 60.09462192222558
# sea_P(y_x) 1 incremental improved_UOB
# 62.149007062642475
# sea_P(y_x) 1 incremental WEOB2
# 61.71113312324068
# sea_P(y_x) 1 incremental UOB
# 62.308710119952345
# sea_P(y_x) 1 incremental OSHAT
# 60.92249385958485
# sea_P(y_x) 1 incremental RebalanceStream
# 56.159043481072956
# sea_P(y_x) 3 sudden improved_OOB
# 64.00416372956147
# sea_P(y_x) 3 sudden WEOB1
# 63.883551415548574
# sea_P(y_x) 3 sudden OOB
# 64.21475160664808
# sea_P(y_x) 3 sudden ESOS_ELM
# 60.19562462799426
# sea_P(y_x) 3 sudden improved_UOB
# 63.38994338332768
# sea_P(y_x) 3 sudden WEOB2
# 61.957002688330746
# sea_P(y_x) 3 sudden UOB
# 63.146542419006764
# sea_P(y_x) 3 sudden OSHAT
# 63.53477261763591
# sea_P(y_x) 3 sudden RebalanceStream
# 62.47396701187141
# sea_P(y_x) 2 incremental improved_OOB
# 64.03737124640068
# sea_P(y_x) 2 incremental WEOB1
# 63.914591785923236
# sea_P(y_x) 2 incremental OOB
# 64.3060751062001
# sea_P(y_x) 2 incremental ESOS_ELM
# 60.29045976089765
# sea_P(y_x) 2 incremental improved_UOB
# 63.20921075154521
# sea_P(y_x) 2 incremental WEOB2
# 62.31004521301975
# sea_P(y_x) 2 incremental UOB
# 62.92722233121181
# sea_P(y_x) 2 incremental OSHAT
# 62.40054618743922
# sea_P(y_x) 2 incremental RebalanceStream
# 58.78554154673176
# sea_P(y_x) 4 sudden improved_OOB
# 63.989133666975114
# sea_P(y_x) 4 sudden WEOB1
# 63.94152232214269
# sea_P(y_x) 4 sudden OOB
# 64.28308252666588
# sea_P(y_x) 4 sudden ESOS_ELM
# 60.306060585840896
# sea_P(y_x) 4 sudden improved_UOB
# 63.74049345398871
# sea_P(y_x) 4 sudden WEOB2
# 61.484281175874266
# sea_P(y_x) 4 sudden UOB
# 63.784296119017334
# sea_P(y_x) 4 sudden OSHAT
# 63.81197066930391
# sea_P(y_x) 4 sudden RebalanceStream
# 63.546736978380544
# sea_P(x_y) 1 sudden improved_OOB
# 64.45155987458746
# sea_P(x_y) 1 sudden WEOB1
# 64.68626334012706
# sea_P(x_y) 1 sudden OOB
# 64.56978108288153
# sea_P(x_y) 1 sudden ESOS_ELM
# 61.17870686868997
# sea_P(x_y) 1 sudden improved_UOB
# 63.537858214903814
# sea_P(x_y) 1 sudden WEOB2
# 62.71346502021631
# sea_P(x_y) 1 sudden UOB
# 63.33519686335281
# sea_P(x_y) 1 sudden OSHAT
# 62.54255515856006
# sea_P(x_y) 1 sudden RebalanceStream
# 57.508796859533426
# sea_P(x_y) 3 incremental improved_OOB
# 64.71079857294083
# sea_P(x_y) 3 incremental WEOB1
# 64.65806689172474
# sea_P(x_y) 3 incremental OOB
# 64.80928150092318
# sea_P(x_y) 3 incremental ESOS_ELM
# 61.49896285151325
# sea_P(x_y) 3 incremental improved_UOB
# 64.30281372587513
# sea_P(x_y) 3 incremental WEOB2
# 63.71503297744657
# sea_P(x_y) 3 incremental UOB
# 64.01204890021805
# sea_P(x_y) 3 incremental OSHAT
# 64.50274140467221
# sea_P(x_y) 3 incremental RebalanceStream
# 63.85550375169752
# sea_P(x_y) 2 sudden improved_OOB
# 64.606502871951
# sea_P(x_y) 2 sudden WEOB1
# 64.61681737091695
# sea_P(x_y) 2 sudden OOB
# 64.8856315059793
# sea_P(x_y) 2 sudden ESOS_ELM
# 60.68363373907598
# sea_P(x_y) 2 sudden improved_UOB
# 64.27879645359462
# sea_P(x_y) 2 sudden WEOB2
# 63.64490766416949
# sea_P(x_y) 2 sudden UOB
# 64.1256793023388
# sea_P(x_y) 2 sudden OSHAT
# 62.704027200919754
# sea_P(x_y) 2 sudden RebalanceStream
# 62.35238653429199
# sea_P(x_y) 4 incremental improved_OOB
# 64.50834949836045
# sea_P(x_y) 4 incremental WEOB1
# 64.45210375327176
# sea_P(x_y) 4 incremental OOB
# 64.61270090855828
# sea_P(x_y) 4 incremental ESOS_ELM
# 61.35815104385284
# sea_P(x_y) 4 incremental improved_UOB
# 64.28569471423812
# sea_P(x_y) 4 incremental WEOB2
# 63.31820549499165
# sea_P(x_y) 4 incremental UOB
# 63.741756811259926
# sea_P(x_y) 4 incremental OSHAT
# 64.4630724709406
# sea_P(x_y) 4 incremental RebalanceStream
# 64.26318972283403
# sea_P(x_y) 1 incremental improved_OOB
# 64.41401701932139
# sea_P(x_y) 1 incremental WEOB1
# 64.68236842135505
# sea_P(x_y) 1 incremental OOB
# 64.68070462727323
# sea_P(x_y) 1 incremental ESOS_ELM
# 61.45679708218891
# sea_P(x_y) 1 incremental improved_UOB
# 63.74403062156599
# sea_P(x_y) 1 incremental WEOB2
# 63.6130501428493
# sea_P(x_y) 1 incremental UOB
# 63.72434516509005
# sea_P(x_y) 1 incremental OSHAT
# 62.28720019815322
# sea_P(x_y) 1 incremental RebalanceStream
# 57.790783202371394
# sea_P(x_y) 3 sudden improved_OOB
# 64.6638295350649
# sea_P(x_y) 3 sudden WEOB1
# 64.56850053163973
# sea_P(x_y) 3 sudden OOB
# 64.8868622852044
# sea_P(x_y) 3 sudden ESOS_ELM
# 60.76874872277531
# sea_P(x_y) 3 sudden improved_UOB
# 64.23081546300716
# sea_P(x_y) 3 sudden WEOB2
# 64.06906775730633
# sea_P(x_y) 3 sudden UOB
# 64.07453232982297
# sea_P(x_y) 3 sudden OSHAT
# 64.49828746885689
# sea_P(x_y) 3 sudden RebalanceStream
# 62.899939323163856
# sea_P(x_y) 2 incremental improved_OOB
# 64.72670304805885
# sea_P(x_y) 2 incremental WEOB1
# 64.738541451972
# sea_P(x_y) 2 incremental OOB
# 64.8543771487874
# sea_P(x_y) 2 incremental ESOS_ELM
# 61.47018221357642
# sea_P(x_y) 2 incremental improved_UOB
# 64.22207887171643
# sea_P(x_y) 2 incremental WEOB2
# 63.606985100612896
# sea_P(x_y) 2 incremental UOB
# 64.05433996049575
# sea_P(x_y) 2 incremental OSHAT
# 63.365476406111426
# sea_P(x_y) 2 incremental RebalanceStream
# 63.248278358091305
# sea_P(x_y) 4 sudden improved_OOB
# 64.53613840787742
# sea_P(x_y) 4 sudden WEOB1
# 64.48800681213663
# sea_P(x_y) 4 sudden OOB
# 64.87327849749587
# sea_P(x_y) 4 sudden ESOS_ELM
# 60.64606312660002
# sea_P(x_y) 4 sudden improved_UOB
# 64.275923607541
# sea_P(x_y) 4 sudden WEOB2
# 64.02276092279774
# sea_P(x_y) 4 sudden UOB
# 63.96318752088323
# sea_P(x_y) 4 sudden OSHAT
# 64.48747065871729
# sea_P(x_y) 4 sudden RebalanceStream
# 64.08815821555008
# sine_P(y) 4 incremental improved_OOB
# 70.40739719825709
# sine_P(y) 4 incremental WEOB1
# 70.40139315245825
# sine_P(y) 4 incremental OOB
# 70.35740360068534
# sine_P(y) 4 incremental ESOS_ELM
# 65.66472448896522
# sine_P(y) 4 incremental improved_UOB
# 70.3401675434582
# sine_P(y) 4 incremental WEOB2
# 70.32583325260615
# sine_P(y) 4 incremental UOB
# 70.35740360068534
# sine_P(y) 4 incremental OSHAT
# 70.23195682581878
# sine_P(y) 4 incremental RebalanceStream
# 70.21797504600305
# sine_P(y) 3 sudden improved_OOB
# 70.38338266813015
# sine_P(y) 3 sudden WEOB1
# 70.36151901756821
# sine_P(y) 3 sudden OOB
# 70.26861419065791
# sine_P(y) 3 sudden ESOS_ELM
# 65.42750282007185
# sine_P(y) 3 sudden improved_UOB
# 70.22524195395758
# sine_P(y) 3 sudden WEOB2
# 70.17325246240259
# sine_P(y) 3 sudden UOB
# 70.26861419065791
# sine_P(y) 3 sudden OSHAT
# 70.0928403052749
# sine_P(y) 3 sudden RebalanceStream
# 69.6024341017642
# sine_P(y) 3 incremental improved_OOB
# 70.38872265964355
# sine_P(y) 3 incremental WEOB1
# 70.37432714762694
# sine_P(y) 3 incremental OOB
# 70.28889425035447
# sine_P(y) 3 incremental ESOS_ELM
# 65.5965815522156
# sine_P(y) 3 incremental improved_UOB
# 70.2409756946971
# sine_P(y) 3 incremental WEOB2
# 70.18765409468187
# sine_P(y) 3 incremental UOB
# 70.28889425035447
# sine_P(y) 3 incremental OSHAT
# 70.26799428987394
# sine_P(y) 3 incremental RebalanceStream
# 70.12040141881099
# sine_P(y) 4 sudden improved_OOB
# 70.38608293976185
# sine_P(y) 4 sudden WEOB1
# 70.38552894288361
# sine_P(y) 4 sudden OOB
# 70.34231360008266
# sine_P(y) 4 sudden ESOS_ELM
# 65.46640787428781
# sine_P(y) 4 sudden improved_UOB
# 70.32622991752399
# sine_P(y) 4 sudden WEOB2
# 70.30346378625703
# sine_P(y) 4 sudden UOB
# 70.34231360008266
# sine_P(y) 4 sudden OSHAT
# 70.22444345535584
# sine_P(y) 4 sudden RebalanceStream
# 70.21240411262262
# sine_P(y) 1 sudden improved_OOB
# 70.14380498495623
# sine_P(y) 1 sudden WEOB1
# 70.17449584809401
# sine_P(y) 1 sudden OOB
# 70.10988785593635
# sine_P(y) 1 sudden ESOS_ELM
# 65.10610815713855
# sine_P(y) 1 sudden improved_UOB
# 69.79024367902143
# sine_P(y) 1 sudden WEOB2
# 69.83506268354269
# sine_P(y) 1 sudden UOB
# 69.69341403818115
# sine_P(y) 1 sudden OSHAT
# 68.74831623941091
# sine_P(y) 1 sudden RebalanceStream
# 67.74605147035535
# sine_P(y) 2 incremental improved_OOB
# 70.35071972023249
# sine_P(y) 2 incremental WEOB1
# 70.32899195614696
# sine_P(y) 2 incremental OOB
# 70.36901144719772
# sine_P(y) 2 incremental ESOS_ELM
# 65.5323445268153
# sine_P(y) 2 incremental improved_UOB
# 70.1151874545044
# sine_P(y) 2 incremental WEOB2
# 70.03297150779474
# sine_P(y) 2 incremental UOB
# 70.07760967468087
# sine_P(y) 2 incremental OSHAT
# 69.78482182092344
# sine_P(y) 2 incremental RebalanceStream
# 69.06255289708803
# sine_P(y) 1 incremental improved_OOB
# 70.18442086728555
# sine_P(y) 1 incremental WEOB1
# 70.21376481982637
# sine_P(y) 1 incremental OOB
# 70.14057977126849
# sine_P(y) 1 incremental ESOS_ELM
# 65.39259454903186
# sine_P(y) 1 incremental improved_UOB
# 69.87343906701253
# sine_P(y) 1 incremental WEOB2
# 69.88675660509111
# sine_P(y) 1 incremental UOB
# 69.82625100436822
# sine_P(y) 1 incremental OSHAT
# 69.00886987889722
# sine_P(y) 1 incremental RebalanceStream
# 68.46468116646568
# sine_P(y) 2 sudden improved_OOB
# 70.3397625621727
# sine_P(y) 2 sudden WEOB1
# 70.32683808191896
# sine_P(y) 2 sudden OOB
# 70.36621982572902
# sine_P(y) 2 sudden ESOS_ELM
# 65.31448389058772
# sine_P(y) 2 sudden improved_UOB
# 70.11266879272235
# sine_P(y) 2 sudden WEOB2
# 70.02291155408605
# sine_P(y) 2 sudden UOB
# 70.07535874366587
# sine_P(y) 2 sudden OSHAT
# 69.4841854494205
# sine_P(y) 2 sudden RebalanceStream
# 69.06114205350137
# sine_P(y_x) 4 incremental improved_OOB
# 68.59553342150991
# sine_P(y_x) 4 incremental WEOB1
# 68.61008602231355
# sine_P(y_x) 4 incremental OOB
# 68.53587496909363
# sine_P(y_x) 4 incremental ESOS_ELM
# 64.10077588248326
# sine_P(y_x) 4 incremental improved_UOB
# 68.50161256117687
# sine_P(y_x) 4 incremental WEOB2
# 58.4916038710238
# sine_P(y_x) 4 incremental UOB
# 68.2027188094709
# sine_P(y_x) 4 incremental OSHAT
# 68.0480317920366
# sine_P(y_x) 4 incremental RebalanceStream
# 68.16975250631046
# sine_P(y_x) 3 sudden improved_OOB
# 69.9036260684112
# sine_P(y_x) 3 sudden WEOB1
# 69.82091456066723
# sine_P(y_x) 3 sudden OOB
# 69.90702219902799
# sine_P(y_x) 3 sudden ESOS_ELM
# 63.58178709448771
# sine_P(y_x) 3 sudden improved_UOB
# 69.58078842405612
# sine_P(y_x) 3 sudden WEOB2
# 63.34833617151967
# sine_P(y_x) 3 sudden UOB
# 69.41037993845052
# sine_P(y_x) 3 sudden OSHAT
# 68.89597778197347
# sine_P(y_x) 3 sudden RebalanceStream
# 69.4442038657794
# sine_P(y_x) 3 incremental improved_OOB
# 68.66002663400113
# sine_P(y_x) 3 incremental WEOB1
# 68.6199183437869
# sine_P(y_x) 3 incremental OOB
# 68.53084374916634
# sine_P(y_x) 3 incremental ESOS_ELM
# 63.534196586140375
# sine_P(y_x) 3 incremental improved_UOB
# 68.3604121130867
# sine_P(y_x) 3 incremental WEOB2
# 59.146351889172266
# sine_P(y_x) 3 incremental UOB
# 68.12843679302229
# sine_P(y_x) 3 incremental OSHAT
# 67.60391396198045
# sine_P(y_x) 3 incremental RebalanceStream
# 67.95151698660496
# sine_P(y_x) 4 sudden improved_OOB
# 69.93298490994212
# sine_P(y_x) 4 sudden WEOB1
# 69.92375018538732
# sine_P(y_x) 4 sudden OOB
# 69.7587131831034
# sine_P(y_x) 4 sudden ESOS_ELM
# 62.855831216530646
# sine_P(y_x) 4 sudden improved_UOB
# 69.68243483004635
# sine_P(y_x) 4 sudden WEOB2
# 64.08284118159713
# sine_P(y_x) 4 sudden UOB
# 69.7587131831034
# sine_P(y_x) 4 sudden OSHAT
# 69.24814481438966
# sine_P(y_x) 4 sudden RebalanceStream
# 69.74737480690206
# sine_P(y_x) 1 sudden improved_OOB
# 69.57487656219105
# sine_P(y_x) 1 sudden WEOB1
# 69.62849768942536
# sine_P(y_x) 1 sudden OOB
# 69.59299009228428
# sine_P(y_x) 1 sudden ESOS_ELM
# 64.24466290437579
# sine_P(y_x) 1 sudden improved_UOB
# 67.62426876846123
# sine_P(y_x) 1 sudden WEOB2
# 57.07454087884595
# sine_P(y_x) 1 sudden UOB
# 66.54521874119715
# sine_P(y_x) 1 sudden OSHAT
# 65.64973992242585
# sine_P(y_x) 1 sudden RebalanceStream
# 67.58244906998064
# sine_P(y_x) 2 incremental improved_OOB
# 68.54082055289254
# sine_P(y_x) 2 incremental WEOB1
# 68.49456310186943
# sine_P(y_x) 2 incremental OOB
# 68.62873412712284
# sine_P(y_x) 2 incremental ESOS_ELM
# 63.716500587552616
# sine_P(y_x) 2 incremental improved_UOB
# 68.03459630239777
# sine_P(y_x) 2 incremental WEOB2
# 56.01097016423587
# sine_P(y_x) 2 incremental UOB
# 68.02761961941715
# sine_P(y_x) 2 incremental OSHAT
# 66.82025334521606
# sine_P(y_x) 2 incremental RebalanceStream
# 66.08837000088349
# sine_P(y_x) 1 incremental improved_OOB
# 68.13716292034697
# sine_P(y_x) 1 incremental WEOB1
# 68.20133878552824
# sine_P(y_x) 1 incremental OOB
# 68.21585163721019
# sine_P(y_x) 1 incremental ESOS_ELM
# 64.08582388223773
# sine_P(y_x) 1 incremental improved_UOB
# 66.64112656951508
# sine_P(y_x) 1 incremental WEOB2
# 54.083256010429444
# sine_P(y_x) 1 incremental UOB
# 66.25668354688892
# sine_P(y_x) 1 incremental OSHAT
# 64.83150986568225
# sine_P(y_x) 1 incremental RebalanceStream
# 64.10740900618967
# sine_P(y_x) 2 sudden improved_OOB
# 69.83214516369438
# sine_P(y_x) 2 sudden WEOB1
# 69.81130274339355
# sine_P(y_x) 2 sudden OOB
# 69.97478795188472
# sine_P(y_x) 2 sudden ESOS_ELM
# 63.84361399275416
# sine_P(y_x) 2 sudden improved_UOB
# 68.86077814415466
# sine_P(y_x) 2 sudden WEOB2
# 56.32467009808211
# sine_P(y_x) 2 sudden UOB
# 68.6127836548033
# sine_P(y_x) 2 sudden OSHAT
# 68.03537526110287
# sine_P(y_x) 2 sudden RebalanceStream
# 68.81015520641344
# sine_P(x_y) 4 incremental improved_OOB
# 70.41003315224181
# sine_P(x_y) 4 incremental WEOB1
# 70.38886759385375
# sine_P(x_y) 4 incremental OOB
# 70.39859358386032
# sine_P(x_y) 4 incremental ESOS_ELM
# 65.26195499185161
# sine_P(x_y) 4 incremental improved_UOB
# 70.28820910441878
# sine_P(x_y) 4 incremental WEOB2
# 70.23177167871985
# sine_P(x_y) 4 incremental UOB
# 70.39859358386033
# sine_P(x_y) 4 incremental OSHAT
# 70.22891975070885
# sine_P(x_y) 4 incremental RebalanceStream
# 70.08548806693531
# sine_P(x_y) 3 sudden improved_OOB
# 70.37207705623985
# sine_P(x_y) 3 sudden WEOB1
# 70.38846608195345
# sine_P(x_y) 3 sudden OOB
# 70.40098411320177
# sine_P(x_y) 3 sudden ESOS_ELM
# 65.4649617398985
# sine_P(x_y) 3 sudden improved_UOB
# 70.25645339459155
# sine_P(x_y) 3 sudden WEOB2
# 70.21835240141368
# sine_P(x_y) 3 sudden UOB
# 70.1590560991533
# sine_P(x_y) 3 sudden OSHAT
# 70.2107693712301
# sine_P(x_y) 3 sudden RebalanceStream
# 70.03901882173543
# sine_P(x_y) 3 incremental improved_OOB
# 70.35460750850152
# sine_P(x_y) 3 incremental WEOB1
# 70.38943141390959
# sine_P(x_y) 3 incremental OOB
# 70.39545430725352
# sine_P(x_y) 3 incremental ESOS_ELM
# 65.35274467207688
# sine_P(x_y) 3 incremental improved_UOB
# 70.2477136421746
# sine_P(x_y) 3 incremental WEOB2
# 70.20205984049622
# sine_P(x_y) 3 incremental UOB
# 70.13434259538573
# sine_P(x_y) 3 incremental OSHAT
# 70.22274824208098
# sine_P(x_y) 3 incremental RebalanceStream
# 69.84061038655162
# sine_P(x_y) 4 sudden improved_OOB
# 70.41624253310604
# sine_P(x_y) 4 sudden WEOB1
# 70.39413885326687
# sine_P(x_y) 4 sudden OOB
# 70.40915997077278
# sine_P(x_y) 4 sudden ESOS_ELM
# 65.44535669600874
# sine_P(x_y) 4 sudden improved_UOB
# 70.29929327034867
# sine_P(x_y) 4 sudden WEOB2
# 70.27750967966463
# sine_P(x_y) 4 sudden UOB
# 70.40915997077278
# sine_P(x_y) 4 sudden OSHAT
# 70.2417241956787
# sine_P(x_y) 4 sudden RebalanceStream
# 70.13839299046957
# sine_P(x_y) 1 sudden improved_OOB
# 70.08604996032076
# sine_P(x_y) 1 sudden WEOB1
# 70.19339333895172
# sine_P(x_y) 1 sudden OOB
# 70.0861117253787
# sine_P(x_y) 1 sudden ESOS_ELM
# 64.88354031726814
# sine_P(x_y) 1 sudden improved_UOB
# 70.00861462694209
# sine_P(x_y) 1 sudden WEOB2
# 69.8195909666778
# sine_P(x_y) 1 sudden UOB
# 69.90378843317458
# sine_P(x_y) 1 sudden OSHAT
# 68.58806653752461
# sine_P(x_y) 1 sudden RebalanceStream
# 69.06053046757015
# sine_P(x_y) 2 incremental improved_OOB
# 70.35273505966595
# sine_P(x_y) 2 incremental WEOB1
# 70.36847085849608
# sine_P(x_y) 2 incremental OOB
# 70.37717215787652
# sine_P(x_y) 2 incremental ESOS_ELM
# 65.23807575879212
# sine_P(x_y) 2 incremental improved_UOB
# 70.1758369770337
# sine_P(x_y) 2 incremental WEOB2
# 70.14729428137979
# sine_P(x_y) 2 incremental UOB
# 70.08179688236888
# sine_P(x_y) 2 incremental OSHAT
# 69.70861750472656
# sine_P(x_y) 2 incremental RebalanceStream
# 69.84485577272508
# sine_P(x_y) 1 incremental improved_OOB
# 70.10139768812886
# sine_P(x_y) 1 incremental WEOB1
# 70.20790253404968
# sine_P(x_y) 1 incremental OOB
# 70.1255444367439
# sine_P(x_y) 1 incremental ESOS_ELM
# 65.1596372159435
# sine_P(x_y) 1 incremental improved_UOB
# 70.06545681233055
# sine_P(x_y) 1 incremental WEOB2
# 69.85395266097191
# sine_P(x_y) 1 incremental UOB
# 69.95996926435326
# sine_P(x_y) 1 incremental OSHAT
# 68.59060246320038
# sine_P(x_y) 1 incremental RebalanceStream
# 69.10225534592428
# sine_P(x_y) 2 sudden improved_OOB
# 70.35665802131493
# sine_P(x_y) 2 sudden WEOB1
# 70.38132599725523
# sine_P(x_y) 2 sudden OOB
# 70.37649910377755
# sine_P(x_y) 2 sudden ESOS_ELM
# 65.3978194149569
# sine_P(x_y) 2 sudden improved_UOB
# 70.17438225167874
# sine_P(x_y) 2 sudden WEOB2
# 70.15811843092912
# sine_P(x_y) 2 sudden UOB
# 70.0861833121186
# sine_P(x_y) 2 sudden OSHAT
# 69.87705728340052
# sine_P(x_y) 2 sudden RebalanceStream
# 69.85589122620468

# %%
old = final_dict.copy()

# %% [markdown]
# # NEW

# %%
final_dict = old.copy()

# %%
for new in new_drifts:
    path = main_dir + "/" + new 
    
    if new not in final_dict:
        final_dict[new] = {}
        
    for unbalance in range(1,5):
        if unbalance not in final_dict[new]:
            final_dict[new][unbalance] = {}


        path1 = path + "/" + str(unbalance)

        for alg in os.listdir(path1):
            if "DS_Store" in alg:
                continue
            path2 = path1 + "/" + alg
            
            alg_dtypes = {}
            alg_dtypes["incremental"] = []
            alg_dtypes["sudden"] = []
            alg_dtypes["periodic"] = []
            
            
            print(f"{new} {unbalance} {alg}")
            #prendo i valori di tutti i 10 esperimenti dei 3 dtype
            
            for result in os.listdir(path2):
                if "err" not in result or "DS_Store" in result:
                    continue
                val = []
                data = import_csv(path2+"/"+ result)
                start = False
                
                for data_row in data:
                    if data_row[1] == "learning evaluation instances":
                        start = True
                        continue
                    if not start:
                        continue

                    try:
                        val.append(float(data_row[13]))
                    except:
                        if data_row[13] == "?":
                            val.append(50)
                        else:
                            print("ZERO")
                            print(data_row)
                    
                        
                    
                
                try:
                    if len(val)>0:
                        alg_dtypes[result[:result.index("_")]].append(np.mean(val))
                except:
                    print(f"error with {result}")
            for k,i in alg_dtypes.items():      
                if k not in final_dict[new][unbalance]:
                    final_dict[new][unbalance][k] = {}
                assert alg not in final_dict[new][unbalance][k]
                final_dict[new][unbalance][k][alg] = {}
                final_dict[new][unbalance][k][alg] = np.mean(i)
                print(k)
                print(np.mean(i))
# Out:
# jitter 1 improved_OOB
# incremental
# 65.54680798951384
# sudden
# 68.06786687849583
# periodic
# 65.54680798951384
# jitter 1 WEOB1
# incremental
# 65.97873469088998
# sudden
# 68.07209927270017
# periodic
# 65.97873469088998
# jitter 1 CSMOTE
# incremental
# 63.12492595289929
# sudden
# 65.08266301936467
# periodic
# 63.12492595289929
# jitter 1 OOB
# incremental
# 65.73554498836094
# sudden
# 68.06853102909277
# periodic
# 65.73554498836094
# jitter 1 ESOS_ELM
# incremental
# 60.627986340595996
# sudden
# 63.500754175705694
# periodic
# 60.36062744426353
# jitter 1 improved_UOB
# incremental
# 64.57847189331599
# sudden
# 66.22416208604338
# periodic
# 64.57847189331599
# jitter 1 WEOB2
# incremental
# 64.46000559134856
# sudden
# 65.2869211400174
# periodic
# 64.46000559134856
# jitter 1 UOB
# incremental
# 64.47643472569294
# sudden
# 65.76155416824315
# periodic
# 64.47643472569294
# jitter 1 RebalanceStream
# incremental
# 54.52086864093758
# sudden
# 60.415199554566605
# periodic
# 54.52086864093758
# jitter 2 improved_OOB
# incremental
# 66.37410959483205
# sudden
# 68.0404451274816
# periodic
# 66.37410959483205
# jitter 2 WEOB1
# incremental
# 66.37507539279667
# sudden
# 67.93069810131354
# periodic
# 66.37507539279667
# jitter 2 CSMOTE
# incremental
# 64.31770050017465
# sudden
# 65.78083132704782
# periodic
# 64.31770050017465
# jitter 2 OOB
# incremental
# 66.70391390343386
# sudden
# 68.2122324659563
# periodic
# 66.70391390343386
# jitter 2 ESOS_ELM
# incremental
# 60.81633673335158
# sudden
# 63.33989806985255
# periodic
# 60.79290209160746
# jitter 2 improved_UOB
# incremental
# 64.31285158276901
# sudden
# 66.8420604459244
# periodic
# 64.31285158276901
# jitter 2 WEOB2
# incremental
# 64.93659595523494
# sudden
# 65.94533355127781
# periodic
# 64.93659595523494
# jitter 2 UOB
# incremental
# 64.77258011359257
# sudden
# 66.54982335991981
# periodic
# 64.77258011359257
# jitter 2 RebalanceStream
# incremental
# 61.78640761419864
# sudden
# 64.9962737106864
# periodic
# 61.78640761419864
# jitter 3 improved_OOB
# incremental
# 66.97973718941998
# sudden
# 68.20218564095885
# periodic
# 66.97973718941998
# jitter 3 WEOB1
# incremental
# 66.84248486462924
# sudden
# 68.0385978866633
# periodic
# 66.84248486462924
# jitter 3 CSMOTE
# incremental
# 65.36687476450018
# sudden
# 66.06723311928644
# periodic
# 65.36687476450018
# jitter 3 OOB
# incremental
# 67.01713606972557
# sudden
# 68.22517175712309
# periodic
# 67.01713606972557
# jitter 3 ESOS_ELM
# incremental
# 62.04299437895683
# sudden
# 63.38714263491804
# periodic
# 62.044375705102276
# jitter 3 improved_UOB
# incremental
# 66.42094533493739
# sudden
# 67.5330278661522
# periodic
# 66.42094533493739
# jitter 3 WEOB2
# incremental
# 65.75702455872575
# sudden
# 66.20077483461891
# periodic
# 65.75702455872575
# jitter 3 UOB
# incremental
# 66.05422080217008
# sudden
# 67.09211430335344
# periodic
# 66.05422080217008
# jitter 3 RebalanceStream
# incremental
# 65.26323204117492
# sudden
# 67.05606296701583
# periodic
# 65.26323204117492
# jitter 4 improved_OOB
# incremental
# 66.79947661018363
# sudden
# 67.98993642631335
# periodic
# 66.79947661018363
# jitter 4 WEOB1
# incremental
# 66.61458125777997
# sudden
# 67.90509473115539
# periodic
# 66.61458125777997
# jitter 4 CSMOTE
# incremental
# 65.33087751350595
# sudden
# 66.20563980068945
# periodic
# 65.33087751350595
# jitter 4 OOB
# incremental
# 66.37953059670906
# sudden
# 67.85814911722971
# periodic
# 66.37953059670906
# jitter 4 ESOS_ELM
# incremental
# 61.16129190221403
# sudden
# 63.34246731382247
# periodic
# 61.005957347229185
# jitter 4 improved_UOB
# incremental
# 65.7530821384556
# sudden
# 67.58651033401733
# periodic
# 65.7530821384556
# jitter 4 WEOB2
# incremental
# 65.49539600972443
# sudden
# 65.92273020822009
# periodic
# 65.49539600972443
# jitter 4 UOB
# incremental
# 66.37953059670906
# sudden
# 67.85814911722971
# periodic
# 66.37953059670906
# jitter 4 RebalanceStream
# incremental
# 65.60781885595068
# sudden
# 67.69902030171428
# periodic
# 65.60781885595068
# disappearing-minority 1 improved_OOB
# incremental
# 58.78151664725533
# sudden
# 57.81232262070282
# periodic
# 65.83513709965686
# disappearing-minority 1 WEOB1
# incremental
# 58.773002320121954
# sudden
# 57.880923766505745
# periodic
# 66.22386658931262
# disappearing-minority 1 CSMOTE
# incremental
# 57.306728632821624
# sudden
# 56.771651143525766
# periodic
# 64.17885236629414
# disappearing-minority 1 OOB
# incremental
# 58.79682227017228
# sudden
# 57.828094090124104
# periodic
# 65.91640158383123
# disappearing-minority 1 ESOS_ELM
# incremental
# 54.67837050129757
# sudden
# 53.84439669040912
# periodic
# 60.99720382118339
# disappearing-minority 1 improved_UOB
# incremental
# 57.65061089999735
# sudden
# 56.86483470532373
# periodic
# 64.90313488635567
# disappearing-minority 1 WEOB2
# incremental
# 57.58652705925501
# sudden
# 56.82222562969432
# periodic
# 64.56765979179735
# disappearing-minority 1 UOB
# incremental
# 57.578783103297575
# sudden
# 56.79376504751548
# periodic
# 64.83022626232743
# disappearing-minority 1 RebalanceStream
# incremental
# 50.47313637322053
# sudden
# 50.12478065079558
# periodic
# 54.940454941477775
# disappearing-minority 2 improved_OOB
# incremental
# 58.7700763062021
# sudden
# 57.882143916833016
# periodic
# 66.30230226824486
# disappearing-minority 2 WEOB1
# incremental
# 58.71902979332473
# sudden
# 57.84409554948536
# periodic
# 66.4422719669192
# disappearing-minority 2 CSMOTE
# incremental
# 58.19451660464396
# sudden
# 57.64906367377923
# periodic
# 65.31749175898786
# disappearing-minority 2 OOB
# incremental
# 58.9424306141972
# sudden
# 58.05646675282243
# periodic
# 66.52219729220519
# disappearing-minority 2 ESOS_ELM
# incremental
# 54.669884357137775
# sudden
# 53.78654990629146
# periodic
# 61.20413768283985
# disappearing-minority 2 improved_UOB
# incremental
# 58.09461443069567
# sudden
# 57.22357001640121
# periodic
# 65.87223227973416
# disappearing-minority 2 WEOB2
# incremental
# 57.921276797504014
# sudden
# 57.07476583535767
# periodic
# 65.59014691972516
# disappearing-minority 2 UOB
# incremental
# 57.893131870001206
# sudden
# 57.05634508811162
# periodic
# 65.56883666561876
# disappearing-minority 2 RebalanceStream
# incremental
# 55.182160903623455
# sudden
# 54.773655601765654
# periodic
# 57.58909876923847
# disappearing-minority 3 improved_OOB
# incremental
# 58.90356356955367
# sudden
# 58.028668632581095
# periodic
# 66.47791607188654
# disappearing-minority 3 WEOB1
# incremental
# 58.80482422362955
# sudden
# 57.92295340949939
# periodic
# 66.62637052059765
# disappearing-minority 3 CSMOTE
# incremental
# 58.54216320330696
# sudden
# 57.87261264464621
# periodic
# 65.93490344305687
# disappearing-minority 3 OOB
# incremental
# 58.914089254395094
# sudden
# 58.03536320362688
# periodic
# 66.51452773083028
# disappearing-minority 3 ESOS_ELM
# incremental
# 54.59378162474119
# sudden
# 53.72390649817845
# periodic
# 60.89129638584708
# disappearing-minority 3 improved_UOB
# incremental
# 58.48585689190385
# sudden
# 57.6258455821944
# periodic
# 66.31675103555384
# disappearing-minority 3 WEOB2
# incremental
# 58.29074306566895
# sudden
# 57.41443828673319
# periodic
# 66.05556946380325
# disappearing-minority 3 UOB
# incremental
# 58.144574922356604
# sudden
# 57.27803449648353
# periodic
# 65.9324629709075
# disappearing-minority 3 RebalanceStream
# incremental
# 57.25897351243693
# sudden
# 56.98624218659139
# periodic
# 62.2304774092785
# disappearing-minority 4 improved_OOB
# incremental
# 58.82774232058453
# sudden
# 57.93929981631777
# periodic
# 66.46870563536501
# disappearing-minority 4 WEOB1
# incremental
# 58.7471742942465
# sudden
# 57.879085250729545
# periodic
# 66.5907552896251
# disappearing-minority 4 CSMOTE
# incremental
# 58.55749522878828
# sudden
# 57.95542585415969
# periodic
# 66.08325583118506
# disappearing-minority 4 OOB
# incremental
# 58.705638182144504
# sudden
# 57.799172315539316
# periodic
# 66.36913581609112
# disappearing-minority 4 ESOS_ELM
# incremental
# 54.617271509169164
# sudden
# 53.71775146717484
# periodic
# 60.813085609402286
# disappearing-minority 4 improved_UOB
# incremental
# 58.46409984659855
# sudden
# 57.624427039882825
# periodic
# 66.35807844463922
# disappearing-minority 4 WEOB2
# incremental
# 58.26274761718129
# sudden
# 57.39429204385302
# periodic
# 66.08475904915704
# disappearing-minority 4 UOB
# incremental
# 58.70544995922014
# sudden
# 57.799172315539316
# periodic
# 65.81641432051029
# disappearing-minority 4 RebalanceStream
# incremental
# 57.830251887161054
# sudden
# 57.61366915811235
# periodic
# 65.22322660208374
# appearing-minority 1 improved_OOB
# incremental
# 58.33129744975289
# sudden
# 57.800665208436726
# periodic
# 51.34712449379024
# appearing-minority 1 WEOB1
# incremental
# 58.69942755855087
# sudden
# 57.93917875459706
# periodic
# 51.49561110463246
# appearing-minority 1 CSMOTE
# incremental
# 57.24298772940339
# sudden
# 56.695878412411595
# periodic
# 51.25877161376354
# appearing-minority 1 OOB
# incremental
# 58.56038790208331
# sudden
# 58.06924396756134
# periodic
# 51.346407912474305
# appearing-minority 1 ESOS_ELM
# incremental
# 50.0
# sudden
# 50.0
# periodic
# 50.0
# appearing-minority 1 improved_UOB
# incremental
# 57.834985240474374
# sudden
# 56.83618808981028
# periodic
# 51.41654519654744
# appearing-minority 1 WEOB2
# incremental
# 57.68109576375863
# sudden
# 56.705767719330915
# periodic
# 51.41218804291721
# appearing-minority 1 UOB
# incremental
# 57.56807907256738
# sudden
# 56.54750566225289
# periodic
# 50.99921332408148
# appearing-minority 1 RebalanceStream
# incremental
# 52.14473376792995
# sudden
# 50.91912665419018
# periodic
# 51.00510301180678
# appearing-minority 2 improved_OOB
# incremental
# 59.018056402590936
# sudden
# 58.308499506956615
# periodic
# 51.54403672443514
# appearing-minority 2 WEOB1
# incremental
# 59.20485211387771
# sudden
# 58.240219911185214
# periodic
# 51.61332072013221
# appearing-minority 2 CSMOTE
# incremental
# 58.012176852540094
# sudden
# 57.48465930301503
# periodic
# 51.39506174332172
# appearing-minority 2 OOB
# incremental
# 59.21394062781682
# sudden
# 58.31392777998967
# periodic
# 51.584672820267336
# appearing-minority 2 ESOS_ELM
# incremental
# 50.0
# sudden
# 50.0
# periodic
# 50.0
# appearing-minority 2 improved_UOB
# incremental
# 58.38310941846644
# sudden
# 57.36015396077615
# periodic
# 51.43804337155323
# appearing-minority 2 WEOB2
# incremental
# 58.16049576315005
# sudden
# 57.16129102173254
# periodic
# 51.43214105741504
# appearing-minority 2 UOB
# incremental
# 58.87613886312355
# sudden
# 57.39022431682704
# periodic
# 51.3170940770739
# appearing-minority 2 RebalanceStream
# incremental
# 54.17645627588662
# sudden
# 54.29666423914114
# periodic
# 51.20719280303943
# appearing-minority 3 improved_OOB
# incremental
# 59.32718208757012
# sudden
# 58.301767672089476
# periodic
# 51.644734694660215
# appearing-minority 3 WEOB1
# incremental
# 59.25954592441743
# sudden
# 58.246377787078515
# periodic
# 51.63318332907416
# appearing-minority 3 CSMOTE
# incremental
# 58.68121875358016
# sudden
# 58.07087279574686
# periodic
# 51.410055785746636
# appearing-minority 3 OOB
# incremental
# 59.45120981199917
# sudden
# 58.22323389650019
# periodic
# 51.6909378873671
# appearing-minority 3 ESOS_ELM
# incremental
# 50.0
# sudden
# 50.0
# periodic
# 50.0
# appearing-minority 3 improved_UOB
# incremental
# 58.86054289687528
# sudden
# 57.501965174835085
# periodic
# 51.46770515401181
# appearing-minority 3 WEOB2
# incremental
# 58.541521175162906
# sudden
# 57.29859702412011
# periodic
# 51.44541667198483
# appearing-minority 3 UOB
# incremental
# 58.783182924230914
# sudden
# 57.64462356910322
# periodic
# 51.44564346593438
# appearing-minority 3 RebalanceStream
# incremental
# 57.591067579067534
# sudden
# 56.700917714994674
# periodic
# 51.29898172219699
# appearing-minority 4 improved_OOB
# incremental
# 59.38721383181852
# sudden
# 58.29709680589701
# periodic
# 51.634303163973506
# appearing-minority 4 WEOB1
# incremental
# 59.37383279528198
# sudden
# 58.19205046817141
# periodic
# 51.596398931809176
# appearing-minority 4 CSMOTE
# incremental
# 58.69108632247687
# sudden
# 57.92810782669794
# periodic
# 51.43871180670586
# appearing-minority 4 OOB
# incremental
# 59.484959277631525
# sudden
# 58.19263929174459
# periodic
# 51.63162283798529
# appearing-minority 4 ESOS_ELM
# incremental
# 50.0
# sudden
# 50.0
# periodic
# 50.0
# appearing-minority 4 improved_UOB
# incremental
# 59.03556799271589
# sudden
# 57.54910599263852
# periodic
# 51.50075814020251
# appearing-minority 4 WEOB2
# incremental
# 58.9156423564635
# sudden
# 57.305372460034654
# periodic
# 51.45388630117905
# appearing-minority 4 UOB
# incremental
# 59.06141505601189
# sudden
# 57.67366525661915
# periodic
# 51.43408177164529
# appearing-minority 4 RebalanceStream
# incremental
# 58.458958664652734
# sudden
# 57.35028899627413
# periodic
# 50.98082108613586
# appearing-clusters 1 improved_OOB
# incremental
# 67.33603414957295
# sudden
# 67.60891207312916
# periodic
# 69.28727245343258
# appearing-clusters 1 WEOB1
# incremental
# 67.59485642265005
# sudden
# 67.64921550885296
# periodic
# 69.26982103489897
# appearing-clusters 1 CSMOTE
# incremental
# 66.20156798566568
# sudden
# 66.25003612010536
# periodic
# 68.59020083204396
# appearing-clusters 1 OOB
# incremental
# 67.70393741368402
# sudden
# 67.62124742339435
# periodic
# 69.2913314538531
# appearing-clusters 1 ESOS_ELM
# incremental
# 61.20989589513723
# sudden
# 61.04654408010614
# periodic
# 62.69668193839377
# appearing-clusters 1 improved_UOB
# incremental
# 67.30974533508973
# sudden
# 67.28489872148899
# periodic
# 68.97842610185774
# appearing-clusters 1 WEOB2
# incremental
# 66.718707308034
# sudden
# 66.3217795727713
# periodic
# 68.83547771741755
# appearing-clusters 1 UOB
# incremental
# 67.21483903082148
# sudden
# 67.1305999173028
# periodic
# 68.90789055622326
# appearing-clusters 1 RebalanceStream
# incremental
# 62.835546048824234
# sudden
# 62.81365013232911
# periodic
# 64.119624470187
# appearing-clusters 2 improved_OOB
# incremental
# 68.1520114095134
# sudden
# 68.02839664426776
# periodic
# 69.41766595464676
# appearing-clusters 2 WEOB1
# incremental
# 68.09826337321104
# sudden
# 68.04734867748788
# periodic
# 69.35862148596469
# appearing-clusters 2 CSMOTE
# incremental
# 67.37353711594442
# sudden
# 67.09079567609663
# periodic
# 69.23521651871008
# appearing-clusters 2 OOB
# incremental
# 68.23458809986388
# sudden
# 68.13619106757918
# periodic
# 69.41447654574617
# appearing-clusters 2 ESOS_ELM
# incremental
# 61.047532598298325
# sudden
# 61.04266082261056
# periodic
# 62.726612022904916
# appearing-clusters 2 improved_UOB
# incremental
# 67.76485031532111
# sudden
# 67.76877273634719
# periodic
# 69.21677709673169
# appearing-clusters 2 WEOB2
# incremental
# 67.57856425213632
# sudden
# 67.47670744735606
# periodic
# 69.06911756883116
# appearing-clusters 2 UOB
# incremental
# 67.64929689907919
# sudden
# 67.57299967298532
# periodic
# 69.08532088237384
# appearing-clusters 2 RebalanceStream
# incremental
# 66.52275770165889
# sudden
# 65.88798286383135
# periodic
# 68.39868427444947
# appearing-clusters 3 improved_OOB
# incremental
# 68.19920457086933
# sudden
# 68.05094361263528
# periodic
# 69.32944832957256
# appearing-clusters 3 WEOB1
# incremental
# 68.16312037932401
# sudden
# 68.01093296257082
# periodic
# 69.2793555469469
# appearing-clusters 3 CSMOTE
# incremental
# 67.65166484279504
# sudden
# 67.5246477480404
# periodic
# 69.26387183379384
# appearing-clusters 3 OOB
# incremental
# 68.25912254731779
# sudden
# 68.1101958065544
# periodic
# 69.3136856494198
# appearing-clusters 3 ESOS_ELM
# incremental
# 61.036502748698275
# sudden
# 60.883111898634375
# periodic
# 62.714232447730936
# appearing-clusters 3 improved_UOB
# incremental
# 67.96976578105092
# sudden
# 67.86287328178966
# periodic
# 69.18624579703081
# appearing-clusters 3 WEOB2
# incremental
# 67.93658806772218
# sudden
# 67.74677081325453
# periodic
# 69.15083560300764
# appearing-clusters 3 UOB
# incremental
# 68.01898610548633
# sudden
# 67.96181002175273
# periodic
# 69.3136856494198
# appearing-clusters 3 RebalanceStream
# incremental
# 67.54049461129416
# sudden
# 67.50894376494622
# periodic
# 69.07685300562619
# appearing-clusters 4 improved_OOB
# incremental
# 68.19612809841736
# sudden
# 68.07852387190806
# periodic
# 69.28361297481624
# appearing-clusters 4 WEOB1
# incremental
# 68.15314889076595
# sudden
# 68.05149422255177
# periodic
# 69.26277995236612
# appearing-clusters 4 CSMOTE
# incremental
# 67.84368795034109
# sudden
# 67.76094289978712
# periodic
# 69.28706315492846
# appearing-clusters 4 OOB
# incremental
# 68.2901301932044
# sudden
# 68.20621384763923
# periodic
# 69.33484819737518
# appearing-clusters 4 ESOS_ELM
# incremental
# 61.34100107529407
# sudden
# 61.15779861007096
# periodic
# 62.7919792536869
# appearing-clusters 4 improved_UOB
# incremental
# 68.07775579657927
# sudden
# 67.9662213906253
# periodic
# 69.24321836107558
# appearing-clusters 4 WEOB2
# incremental
# 68.02671078649998
# sudden
# 67.91958529920814
# periodic
# 69.1904011170383
# appearing-clusters 4 UOB
# incremental
# 68.20189973558664
# sudden
# 68.1146193405034
# periodic
# 69.32526456459546
# appearing-clusters 4 RebalanceStream
# incremental
# 68.1018484475222
# sudden
# 67.79793602507915
# periodic
# 69.27769641256404
# shapeshift 1 improved_OOB
# incremental
# 65.77237424856544
# sudden
# 65.74375707413343
# periodic
# 65.85906213310452
# shapeshift 1 WEOB1
# incremental
# 65.88912076504445
# sudden
# 65.93146952346504
# periodic
# 66.0686387322356
# shapeshift 1 CSMOTE
# incremental
# 63.459174687001926
# sudden
# 63.43493209263637
# periodic
# 64.2728703202492
# shapeshift 1 OOB
# incremental
# 65.95827393698009
# sudden
# 65.97054761576831
# periodic
# 66.05612013096717
# shapeshift 1 ESOS_ELM
# incremental
# 60.99257688457885
# sudden
# 61.0106258887959
# periodic
# 60.579556639668944
# shapeshift 1 improved_UOB
# incremental
# 64.44748913003704
# sudden
# 64.52425586423182
# periodic
# 64.69194943426051
# shapeshift 1 WEOB2
# incremental
# 64.26703208451609
# sudden
# 64.04578675263683
# periodic
# 64.41579302275025
# shapeshift 1 UOB
# incremental
# 64.57753186338832
# sudden
# 64.41281422634857
# periodic
# 64.69741680212407
# shapeshift 1 RebalanceStream
# incremental
# 55.060305920497704
# sudden
# 55.14708171363427
# periodic
# 55.15921801729756
# shapeshift 2 improved_OOB
# incremental
# 66.16842845165829
# sudden
# 66.16367298730859
# periodic
# 66.21329464476855
# shapeshift 2 WEOB1
# incremental
# 66.06170376507427
# sudden
# 66.03553599906078
# periodic
# 66.17576922323418
# shapeshift 2 CSMOTE
# incremental
# 65.29479509160862
# sudden
# 65.255539328357
# periodic
# 65.18830062261097
# shapeshift 2 OOB
# incremental
# 66.36079747987114
# sudden
# 66.37523810268681
# periodic
# 66.4960853574364
# shapeshift 2 ESOS_ELM
# incremental
# 61.13364919932428
# sudden
# 60.92489407562628
# periodic
# 60.454476379509
# shapeshift 2 improved_UOB
# incremental
# 65.32419598657751
# sudden
# 65.26381752236534
# periodic
# 65.4372472406096
# shapeshift 2 WEOB2
# incremental
# 65.0561989443249
# sudden
# 64.95289865957014
# periodic
# 65.26441176480168
# shapeshift 2 UOB
# incremental
# 65.06637844022376
# sudden
# 65.02471079618752
# periodic
# 65.25579353204316
# shapeshift 2 RebalanceStream
# incremental
# 61.35881929066918
# sudden
# 61.34363971606935
# periodic
# 61.68613924009511
# shapeshift 3 improved_OOB
# incremental
# 66.3200902904487
# sudden
# 66.30073048316208
# periodic
# 66.29730191596435
# shapeshift 3 WEOB1
# incremental
# 66.16926787293656
# sudden
# 66.15584418825551
# periodic
# 66.15456688799864
# shapeshift 3 CSMOTE
# incremental
# 65.5759228611939
# sudden
# 65.56451021539363
# periodic
# 65.50166257818759
# shapeshift 3 OOB
# incremental
# 66.36939313071977
# sudden
# 66.35996620771462
# periodic
# 66.2496339192404
# shapeshift 3 ESOS_ELM
# incremental
# 61.09427307670683
# sudden
# 60.98885752253691
# periodic
# 60.36971420794599
# shapeshift 3 improved_UOB
# incremental
# 65.7731618108742
# sudden
# 65.74440197024026
# periodic
# 65.6801620688219
# shapeshift 3 WEOB2
# incremental
# 65.57492866696506
# sudden
# 65.68043224762849
# periodic
# 65.54690724990998
# shapeshift 3 UOB
# incremental
# 65.50466139707211
# sudden
# 65.43564837579187
# periodic
# 65.34982267585237
# shapeshift 3 RebalanceStream
# incremental
# 64.56946321898457
# sudden
# 64.68186621603627
# periodic
# 64.87350269524818
# shapeshift 4 improved_OOB
# incremental
# 66.24187435309014
# sudden
# 66.13839787180554
# periodic
# 66.25657999156341
# shapeshift 4 WEOB1
# incremental
# 66.15403203597508
# sudden
# 66.0887843920921
# periodic
# 66.1493595355654
# shapeshift 4 CSMOTE
# incremental
# 65.48258907483778
# sudden
# 65.37228044275369
# periodic
# 65.48619171882288
# shapeshift 4 OOB
# incremental
# 65.99683191760161
# sudden
# 65.95708884176311
# periodic
# 65.92813919003493
# shapeshift 4 ESOS_ELM
# incremental
# 60.88436608643519
# sudden
# 60.830388655735874
# periodic
# 60.32018097068294
# shapeshift 4 improved_UOB
# incremental
# 65.8407553412072
# sudden
# 65.82926017415514
# periodic
# 65.75981805052831
# shapeshift 4 WEOB2
# incremental
# 65.5948010892192
# sudden
# 65.59113134758528
# periodic
# 65.53540617860202
# shapeshift 4 UOB
# incremental
# 65.99683191760161
# sudden
# 65.95708884176311
# periodic
# 65.92813919003493
# shapeshift 4 RebalanceStream
# incremental
# 65.69416378641867
# sudden
# 65.5206388818976
# periodic
# 65.81251548094772
# minority-share 1 improved_OOB
# incremental
# 66.188071566388
# sudden
# 66.42866921762786
# periodic
# 58.64992955731562
# minority-share 1 WEOB1
# incremental
# 66.50401568290758
# sudden
# 66.61504026123023
# periodic
# 58.759568879258026
# minority-share 1 CSMOTE
# incremental
# 62.87985510988765
# sudden
# 64.59410930238302
# periodic
# 56.925570291702215
# minority-share 1 OOB
# incremental
# 66.30257015968888
# sudden
# 66.52283782105232
# periodic
# 58.704736251827185
# minority-share 1 ESOS_ELM
# incremental
# 60.995662413680506
# sudden
# 60.82546109427233
# periodic
# 54.64711865062198
# minority-share 1 improved_UOB
# incremental
# 64.92602867982232
# sudden
# 64.90201323902997
# periodic
# 57.676288496695314
# minority-share 1 WEOB2
# incremental
# 64.62870231029162
# sudden
# 64.53170550395251
# periodic
# 57.62809840139223
# minority-share 1 UOB
# incremental
# 64.92733849695172
# sudden
# 64.84498407104499
# periodic
# 57.62628321675403
# minority-share 1 RebalanceStream
# incremental
# 51.58958922078405
# sudden
# 55.165443585640205
# periodic
# 50.22614077880404
# minority-share 2 improved_OOB
# incremental
# 66.28638362073136
# sudden
# 66.68399325678861
# periodic
# 58.7521017771468
# minority-share 2 WEOB1
# incremental
# 66.4748405813825
# sudden
# 66.60759419048858
# periodic
# 58.728302496099765
# minority-share 2 CSMOTE
# incremental
# 64.75173081436037
# sudden
# 66.24624314101632
# periodic
# 57.87323958157955
# minority-share 2 OOB
# incremental
# 66.47256034546771
# sudden
# 66.87528207677953
# periodic
# 58.93427265865726
# minority-share 2 ESOS_ELM
# incremental
# 60.9252672898855
# sudden
# 60.908943321196865
# periodic
# 54.644057010068686
# minority-share 2 improved_UOB
# incremental
# 65.84390957787102
# sudden
# 65.83135087569484
# periodic
# 58.13923489265502
# minority-share 2 WEOB2
# incremental
# 65.58649308061953
# sudden
# 65.56690948902835
# periodic
# 57.96493679909632
# minority-share 2 UOB
# incremental
# 65.60706127085824
# sudden
# 65.55998610588736
# periodic
# 57.95838247773033
# minority-share 2 RebalanceStream
# incremental
# 55.44776415708897
# sudden
# 61.367237461811214
# periodic
# 54.19322338510729
# minority-share 3 improved_OOB
# incremental
# 66.23548413266056
# sudden
# 66.85873413411957
# periodic
# 58.903306035249116
# minority-share 3 WEOB1
# incremental
# 66.65742924970675
# sudden
# 66.73432077315724
# periodic
# 58.84139657467286
# minority-share 3 CSMOTE
# incremental
# 65.96159780048994
# sudden
# 66.52558362522265
# periodic
# 58.3001817076737
# minority-share 3 OOB
# incremental
# 66.36099657678724
# sudden
# 66.84851957791042
# periodic
# 58.77584916087975
# minority-share 3 ESOS_ELM
# incremental
# 60.97757794971322
# sudden
# 60.99002934235176
# periodic
# 54.61085304528351
# minority-share 3 improved_UOB
# incremental
# 66.40150984651765
# sudden
# 66.37142842449433
# periodic
# 58.55483650438849
# minority-share 3 WEOB2
# incremental
# 66.11435703613395
# sudden
# 66.0836771025063
# periodic
# 58.338285066658514
# minority-share 3 UOB
# incremental
# 66.02210007591313
# sudden
# 65.94069538554561
# periodic
# 58.21752070557218
# minority-share 3 RebalanceStream
# incremental
# 62.261433105471006
# sudden
# 65.07026895779009
# periodic
# 56.36696712033129
# minority-share 4 improved_OOB
# incremental
# 66.31139439061016
# sudden
# 66.74752374943276
# periodic
# 58.628077734693
# minority-share 4 WEOB1
# incremental
# 66.60419812277279
# sudden
# 66.6883262778804
# periodic
# 58.76135648950335
# minority-share 4 CSMOTE
# incremental
# 66.07749913957267
# sudden
# 66.65735141663717
# periodic
# 58.35332408915493
# minority-share 4 OOB
# incremental
# 66.05236806797606
# sudden
# 66.60778934230697
# periodic
# 58.62214167296545
# minority-share 4 ESOS_ELM
# incremental
# 60.914903700848456
# sudden
# 60.80851613544379
# periodic
# 54.54543276402865
# minority-share 4 improved_UOB
# incremental
# 66.42913793350206
# sudden
# 66.37114619788451
# periodic
# 58.54067921337777
# minority-share 4 WEOB2
# incremental
# 66.09685490408174
# sudden
# 66.03988676346913
# periodic
# 58.30259743758275
# minority-share 4 UOB
# incremental
# 66.0467808597173
# sudden
# 66.60778934230697
# periodic
# 58.59290097606887
# minority-share 4 RebalanceStream
# incremental
# 63.590830319459506
# sudden
# 66.1503913027684
# periodic
# 57.368968287876555
# splitting-clusters 1 improved_OOB
# incremental
# 66.94667140901967
# sudden
# 66.93844590173991
# periodic
# 68.05606463812117
# splitting-clusters 1 WEOB1
# incremental
# 67.38850294645154
# sudden
# 66.99417724560747
# periodic
# 68.24602863262655
# splitting-clusters 1 CSMOTE
# incremental
# 64.61928388830397
# sudden
# 64.87284410133911
# periodic
# 67.19511313361478
# splitting-clusters 1 OOB
# incremental
# 67.34258315694845
# sudden
# 67.25797311567877
# periodic
# 68.19374214203927
# splitting-clusters 1 ESOS_ELM
# incremental
# 61.58717467612119
# sudden
# 60.80263792667139
# periodic
# 62.7210109451353
# splitting-clusters 1 improved_UOB
# incremental
# 67.18574436093404
# sudden
# 66.34449650701434
# periodic
# 68.16024301169269
# splitting-clusters 1 WEOB2
# incremental
# 66.74538455304977
# sudden
# 66.03227789368123
# periodic
# 68.15373813517003
# splitting-clusters 1 UOB
# incremental
# 66.95352815860348
# sudden
# 65.57606866808034
# periodic
# 68.0819587882481
# splitting-clusters 1 RebalanceStream
# incremental
# 61.079343186302104
# sudden
# 61.93873334543523
# periodic
# 63.775406626998766
# splitting-clusters 2 improved_OOB
# incremental
# 67.65791001244267
# sudden
# 67.62529714779919
# periodic
# 68.39659167894038
# splitting-clusters 2 WEOB1
# incremental
# 67.75038294067805
# sudden
# 67.5767919373171
# periodic
# 68.42040117240809
# splitting-clusters 2 CSMOTE
# incremental
# 66.51838315572385
# sudden
# 66.06921266060208
# periodic
# 67.83682028248082
# splitting-clusters 2 OOB
# incremental
# 67.73887352274754
# sudden
# 67.75545250655355
# periodic
# 68.46076811030704
# splitting-clusters 2 ESOS_ELM
# incremental
# 61.53954787897153
# sudden
# 60.91013968643773
# periodic
# 62.73800764635574
# splitting-clusters 2 improved_UOB
# incremental
# 67.58026616130576
# sudden
# 67.26637093687755
# periodic
# 68.18408692045702
# splitting-clusters 2 WEOB2
# incremental
# 67.37025310028969
# sudden
# 66.71698913601924
# periodic
# 68.22905782040422
# splitting-clusters 2 UOB
# incremental
# 67.59401720811573
# sudden
# 67.08056564239043
# periodic
# 68.21356212902461
# splitting-clusters 2 RebalanceStream
# incremental
# 65.02142028399581
# sudden
# 65.47279626028585
# periodic
# 66.76452305165206
# splitting-clusters 3 improved_OOB
# incremental
# 67.89781312042227
# sudden
# 67.66525271047398
# periodic
# 68.52381463055244
# splitting-clusters 3 WEOB1
# incremental
# 67.88491763669381
# sudden
# 67.64759361423796
# periodic
# 68.5065340366622
# splitting-clusters 3 CSMOTE
# incremental
# 67.2667206567378
# sudden
# 67.1948058372158
# periodic
# 68.11298691906327
# splitting-clusters 3 OOB
# incremental
# 67.61023609250012
# sudden
# 67.52664594297973
# periodic
# 68.26101422058396
# splitting-clusters 3 ESOS_ELM
# incremental
# 61.4608296696814
# sudden
# 61.17129867639967
# periodic
# 62.687780956715415
# splitting-clusters 3 improved_UOB
# incremental
# 67.73086057859915
# sudden
# 67.45071232472421
# periodic
# 68.34226046560278
# splitting-clusters 3 WEOB2
# incremental
# 67.60500274353231
# sudden
# 67.39927502908904
# periodic
# 68.36068292708255
# splitting-clusters 3 UOB
# incremental
# 67.00806070102952
# sudden
# 67.0845847891895
# periodic
# 68.10491681904396
# splitting-clusters 3 RebalanceStream
# incremental
# 66.85224709189
# sudden
# 66.8562733729668
# periodic
# 67.82088020219429
# splitting-clusters 4 improved_OOB
# incremental
# 67.817888321582
# sudden
# 67.75684130654824
# periodic
# 68.46795048954547
# splitting-clusters 4 WEOB1
# incremental
# 67.81373817109895
# sudden
# 67.76011276164687
# periodic
# 68.5538924848305
# splitting-clusters 4 CSMOTE
# incremental
# 67.28560628260252
# sudden
# 67.39962662809447
# periodic
# 68.3620128180601
# splitting-clusters 4 OOB
# incremental
# 67.71367342751896
# sudden
# 67.69696517419074
# periodic
# 68.44181526007594
# splitting-clusters 4 ESOS_ELM
# incremental
# 61.53844941973186
# sudden
# 60.952961069674735
# periodic
# 62.795797834009285
# splitting-clusters 4 improved_UOB
# incremental
# 67.75667268891902
# sudden
# 67.66819228920507
# periodic
# 68.48139277118466
# splitting-clusters 4 WEOB2
# incremental
# 67.69622834180811
# sudden
# 67.51577907570585
# periodic
# 68.44129158407256
# splitting-clusters 4 UOB
# incremental
# 67.07518569061924
# sudden
# 67.55469146576505
# periodic
# 68.33822770703236
# splitting-clusters 4 RebalanceStream
# incremental
# 67.5003932081784
# sudden
# 67.481067282169
# periodic
# 68.30898705066282
# clusters-movement 1 improved_OOB
# incremental
# 65.30459578535665
# sudden
# 64.25761620768102
# periodic
# 64.8029160482239
# clusters-movement 1 WEOB1
# incremental
# 65.35525393448094
# sudden
# 64.27623703536428
# periodic
# 65.19868780664021
# clusters-movement 1 CSMOTE
# incremental
# 59.40571963544638
# sudden
# 58.174361494256836
# periodic
# 63.073260027097184
# clusters-movement 1 OOB
# incremental
# 65.59220484415326
# sudden
# 65.04064489143953
# periodic
# 65.48615140690637
# clusters-movement 1 ESOS_ELM
# incremental
# 61.191206974869104
# sudden
# 58.68037519720785
# periodic
# 60.58572641332512
# clusters-movement 1 improved_UOB
# incremental
# 63.03429045447668
# sudden
# 61.30193617748174
# periodic
# 63.4364314692019
# clusters-movement 1 WEOB2
# incremental
# 61.75582024773771
# sudden
# 60.62147393678924
# periodic
# 63.46446923024151
# clusters-movement 1 UOB
# incremental
# 63.010162645357454
# sudden
# 60.03352435116402
# periodic
# 63.127654902892154
# clusters-movement 1 RebalanceStream
# incremental
# 54.937654098128405
# sudden
# 53.81195076866595
# periodic
# 51.9320609321163
# clusters-movement 2 improved_OOB
# incremental
# 65.92623724041486
# sudden
# 66.00169702318317
# periodic
# 65.60645384590802
# clusters-movement 2 WEOB1
# incremental
# 65.99018556080827
# sudden
# 65.89036014028821
# periodic
# 65.44919906930878
# clusters-movement 2 CSMOTE
# incremental
# 61.619796352869876
# sudden
# 60.37487859543431
# periodic
# 64.6884063764649
# clusters-movement 2 OOB
# incremental
# 66.21371285083492
# sudden
# 66.26180647836158
# periodic
# 65.97321147446856
# clusters-movement 2 ESOS_ELM
# incremental
# 61.11245907755425
# sudden
# 59.71995661646141
# periodic
# 60.39933498731948
# clusters-movement 2 improved_UOB
# incremental
# 65.10052049869321
# sudden
# 64.40251378848518
# periodic
# 64.09582494941887
# clusters-movement 2 WEOB2
# incremental
# 62.99276775296494
# sudden
# 61.342511385300135
# periodic
# 64.38109288460602
# clusters-movement 2 UOB
# incremental
# 64.45947381885802
# sudden
# 62.993763422338894
# periodic
# 63.85644970924064
# clusters-movement 2 RebalanceStream
# incremental
# 60.45860467880092
# sudden
# 60.20400623937193
# periodic
# 58.971191523832466
# clusters-movement 3 improved_OOB
# incremental
# 66.28185919744797
# sudden
# 65.92402987027319
# periodic
# 65.91999648206378
# clusters-movement 3 WEOB1
# incremental
# 66.07333419011283
# sudden
# 65.82471679164078
# periodic
# 65.68791115754938
# clusters-movement 3 CSMOTE
# incremental
# 62.31040255303692
# sudden
# 61.848498658173376
# periodic
# 65.31587185621807
# clusters-movement 3 OOB
# incremental
# 66.38445494595094
# sudden
# 66.14355318218716
# periodic
# 66.12671640216578
# clusters-movement 3 ESOS_ELM
# incremental
# 59.392164040015246
# sudden
# 59.81844691130611
# periodic
# 60.54451826815961
# clusters-movement 3 improved_UOB
# incremental
# 65.2492813521769
# sudden
# 65.25447314443934
# periodic
# 65.00676123056803
# clusters-movement 3 WEOB2
# incremental
# 64.01199732431795
# sudden
# 61.655531553884074
# periodic
# 64.8814686052042
# clusters-movement 3 UOB
# incremental
# 64.57000591439609
# sudden
# 62.83653642622058
# periodic
# 64.57199954474022
# clusters-movement 3 RebalanceStream
# incremental
# 63.60723197783985
# sudden
# 60.61201689589242
# periodic
# 63.254365972762386
# clusters-movement 4 improved_OOB
# incremental
# 66.07261703861889
# sudden
# 66.09418392277396
# periodic
# 65.79215363938303
# clusters-movement 4 WEOB1
# incremental
# 65.9934573253386
# sudden
# 65.9799839419359
# periodic
# 65.6640427297417
# clusters-movement 4 CSMOTE
# incremental
# 63.129462555182066
# sudden
# 62.37225384241435
# periodic
# 65.3382469497258
# clusters-movement 4 OOB
# incremental
# 65.93174382432349
# sudden
# 65.99030474521213
# periodic
# 65.62421710969724
# clusters-movement 4 ESOS_ELM
# incremental
# 60.81769083487295
# sudden
# 60.681113400128496
# periodic
# 60.50100577714893
# clusters-movement 4 improved_UOB
# incremental
# 65.42974429591388
# sudden
# 65.52751422707027
# periodic
# 65.05620818000685
# clusters-movement 4 WEOB2
# incremental
# 63.89960630851702
# sudden
# 61.293739110688385
# periodic
# 64.79627428502594
# clusters-movement 4 UOB
# incremental
# 65.26931847452785
# sudden
# 64.45862898468769
# periodic
# 65.05815146827834
# clusters-movement 4 RebalanceStream
# incremental
# 64.84708573333214
# sudden
# 64.44805888186711
# periodic
# 64.66204364744786
# borderline 1 improved_OOB
# incremental
# 66.847202599312
# sudden
# 66.7371981673601
# periodic
# 67.68065452912569
# borderline 1 WEOB1
# incremental
# 66.74309515761338
# sudden
# 66.58722641194825
# periodic
# 67.33932056599771
# borderline 1 CSMOTE
# incremental
# 64.28817632295443
# sudden
# 64.3168129697493
# periodic
# 64.90923335909471
# borderline 1 OOB
# incremental
# 66.93702414438027
# sudden
# 66.72945412892884
# periodic
# 67.68553626475418
# borderline 1 ESOS_ELM
# incremental
# 61.212910607231606
# sudden
# 60.99629458684187
# periodic
# 61.64668842393941
# borderline 1 improved_UOB
# incremental
# 64.95916471219553
# sudden
# 64.8551728716378
# periodic
# 65.448472082645
# borderline 1 WEOB2
# incremental
# 64.5694756472432
# sudden
# 64.37573556290548
# periodic
# 64.96844508134407
# borderline 1 UOB
# incremental
# 64.92109942520224
# sudden
# 64.69877786162274
# periodic
# 65.36371993937021
# borderline 1 RebalanceStream
# incremental
# 55.881637978764346
# sudden
# 55.824304494576054
# periodic
# 56.80034261627641
# borderline 2 improved_OOB
# incremental
# 66.97388860992497
# sudden
# 66.74843885475897
# periodic
# 67.66911560298209
# borderline 2 WEOB1
# incremental
# 66.84311894120626
# sudden
# 66.57498580279488
# periodic
# 67.40855922876207
# borderline 2 CSMOTE
# incremental
# 66.21710349450953
# sudden
# 65.76091314388883
# periodic
# 66.67871231956539
# borderline 2 OOB
# incremental
# 67.05407576819422
# sudden
# 66.82441599158133
# periodic
# 67.69508747131796
# borderline 2 ESOS_ELM
# incremental
# 61.23541196531236
# sudden
# 61.13332923186861
# periodic
# 61.69523107464141
# borderline 2 improved_UOB
# incremental
# 66.1010471845253
# sudden
# 65.72147965034586
# periodic
# 66.51183925961934
# borderline 2 WEOB2
# incremental
# 65.71129424284871
# sudden
# 65.45634520841057
# periodic
# 66.20870706346889
# borderline 2 UOB
# incremental
# 65.73576216959353
# sudden
# 65.4860037742454
# periodic
# 66.28054483658232
# borderline 2 RebalanceStream
# incremental
# 62.68051778322464
# sudden
# 62.211696028775954
# periodic
# 64.39349594434228
# borderline 3 improved_OOB
# incremental
# 67.08089872496136
# sudden
# 66.85176223718153
# periodic
# 67.73073460112502
# borderline 3 WEOB1
# incremental
# 66.91353533892756
# sudden
# 66.67427505396071
# periodic
# 67.54226415321286
# borderline 3 CSMOTE
# incremental
# 66.08753158140475
# sudden
# 66.04715585412897
# periodic
# 66.90894155194563
# borderline 3 OOB
# incremental
# 66.93204728730737
# sudden
# 66.77022149578542
# periodic
# 67.55836773143452
# borderline 3 ESOS_ELM
# incremental
# 61.1299097131601
# sudden
# 61.04819563738423
# periodic
# 61.46114938577226
# borderline 3 improved_UOB
# incremental
# 66.5577953362255
# sudden
# 66.29670617245085
# periodic
# 67.1615064844622
# borderline 3 WEOB2
# incremental
# 66.30002435566186
# sudden
# 66.11297286436022
# periodic
# 66.76678658019321
# borderline 3 UOB
# incremental
# 66.13374524353112
# sudden
# 65.85087499807324
# periodic
# 66.73809563792659
# borderline 3 RebalanceStream
# incremental
# 65.9433863048459
# sudden
# 65.7252183806061
# periodic
# 66.85261202142142
# borderline 4 improved_OOB
# incremental
# 66.96619672876419
# sudden
# 66.7518750882026
# periodic
# 67.64371803619191
# borderline 4 WEOB1
# incremental
# 66.87937056325055
# sudden
# 66.66522479078358
# periodic
# 67.56493731599843
# borderline 4 CSMOTE
# incremental
# 66.53648153822976
# sudden
# 66.48757824750751
# periodic
# 66.96853929065489
# borderline 4 OOB
# incremental
# 66.9273135130542
# sudden
# 66.6883339652369
# periodic
# 67.58382276865701
# borderline 4 ESOS_ELM
# incremental
# 61.147387212928535
# sudden
# 61.10772456362382
# periodic
# 61.564477555396955
# borderline 4 improved_UOB
# incremental
# 66.5363417163035
# sudden
# 66.33879531205858
# periodic
# 67.20156939447801
# borderline 4 WEOB2
# incremental
# 66.29335226262536
# sudden
# 66.0539686078456
# periodic
# 66.8679444713357
# borderline 4 UOB
# incremental
# 66.9273135130542
# sudden
# 66.6883339652369
# periodic
# 67.58382276865701
# borderline 4 RebalanceStream
# incremental
# 66.48740086761347
# sudden
# 66.39020165554214
# periodic
# 67.28840043143023

# %%
final_dict
# Out:
# {'sea_P(y)': {1: {'sudden': {'improved_OOB': 70.35194043770869,
#     'WEOB1': 70.3467839263607,
#     'OOB': 70.32735479606795,
#     'ESOS_ELM': 65.32599718707182,
#     'improved_UOB': 70.28360889906938,
#     'WEOB2': 70.21106346302977,
#     'UOB': 70.32735479606795,
#     'CSMOTE': 70.22543513635313,
#     'RebalanceStream': 68.75269709510368},
#    'incremental': {'improved_OOB': 70.37893250807234,
#     'WEOB1': 70.35681895951737,
#     'OOB': 70.33583328899387,
#     'ESOS_ELM': 65.53153617761798,
#     'improved_UOB': 70.30404622699567,
#     'WEOB2': 70.24594742649154,
#     'UOB': 70.33583328899387,
#     'CSMOTE': 70.2150639171223,
#     'RebalanceStream': 70.22553149698658}},
#   3: {'incremental': {'improved_OOB': 64.66726516871196,
#     'WEOB1': 64.68776455295958,
#     'OOB': 64.62508213593722,
#     'ESOS_ELM': 61.141349756833336,
#     'improved_UOB': 64.58282225155952,
#     'WEOB2': 64.40379927342454,
#     'UOB': 64.59499764956168,
#     'CSMOTE': 63.49084195782807,
#     'RebalanceStream': 64.2862219055536},
#    'sudden': {'improved_OOB': 64.6368984646941,
#     'WEOB1': 64.66508664177272,
#     'OOB': 64.61829871533901,
#     'ESOS_ELM': 61.03015938952633,
#     'improved_UOB': 64.59578900783663,
#     'WEOB2': 64.352506765577,
#     'UOB': 64.58449071397526,
#     'CSMOTE': 64.29709589700165,
#     'RebalanceStream': 64.27453271025215}},
#   2: {'sudden': {'improved_OOB': 64.63206987274586,
#     'WEOB1': 64.66098248466639,
#     'OOB': 64.63253655479865,
#     'ESOS_ELM': 60.97845897001802,
#     'improved_UOB': 64.57966721824491,
#     'WEOB2': 64.36556981717865,
#     'UOB': 64.58845694398596,
#     'CSMOTE': 64.0546331285078,
#     'RebalanceStream': 63.101123460073076},
#    'incremental': {'improved_OOB': 64.65866731487436,
#     'WEOB1': 64.68082277827105,
#     'OOB': 64.62944415175681,
#     'ESOS_ELM': 61.12691659804703,
#     'improved_UOB': 64.57212479222073,
#     'WEOB2': 64.36496512857023,
#     'UOB': 64.5698342623623,
#     'CSMOTE': 62.49109125835164,
#     'RebalanceStream': 64.30799002610239}},
#   4: {'incremental': {'improved_OOB': 64.65351408472245,
#     'WEOB1': 64.68236628796919,
#     'OOB': 64.60089044393153,
#     'ESOS_ELM': 61.13721489626764,
#     'improved_UOB': 64.60630170720034,
#     'WEOB2': 64.40907044473684,
#     'UOB': 64.56720159702652,
#     'CSMOTE': 64.1254178323287,
#     'RebalanceStream': 64.28043722909976},
#    'sudden': {'improved_OOB': 64.63466517954751,
#     'WEOB1': 64.66388563446131,
#     'OOB': 64.58533110460186,
#     'ESOS_ELM': 61.00305220595396,
#     'improved_UOB': 64.5830067841266,
#     'WEOB2': 64.37238846420993,
#     'UOB': 64.57589343841664,
#     'CSMOTE': 64.1251676874541,
#     'RebalanceStream': 64.26171181870824}}},
#  'sea_P(y_x)': {1: {'sudden': {'improved_OOB': 63.54889262155267,
#     'WEOB1': 63.37459605872808,
#     'OOB': 63.867360482744026,
#     'ESOS_ELM': 60.087345383046,
#     'improved_UOB': 61.98413367823448,
#     'WEOB2': 61.43358522896673,
#     'UOB': 62.014441313778164,
#     'CSMOTE': 61.0480321300498,
#     'RebalanceStream': 55.95967503866681},
#    'incremental': {'improved_OOB': 63.390590062854,
#     'WEOB1': 63.33871261093236,
#     'OOB': 63.65189038348458,
#     'ESOS_ELM': 60.09462192222558,
#     'improved_UOB': 62.149007062642475,
#     'WEOB2': 61.71113312324068,
#     'UOB': 62.308710119952345,
#     'CSMOTE': 60.92249385958485,
#     'RebalanceStream': 56.159043481072956}},
#   3: {'incremental': {'improved_OOB': 64.03796350701904,
#     'WEOB1': 63.9545374247282,
#     'OOB': 64.17477256120152,
#     'ESOS_ELM': 60.32608516237677,
#     'improved_UOB': 63.52655165470942,
#     'WEOB2': 62.30077330893486,
#     'UOB': 63.28667129814139,
#     'CSMOTE': 63.44295615171192,
#     'RebalanceStream': 62.47627871677944},
#    'sudden': {'improved_OOB': 64.00416372956147,
#     'WEOB1': 63.883551415548574,
#     'OOB': 64.21475160664808,
#     'ESOS_ELM': 60.19562462799426,
#     'improved_UOB': 63.38994338332768,
#     'WEOB2': 61.957002688330746,
#     'UOB': 63.146542419006764,
#     'CSMOTE': 63.53477261763591,
#     'RebalanceStream': 62.47396701187141}},
#   2: {'sudden': {'improved_OOB': 64.00450705155751,
#     'WEOB1': 63.877742299695434,
#     'OOB': 64.14914692160153,
#     'ESOS_ELM': 60.066733519181675,
#     'improved_UOB': 63.13420838441581,
#     'WEOB2': 61.81625156771819,
#     'UOB': 62.88944886569484,
#     'CSMOTE': 62.79959442303971,
#     'RebalanceStream': 58.43655576279688},
#    'incremental': {'improved_OOB': 64.03737124640068,
#     'WEOB1': 63.914591785923236,
#     'OOB': 64.3060751062001,
#     'ESOS_ELM': 60.29045976089765,
#     'improved_UOB': 63.20921075154521,
#     'WEOB2': 62.31004521301975,
#     'UOB': 62.92722233121181,
#     'CSMOTE': 62.40054618743922,
#     'RebalanceStream': 58.78554154673176}},
#   4: {'incremental': {'improved_OOB': 64.01392742057723,
#     'WEOB1': 63.988546774525844,
#     'OOB': 64.18460768291088,
#     'ESOS_ELM': 60.34515626608832,
#     'improved_UOB': 63.82714337195652,
#     'WEOB2': 62.001761451191626,
#     'UOB': 63.6514760206343,
#     'CSMOTE': 63.61304295977421,
#     'RebalanceStream': 63.42356618296925},
#    'sudden': {'improved_OOB': 63.989133666975114,
#     'WEOB1': 63.94152232214269,
#     'OOB': 64.28308252666588,
#     'ESOS_ELM': 60.306060585840896,
#     'improved_UOB': 63.74049345398871,
#     'WEOB2': 61.484281175874266,
#     'UOB': 63.784296119017334,
#     'CSMOTE': 63.81197066930391,
#     'RebalanceStream': 63.546736978380544}}},
#  'sea_P(x_y)': {1: {'sudden': {'improved_OOB': 64.45155987458746,
#     'WEOB1': 64.68626334012706,
#     'OOB': 64.56978108288153,
#     'ESOS_ELM': 61.17870686868997,
#     'improved_UOB': 63.537858214903814,
#     'WEOB2': 62.71346502021631,
#     'UOB': 63.33519686335281,
#     'CSMOTE': 62.54255515856006,
#     'RebalanceStream': 57.508796859533426},
#    'incremental': {'improved_OOB': 64.41401701932139,
#     'WEOB1': 64.68236842135505,
#     'OOB': 64.68070462727323,
#     'ESOS_ELM': 61.45679708218891,
#     'improved_UOB': 63.74403062156599,
#     'WEOB2': 63.6130501428493,
#     'UOB': 63.72434516509005,
#     'CSMOTE': 62.28720019815322,
#     'RebalanceStream': 57.790783202371394}},
#   3: {'incremental': {'improved_OOB': 64.71079857294083,
#     'WEOB1': 64.65806689172474,
#     'OOB': 64.80928150092318,
#     'ESOS_ELM': 61.49896285151325,
#     'improved_UOB': 64.30281372587513,
#     'WEOB2': 63.71503297744657,
#     'UOB': 64.01204890021805,
#     'CSMOTE': 64.50274140467221,
#     'RebalanceStream': 63.85550375169752},
#    'sudden': {'improved_OOB': 64.6638295350649,
#     'WEOB1': 64.56850053163973,
#     'OOB': 64.8868622852044,
#     'ESOS_ELM': 60.76874872277531,
#     'improved_UOB': 64.23081546300716,
#     'WEOB2': 64.06906775730633,
#     'UOB': 64.07453232982297,
#     'CSMOTE': 64.49828746885689,
#     'RebalanceStream': 62.899939323163856}},
#   2: {'sudden': {'improved_OOB': 64.606502871951,
#     'WEOB1': 64.61681737091695,
#     'OOB': 64.8856315059793,
#     'ESOS_ELM': 60.68363373907598,
#     'improved_UOB': 64.27879645359462,
#     'WEOB2': 63.64490766416949,
#     'UOB': 64.1256793023388,
#     'CSMOTE': 62.704027200919754,
#     'RebalanceStream': 62.35238653429199},
#    'incremental': {'improved_OOB': 64.72670304805885,
#     'WEOB1': 64.738541451972,
#     'OOB': 64.8543771487874,
#     'ESOS_ELM': 61.47018221357642,
#     'improved_UOB': 64.22207887171643,
#     'WEOB2': 63.606985100612896,
#     'UOB': 64.05433996049575,
#     'CSMOTE': 63.365476406111426,
#     'RebalanceStream': 63.248278358091305}},
#   4: {'incremental': {'improved_OOB': 64.50834949836045,
#     'WEOB1': 64.45210375327176,
#     'OOB': 64.61270090855828,
#     'ESOS_ELM': 61.35815104385284,
#     'improved_UOB': 64.28569471423812,
#     'WEOB2': 63.31820549499165,
#     'UOB': 63.741756811259926,
#     'CSMOTE': 64.4630724709406,
#     'RebalanceStream': 64.26318972283403},
#    'sudden': {'improved_OOB': 64.53613840787742,
#     'WEOB1': 64.48800681213663,
#     'OOB': 64.87327849749587,
#     'ESOS_ELM': 60.64606312660002,
#     'improved_UOB': 64.275923607541,
#     'WEOB2': 64.02276092279774,
#     'UOB': 63.96318752088323,
#     'CSMOTE': 64.48747065871729,
#     'RebalanceStream': 64.08815821555008}}},
#  'sine_P(y)': {4: {'incremental': {'improved_OOB': 70.40739719825709,
#     'WEOB1': 70.40139315245825,
#     'OOB': 70.35740360068534,
#     'ESOS_ELM': 65.66472448896522,
#     'improved_UOB': 70.3401675434582,
#     'WEOB2': 70.32583325260615,
#     'UOB': 70.35740360068534,
#     'CSMOTE': 70.23195682581878,
#     'RebalanceStream': 70.21797504600305},
#    'sudden': {'improved_OOB': 70.38608293976185,
#     'WEOB1': 70.38552894288361,
#     'OOB': 70.34231360008266,
#     'ESOS_ELM': 65.46640787428781,
#     'improved_UOB': 70.32622991752399,
#     'WEOB2': 70.30346378625703,
#     'UOB': 70.34231360008266,
#     'CSMOTE': 70.22444345535584,
#     'RebalanceStream': 70.21240411262262}},
#   3: {'sudden': {'improved_OOB': 70.38338266813015,
#     'WEOB1': 70.36151901756821,
#     'OOB': 70.26861419065791,
#     'ESOS_ELM': 65.42750282007185,
#     'improved_UOB': 70.22524195395758,
#     'WEOB2': 70.17325246240259,
#     'UOB': 70.26861419065791,
#     'CSMOTE': 70.0928403052749,
#     'RebalanceStream': 69.6024341017642},
#    'incremental': {'improved_OOB': 70.38872265964355,
#     'WEOB1': 70.37432714762694,
#     'OOB': 70.28889425035447,
#     'ESOS_ELM': 65.5965815522156,
#     'improved_UOB': 70.2409756946971,
#     'WEOB2': 70.18765409468187,
#     'UOB': 70.28889425035447,
#     'CSMOTE': 70.26799428987394,
#     'RebalanceStream': 70.12040141881099}},
#   1: {'sudden': {'improved_OOB': 70.14380498495623,
#     'WEOB1': 70.17449584809401,
#     'OOB': 70.10988785593635,
#     'ESOS_ELM': 65.10610815713855,
#     'improved_UOB': 69.79024367902143,
#     'WEOB2': 69.83506268354269,
#     'UOB': 69.69341403818115,
#     'CSMOTE': 68.74831623941091,
#     'RebalanceStream': 67.74605147035535},
#    'incremental': {'improved_OOB': 70.18442086728555,
#     'WEOB1': 70.21376481982637,
#     'OOB': 70.14057977126849,
#     'ESOS_ELM': 65.39259454903186,
#     'improved_UOB': 69.87343906701253,
#     'WEOB2': 69.88675660509111,
#     'UOB': 69.82625100436822,
#     'CSMOTE': 69.00886987889722,
#     'RebalanceStream': 68.46468116646568}},
#   2: {'incremental': {'improved_OOB': 70.35071972023249,
#     'WEOB1': 70.32899195614696,
#     'OOB': 70.36901144719772,
#     'ESOS_ELM': 65.5323445268153,
#     'improved_UOB': 70.1151874545044,
#     'WEOB2': 70.03297150779474,
#     'UOB': 70.07760967468087,
#     'CSMOTE': 69.78482182092344,
#     'RebalanceStream': 69.06255289708803},
#    'sudden': {'improved_OOB': 70.3397625621727,
#     'WEOB1': 70.32683808191896,
#     'OOB': 70.36621982572902,
#     'ESOS_ELM': 65.31448389058772,
#     'improved_UOB': 70.11266879272235,
#     'WEOB2': 70.02291155408605,
#     'UOB': 70.07535874366587,
#     'CSMOTE': 69.4841854494205,
#     'RebalanceStream': 69.06114205350137}}},
#  'sine_P(y_x)': {4: {'incremental': {'improved_OOB': 68.59553342150991,
#     'WEOB1': 68.61008602231355,
#     'OOB': 68.53587496909363,
#     'ESOS_ELM': 64.10077588248326,
#     'improved_UOB': 68.50161256117687,
#     'WEOB2': 58.4916038710238,
#     'UOB': 68.2027188094709,
#     'CSMOTE': 68.0480317920366,
#     'RebalanceStream': 68.16975250631046},
#    'sudden': {'improved_OOB': 69.93298490994212,
#     'WEOB1': 69.92375018538732,
#     'OOB': 69.7587131831034,
#     'ESOS_ELM': 62.855831216530646,
#     'improved_UOB': 69.68243483004635,
#     'WEOB2': 64.08284118159713,
#     'UOB': 69.7587131831034,
#     'CSMOTE': 69.24814481438966,
#     'RebalanceStream': 69.74737480690206}},
#   3: {'sudden': {'improved_OOB': 69.9036260684112,
#     'WEOB1': 69.82091456066723,
#     'OOB': 69.90702219902799,
#     'ESOS_ELM': 63.58178709448771,
#     'improved_UOB': 69.58078842405612,
#     'WEOB2': 63.34833617151967,
#     'UOB': 69.41037993845052,
#     'CSMOTE': 68.89597778197347,
#     'RebalanceStream': 69.4442038657794},
#    'incremental': {'improved_OOB': 68.66002663400113,
#     'WEOB1': 68.6199183437869,
#     'OOB': 68.53084374916634,
#     'ESOS_ELM': 63.534196586140375,
#     'improved_UOB': 68.3604121130867,
#     'WEOB2': 59.146351889172266,
#     'UOB': 68.12843679302229,
#     'CSMOTE': 67.60391396198045,
#     'RebalanceStream': 67.95151698660496}},
#   1: {'sudden': {'improved_OOB': 69.57487656219105,
#     'WEOB1': 69.62849768942536,
#     'OOB': 69.59299009228428,
#     'ESOS_ELM': 64.24466290437579,
#     'improved_UOB': 67.62426876846123,
#     'WEOB2': 57.07454087884595,
#     'UOB': 66.54521874119715,
#     'CSMOTE': 65.64973992242585,
#     'RebalanceStream': 67.58244906998064},
#    'incremental': {'improved_OOB': 68.13716292034697,
#     'WEOB1': 68.20133878552824,
#     'OOB': 68.21585163721019,
#     'ESOS_ELM': 64.08582388223773,
#     'improved_UOB': 66.64112656951508,
#     'WEOB2': 54.083256010429444,
#     'UOB': 66.25668354688892,
#     'CSMOTE': 64.83150986568225,
#     'RebalanceStream': 64.10740900618967}},
#   2: {'incremental': {'improved_OOB': 68.54082055289254,
#     'WEOB1': 68.49456310186943,
#     'OOB': 68.62873412712284,
#     'ESOS_ELM': 63.716500587552616,
#     'improved_UOB': 68.03459630239777,
#     'WEOB2': 56.01097016423587,
#     'UOB': 68.02761961941715,
#     'CSMOTE': 66.82025334521606,
#     'RebalanceStream': 66.08837000088349},
#    'sudden': {'improved_OOB': 69.83214516369438,
#     'WEOB1': 69.81130274339355,
#     'OOB': 69.97478795188472,
#     'ESOS_ELM': 63.84361399275416,
#     'improved_UOB': 68.86077814415466,
#     'WEOB2': 56.32467009808211,
#     'UOB': 68.6127836548033,
#     'CSMOTE': 68.03537526110287,
#     'RebalanceStream': 68.81015520641344}}},
#  'sine_P(x_y)': {4: {'incremental': {'improved_OOB': 70.41003315224181,
#     'WEOB1': 70.38886759385375,
#     'OOB': 70.39859358386032,
#     'ESOS_ELM': 65.26195499185161,
#     'improved_UOB': 70.28820910441878,
#     'WEOB2': 70.23177167871985,
#     'UOB': 70.39859358386033,
#     'CSMOTE': 70.22891975070885,
#     'RebalanceStream': 70.08548806693531},
#    'sudden': {'improved_OOB': 70.41624253310604,
#     'WEOB1': 70.39413885326687,
#     'OOB': 70.40915997077278,
#     'ESOS_ELM': 65.44535669600874,
#     'improved_UOB': 70.29929327034867,
#     'WEOB2': 70.27750967966463,
#     'UOB': 70.40915997077278,
#     'CSMOTE': 70.2417241956787,
#     'RebalanceStream': 70.13839299046957}},
#   3: {'sudden': {'improved_OOB': 70.37207705623985,
#     'WEOB1': 70.38846608195345,
#     'OOB': 70.40098411320177,
#     'ESOS_ELM': 65.4649617398985,
#     'improved_UOB': 70.25645339459155,
#     'WEOB2': 70.21835240141368,
#     'UOB': 70.1590560991533,
#     'CSMOTE': 70.2107693712301,
#     'RebalanceStream': 70.03901882173543},
#    'incremental': {'improved_OOB': 70.35460750850152,
#     'WEOB1': 70.38943141390959,
#     'OOB': 70.39545430725352,
#     'ESOS_ELM': 65.35274467207688,
#     'improved_UOB': 70.2477136421746,
#     'WEOB2': 70.20205984049622,
#     'UOB': 70.13434259538573,
#     'CSMOTE': 70.22274824208098,
#     'RebalanceStream': 69.84061038655162}},
#   1: {'sudden': {'improved_OOB': 70.08604996032076,
#     'WEOB1': 70.19339333895172,
#     'OOB': 70.0861117253787,
#     'ESOS_ELM': 64.88354031726814,
#     'improved_UOB': 70.00861462694209,
#     'WEOB2': 69.8195909666778,
#     'UOB': 69.90378843317458,
#     'CSMOTE': 68.58806653752461,
#     'RebalanceStream': 69.06053046757015},
#    'incremental': {'improved_OOB': 70.10139768812886,
#     'WEOB1': 70.20790253404968,
#     'OOB': 70.1255444367439,
#     'ESOS_ELM': 65.1596372159435,
#     'improved_UOB': 70.06545681233055,
#     'WEOB2': 69.85395266097191,
#     'UOB': 69.95996926435326,
#     'CSMOTE': 68.59060246320038,
#     'RebalanceStream': 69.10225534592428}},
#   2: {'incremental': {'improved_OOB': 70.35273505966595,
#     'WEOB1': 70.36847085849608,
#     'OOB': 70.37717215787652,
#     'ESOS_ELM': 65.23807575879212,
#     'improved_UOB': 70.1758369770337,
#     'WEOB2': 70.14729428137979,
#     'UOB': 70.08179688236888,
#     'CSMOTE': 69.70861750472656,
#     'RebalanceStream': 69.84485577272508},
#    'sudden': {'improved_OOB': 70.35665802131493,
#     'WEOB1': 70.38132599725523,
#     'OOB': 70.37649910377755,
#     'ESOS_ELM': 65.3978194149569,
#     'improved_UOB': 70.17438225167874,
#     'WEOB2': 70.15811843092912,
#     'UOB': 70.0861833121186,
#     'CSMOTE': 69.87705728340052,
#     'RebalanceStream': 69.85589122620468}}},
#  'jitter': {1: {'incremental': {'improved_OOB': 65.54680798951384,
#     'WEOB1': 65.97873469088998,
#     'CSMOTE': 63.12492595289929,
#     'OOB': 65.73554498836094,
#     'ESOS_ELM': 60.627986340595996,
#     'improved_UOB': 64.57847189331599,
#     'WEOB2': 64.46000559134856,
#     'UOB': 64.47643472569294,
#     'RebalanceStream': 54.52086864093758},
#    'sudden': {'improved_OOB': 68.06786687849583,
#     'WEOB1': 68.07209927270017,
#     'CSMOTE': 65.08266301936467,
#     'OOB': 68.06853102909277,
#     'ESOS_ELM': 63.500754175705694,
#     'improved_UOB': 66.22416208604338,
#     'WEOB2': 65.2869211400174,
#     'UOB': 65.76155416824315,
#     'RebalanceStream': 60.415199554566605},
#    'periodic': {'improved_OOB': 65.54680798951384,
#     'WEOB1': 65.97873469088998,
#     'CSMOTE': 63.12492595289929,
#     'OOB': 65.73554498836094,
#     'ESOS_ELM': 60.36062744426353,
#     'improved_UOB': 64.57847189331599,
#     'WEOB2': 64.46000559134856,
#     'UOB': 64.47643472569294,
#     'RebalanceStream': 54.52086864093758}},
#   2: {'incremental': {'improved_OOB': 66.37410959483205,
#     'WEOB1': 66.37507539279667,
#     'CSMOTE': 64.31770050017465,
#     'OOB': 66.70391390343386,
#     'ESOS_ELM': 60.81633673335158,
#     'improved_UOB': 64.31285158276901,
#     'WEOB2': 64.93659595523494,
#     'UOB': 64.77258011359257,
#     'RebalanceStream': 61.78640761419864},
#    'sudden': {'improved_OOB': 68.0404451274816,
#     'WEOB1': 67.93069810131354,
#     'CSMOTE': 65.78083132704782,
#     'OOB': 68.2122324659563,
#     'ESOS_ELM': 63.33989806985255,
#     'improved_UOB': 66.8420604459244,
#     'WEOB2': 65.94533355127781,
#     'UOB': 66.54982335991981,
#     'RebalanceStream': 64.9962737106864},
#    'periodic': {'improved_OOB': 66.37410959483205,
#     'WEOB1': 66.37507539279667,
#     'CSMOTE': 64.31770050017465,
#     'OOB': 66.70391390343386,
#     'ESOS_ELM': 60.79290209160746,
#     'improved_UOB': 64.31285158276901,
#     'WEOB2': 64.93659595523494,
#     'UOB': 64.77258011359257,
#     'RebalanceStream': 61.78640761419864}},
#   3: {'incremental': {'improved_OOB': 66.97973718941998,
#     'WEOB1': 66.84248486462924,
#     'CSMOTE': 65.36687476450018,
#     'OOB': 67.01713606972557,
#     'ESOS_ELM': 62.04299437895683,
#     'improved_UOB': 66.42094533493739,
#     'WEOB2': 65.75702455872575,
#     'UOB': 66.05422080217008,
#     'RebalanceStream': 65.26323204117492},
#    'sudden': {'improved_OOB': 68.20218564095885,
#     'WEOB1': 68.0385978866633,
#     'CSMOTE': 66.06723311928644,
#     'OOB': 68.22517175712309,
#     'ESOS_ELM': 63.38714263491804,
#     'improved_UOB': 67.5330278661522,
#     'WEOB2': 66.20077483461891,
#     'UOB': 67.09211430335344,
#     'RebalanceStream': 67.05606296701583},
#    'periodic': {'improved_OOB': 66.97973718941998,
#     'WEOB1': 66.84248486462924,
#     'CSMOTE': 65.36687476450018,
#     'OOB': 67.01713606972557,
#     'ESOS_ELM': 62.044375705102276,
#     'improved_UOB': 66.42094533493739,
#     'WEOB2': 65.75702455872575,
#     'UOB': 66.05422080217008,
#     'RebalanceStream': 65.26323204117492}},
#   4: {'incremental': {'improved_OOB': 66.79947661018363,
#     'WEOB1': 66.61458125777997,
#     'CSMOTE': 65.33087751350595,
#     'OOB': 66.37953059670906,
#     'ESOS_ELM': 61.16129190221403,
#     'improved_UOB': 65.7530821384556,
#     'WEOB2': 65.49539600972443,
#     'UOB': 66.37953059670906,
#     'RebalanceStream': 65.60781885595068},
#    'sudden': {'improved_OOB': 67.98993642631335,
#     'WEOB1': 67.90509473115539,
#     'CSMOTE': 66.20563980068945,
#     'OOB': 67.85814911722971,
#     'ESOS_ELM': 63.34246731382247,
#     'improved_UOB': 67.58651033401733,
#     'WEOB2': 65.92273020822009,
#     'UOB': 67.85814911722971,
#     'RebalanceStream': 67.69902030171428},
#    'periodic': {'improved_OOB': 66.79947661018363,
#     'WEOB1': 66.61458125777997,
#     'CSMOTE': 65.33087751350595,
#     'OOB': 66.37953059670906,
#     'ESOS_ELM': 61.005957347229185,
#     'improved_UOB': 65.7530821384556,
#     'WEOB2': 65.49539600972443,
#     'UOB': 66.37953059670906,
#     'RebalanceStream': 65.60781885595068}}},
#  'disappearing-minority': {1: {'incremental': {'improved_OOB': 58.78151664725533,
#     'WEOB1': 58.773002320121954,
#     'CSMOTE': 57.306728632821624,
#     'OOB': 58.79682227017228,
#     'ESOS_ELM': 54.67837050129757,
#     'improved_UOB': 57.65061089999735,
#     'WEOB2': 57.58652705925501,
#     'UOB': 57.578783103297575,
#     'RebalanceStream': 50.47313637322053},
#    'sudden': {'improved_OOB': 57.81232262070282,
#     'WEOB1': 57.880923766505745,
#     'CSMOTE': 56.771651143525766,
#     'OOB': 57.828094090124104,
#     'ESOS_ELM': 53.84439669040912,
#     'improved_UOB': 56.86483470532373,
#     'WEOB2': 56.82222562969432,
#     'UOB': 56.79376504751548,
#     'RebalanceStream': 50.12478065079558},
#    'periodic': {'improved_OOB': 65.83513709965686,
#     'WEOB1': 66.22386658931262,
#     'CSMOTE': 64.17885236629414,
#     'OOB': 65.91640158383123,
#     'ESOS_ELM': 60.99720382118339,
#     'improved_UOB': 64.90313488635567,
#     'WEOB2': 64.56765979179735,
#     'UOB': 64.83022626232743,
#     'RebalanceStream': 54.940454941477775}},
#   2: {'incremental': {'improved_OOB': 58.7700763062021,
#     'WEOB1': 58.71902979332473,
#     'CSMOTE': 58.19451660464396,
#     'OOB': 58.9424306141972,
#     'ESOS_ELM': 54.669884357137775,
#     'improved_UOB': 58.09461443069567,
#     'WEOB2': 57.921276797504014,
#     'UOB': 57.893131870001206,
#     'RebalanceStream': 55.182160903623455},
#    'sudden': {'improved_OOB': 57.882143916833016,
#     'WEOB1': 57.84409554948536,
#     'CSMOTE': 57.64906367377923,
#     'OOB': 58.05646675282243,
#     'ESOS_ELM': 53.78654990629146,
#     'improved_UOB': 57.22357001640121,
#     'WEOB2': 57.07476583535767,
#     'UOB': 57.05634508811162,
#     'RebalanceStream': 54.773655601765654},
#    'periodic': {'improved_OOB': 66.30230226824486,
#     'WEOB1': 66.4422719669192,
#     'CSMOTE': 65.31749175898786,
#     'OOB': 66.52219729220519,
#     'ESOS_ELM': 61.20413768283985,
#     'improved_UOB': 65.87223227973416,
#     'WEOB2': 65.59014691972516,
#     'UOB': 65.56883666561876,
#     'RebalanceStream': 57.58909876923847}},
#   3: {'incremental': {'improved_OOB': 58.90356356955367,
#     'WEOB1': 58.80482422362955,
#     'CSMOTE': 58.54216320330696,
#     'OOB': 58.914089254395094,
#     'ESOS_ELM': 54.59378162474119,
#     'improved_UOB': 58.48585689190385,
#     'WEOB2': 58.29074306566895,
#     'UOB': 58.144574922356604,
#     'RebalanceStream': 57.25897351243693},
#    'sudden': {'improved_OOB': 58.028668632581095,
#     'WEOB1': 57.92295340949939,
#     'CSMOTE': 57.87261264464621,
#     'OOB': 58.03536320362688,
#     'ESOS_ELM': 53.72390649817845,
#     'improved_UOB': 57.6258455821944,
#     'WEOB2': 57.41443828673319,
#     'UOB': 57.27803449648353,
#     'RebalanceStream': 56.98624218659139},
#    'periodic': {'improved_OOB': 66.47791607188654,
#     'WEOB1': 66.62637052059765,
#     'CSMOTE': 65.93490344305687,
#     'OOB': 66.51452773083028,
#     'ESOS_ELM': 60.89129638584708,
#     'improved_UOB': 66.31675103555384,
#     'WEOB2': 66.05556946380325,
#     'UOB': 65.9324629709075,
#     'RebalanceStream': 62.2304774092785}},
#   4: {'incremental': {'improved_OOB': 58.82774232058453,
#     'WEOB1': 58.7471742942465,
#     'CSMOTE': 58.55749522878828,
#     'OOB': 58.705638182144504,
#     'ESOS_ELM': 54.617271509169164,
#     'improved_UOB': 58.46409984659855,
#     'WEOB2': 58.26274761718129,
#     'UOB': 58.70544995922014,
#     'RebalanceStream': 57.830251887161054},
#    'sudden': {'improved_OOB': 57.93929981631777,
#     'WEOB1': 57.879085250729545,
#     'CSMOTE': 57.95542585415969,
#     'OOB': 57.799172315539316,
#     'ESOS_ELM': 53.71775146717484,
#     'improved_UOB': 57.624427039882825,
#     'WEOB2': 57.39429204385302,
#     'UOB': 57.799172315539316,
#     'RebalanceStream': 57.61366915811235},
#    'periodic': {'improved_OOB': 66.46870563536501,
#     'WEOB1': 66.5907552896251,
#     'CSMOTE': 66.08325583118506,
#     'OOB': 66.36913581609112,
#     'ESOS_ELM': 60.813085609402286,
#     'improved_UOB': 66.35807844463922,
#     'WEOB2': 66.08475904915704,
#     'UOB': 65.81641432051029,
#     'RebalanceStream': 65.22322660208374}}},
#  'appearing-minority': {1: {'incremental': {'improved_OOB': 58.33129744975289,
#     'WEOB1': 58.69942755855087,
#     'CSMOTE': 57.24298772940339,
#     'OOB': 58.56038790208331,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 57.834985240474374,
#     'WEOB2': 57.68109576375863,
#     'UOB': 57.56807907256738,
#     'RebalanceStream': 52.14473376792995},
#    'sudden': {'improved_OOB': 57.800665208436726,
#     'WEOB1': 57.93917875459706,
#     'CSMOTE': 56.695878412411595,
#     'OOB': 58.06924396756134,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 56.83618808981028,
#     'WEOB2': 56.705767719330915,
#     'UOB': 56.54750566225289,
#     'RebalanceStream': 50.91912665419018},
#    'periodic': {'improved_OOB': 51.34712449379024,
#     'WEOB1': 51.49561110463246,
#     'CSMOTE': 51.25877161376354,
#     'OOB': 51.346407912474305,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 51.41654519654744,
#     'WEOB2': 51.41218804291721,
#     'UOB': 50.99921332408148,
#     'RebalanceStream': 51.00510301180678}},
#   2: {'incremental': {'improved_OOB': 59.018056402590936,
#     'WEOB1': 59.20485211387771,
#     'CSMOTE': 58.012176852540094,
#     'OOB': 59.21394062781682,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 58.38310941846644,
#     'WEOB2': 58.16049576315005,
#     'UOB': 58.87613886312355,
#     'RebalanceStream': 54.17645627588662},
#    'sudden': {'improved_OOB': 58.308499506956615,
#     'WEOB1': 58.240219911185214,
#     'CSMOTE': 57.48465930301503,
#     'OOB': 58.31392777998967,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 57.36015396077615,
#     'WEOB2': 57.16129102173254,
#     'UOB': 57.39022431682704,
#     'RebalanceStream': 54.29666423914114},
#    'periodic': {'improved_OOB': 51.54403672443514,
#     'WEOB1': 51.61332072013221,
#     'CSMOTE': 51.39506174332172,
#     'OOB': 51.584672820267336,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 51.43804337155323,
#     'WEOB2': 51.43214105741504,
#     'UOB': 51.3170940770739,
#     'RebalanceStream': 51.20719280303943}},
#   3: {'incremental': {'improved_OOB': 59.32718208757012,
#     'WEOB1': 59.25954592441743,
#     'CSMOTE': 58.68121875358016,
#     'OOB': 59.45120981199917,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 58.86054289687528,
#     'WEOB2': 58.541521175162906,
#     'UOB': 58.783182924230914,
#     'RebalanceStream': 57.591067579067534},
#    'sudden': {'improved_OOB': 58.301767672089476,
#     'WEOB1': 58.246377787078515,
#     'CSMOTE': 58.07087279574686,
#     'OOB': 58.22323389650019,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 57.501965174835085,
#     'WEOB2': 57.29859702412011,
#     'UOB': 57.64462356910322,
#     'RebalanceStream': 56.700917714994674},
#    'periodic': {'improved_OOB': 51.644734694660215,
#     'WEOB1': 51.63318332907416,
#     'CSMOTE': 51.410055785746636,
#     'OOB': 51.6909378873671,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 51.46770515401181,
#     'WEOB2': 51.44541667198483,
#     'UOB': 51.44564346593438,
#     'RebalanceStream': 51.29898172219699}},
#   4: {'incremental': {'improved_OOB': 59.38721383181852,
#     'WEOB1': 59.37383279528198,
#     'CSMOTE': 58.69108632247687,
#     'OOB': 59.484959277631525,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 59.03556799271589,
#     'WEOB2': 58.9156423564635,
#     'UOB': 59.06141505601189,
#     'RebalanceStream': 58.458958664652734},
#    'sudden': {'improved_OOB': 58.29709680589701,
#     'WEOB1': 58.19205046817141,
#     'CSMOTE': 57.92810782669794,
#     'OOB': 58.19263929174459,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 57.54910599263852,
#     'WEOB2': 57.305372460034654,
#     'UOB': 57.67366525661915,
#     'RebalanceStream': 57.35028899627413},
#    'periodic': {'improved_OOB': 51.634303163973506,
#     'WEOB1': 51.596398931809176,
#     'CSMOTE': 51.43871180670586,
#     'OOB': 51.63162283798529,
#     'ESOS_ELM': 50.0,
#     'improved_UOB': 51.50075814020251,
#     'WEOB2': 51.45388630117905,
#     'UOB': 51.43408177164529,
#     'RebalanceStream': 50.98082108613586}}},
#  'appearing-clusters': {1: {'incremental': {'improved_OOB': 67.33603414957295,
#     'WEOB1': 67.59485642265005,
#     'CSMOTE': 66.20156798566568,
#     'OOB': 67.70393741368402,
#     'ESOS_ELM': 61.20989589513723,
#     'improved_UOB': 67.30974533508973,
#     'WEOB2': 66.718707308034,
#     'UOB': 67.21483903082148,
#     'RebalanceStream': 62.835546048824234},
#    'sudden': {'improved_OOB': 67.60891207312916,
#     'WEOB1': 67.64921550885296,
#     'CSMOTE': 66.25003612010536,
#     'OOB': 67.62124742339435,
#     'ESOS_ELM': 61.04654408010614,
#     'improved_UOB': 67.28489872148899,
#     'WEOB2': 66.3217795727713,
#     'UOB': 67.1305999173028,
#     'RebalanceStream': 62.81365013232911},
#    'periodic': {'improved_OOB': 69.28727245343258,
#     'WEOB1': 69.26982103489897,
#     'CSMOTE': 68.59020083204396,
#     'OOB': 69.2913314538531,
#     'ESOS_ELM': 62.69668193839377,
#     'improved_UOB': 68.97842610185774,
#     'WEOB2': 68.83547771741755,
#     'UOB': 68.90789055622326,
#     'RebalanceStream': 64.119624470187}},
#   2: {'incremental': {'improved_OOB': 68.1520114095134,
#     'WEOB1': 68.09826337321104,
#     'CSMOTE': 67.37353711594442,
#     'OOB': 68.23458809986388,
#     'ESOS_ELM': 61.047532598298325,
#     'improved_UOB': 67.76485031532111,
#     'WEOB2': 67.57856425213632,
#     'UOB': 67.64929689907919,
#     'RebalanceStream': 66.52275770165889},
#    'sudden': {'improved_OOB': 68.02839664426776,
#     'WEOB1': 68.04734867748788,
#     'CSMOTE': 67.09079567609663,
#     'OOB': 68.13619106757918,
#     'ESOS_ELM': 61.04266082261056,
#     'improved_UOB': 67.76877273634719,
#     'WEOB2': 67.47670744735606,
#     'UOB': 67.57299967298532,
#     'RebalanceStream': 65.88798286383135},
#    'periodic': {'improved_OOB': 69.41766595464676,
#     'WEOB1': 69.35862148596469,
#     'CSMOTE': 69.23521651871008,
#     'OOB': 69.41447654574617,
#     'ESOS_ELM': 62.726612022904916,
#     'improved_UOB': 69.21677709673169,
#     'WEOB2': 69.06911756883116,
#     'UOB': 69.08532088237384,
#     'RebalanceStream': 68.39868427444947}},
#   3: {'incremental': {'improved_OOB': 68.19920457086933,
#     'WEOB1': 68.16312037932401,
#     'CSMOTE': 67.65166484279504,
#     'OOB': 68.25912254731779,
#     'ESOS_ELM': 61.036502748698275,
#     'improved_UOB': 67.96976578105092,
#     'WEOB2': 67.93658806772218,
#     'UOB': 68.01898610548633,
#     'RebalanceStream': 67.54049461129416},
#    'sudden': {'improved_OOB': 68.05094361263528,
#     'WEOB1': 68.01093296257082,
#     'CSMOTE': 67.5246477480404,
#     'OOB': 68.1101958065544,
#     'ESOS_ELM': 60.883111898634375,
#     'improved_UOB': 67.86287328178966,
#     'WEOB2': 67.74677081325453,
#     'UOB': 67.96181002175273,
#     'RebalanceStream': 67.50894376494622},
#    'periodic': {'improved_OOB': 69.32944832957256,
#     'WEOB1': 69.2793555469469,
#     'CSMOTE': 69.26387183379384,
#     'OOB': 69.3136856494198,
#     'ESOS_ELM': 62.714232447730936,
#     'improved_UOB': 69.18624579703081,
#     'WEOB2': 69.15083560300764,
#     'UOB': 69.3136856494198,
#     'RebalanceStream': 69.07685300562619}},
#   4: {'incremental': {'improved_OOB': 68.19612809841736,
#     'WEOB1': 68.15314889076595,
#     'CSMOTE': 67.84368795034109,
#     'OOB': 68.2901301932044,
#     'ESOS_ELM': 61.34100107529407,
#     'improved_UOB': 68.07775579657927,
#     'WEOB2': 68.02671078649998,
#     'UOB': 68.20189973558664,
#     'RebalanceStream': 68.1018484475222},
#    'sudden': {'improved_OOB': 68.07852387190806,
#     'WEOB1': 68.05149422255177,
#     'CSMOTE': 67.76094289978712,
#     'OOB': 68.20621384763923,
#     'ESOS_ELM': 61.15779861007096,
#     'improved_UOB': 67.9662213906253,
#     'WEOB2': 67.91958529920814,
#     'UOB': 68.1146193405034,
#     'RebalanceStream': 67.79793602507915},
#    'periodic': {'improved_OOB': 69.28361297481624,
#     'WEOB1': 69.26277995236612,
#     'CSMOTE': 69.28706315492846,
#     'OOB': 69.33484819737518,
#     'ESOS_ELM': 62.7919792536869,
#     'improved_UOB': 69.24321836107558,
#     'WEOB2': 69.1904011170383,
#     'UOB': 69.32526456459546,
#     'RebalanceStream': 69.27769641256404}}},
#  'shapeshift': {1: {'incremental': {'improved_OOB': 65.77237424856544,
#     'WEOB1': 65.88912076504445,
#     'CSMOTE': 63.459174687001926,
#     'OOB': 65.95827393698009,
#     'ESOS_ELM': 60.99257688457885,
#     'improved_UOB': 64.44748913003704,
#     'WEOB2': 64.26703208451609,
#     'UOB': 64.57753186338832,
#     'RebalanceStream': 55.060305920497704},
#    'sudden': {'improved_OOB': 65.74375707413343,
#     'WEOB1': 65.93146952346504,
#     'CSMOTE': 63.43493209263637,
#     'OOB': 65.97054761576831,
#     'ESOS_ELM': 61.0106258887959,
#     'improved_UOB': 64.52425586423182,
#     'WEOB2': 64.04578675263683,
#     'UOB': 64.41281422634857,
#     'RebalanceStream': 55.14708171363427},
#    'periodic': {'improved_OOB': 65.85906213310452,
#     'WEOB1': 66.0686387322356,
#     'CSMOTE': 64.2728703202492,
#     'OOB': 66.05612013096717,
#     'ESOS_ELM': 60.579556639668944,
#     'improved_UOB': 64.69194943426051,
#     'WEOB2': 64.41579302275025,
#     'UOB': 64.69741680212407,
#     'RebalanceStream': 55.15921801729756}},
#   2: {'incremental': {'improved_OOB': 66.16842845165829,
#     'WEOB1': 66.06170376507427,
#     'CSMOTE': 65.29479509160862,
#     'OOB': 66.36079747987114,
#     'ESOS_ELM': 61.13364919932428,
#     'improved_UOB': 65.32419598657751,
#     'WEOB2': 65.0561989443249,
#     'UOB': 65.06637844022376,
#     'RebalanceStream': 61.35881929066918},
#    'sudden': {'improved_OOB': 66.16367298730859,
#     'WEOB1': 66.03553599906078,
#     'CSMOTE': 65.255539328357,
#     'OOB': 66.37523810268681,
#     'ESOS_ELM': 60.92489407562628,
#     'improved_UOB': 65.26381752236534,
#     'WEOB2': 64.95289865957014,
#     'UOB': 65.02471079618752,
#     'RebalanceStream': 61.34363971606935},
#    'periodic': {'improved_OOB': 66.21329464476855,
#     'WEOB1': 66.17576922323418,
#     'CSMOTE': 65.18830062261097,
#     'OOB': 66.4960853574364,
#     'ESOS_ELM': 60.454476379509,
#     'improved_UOB': 65.4372472406096,
#     'WEOB2': 65.26441176480168,
#     'UOB': 65.25579353204316,
#     'RebalanceStream': 61.68613924009511}},
#   3: {'incremental': {'improved_OOB': 66.3200902904487,
#     'WEOB1': 66.16926787293656,
#     'CSMOTE': 65.5759228611939,
#     'OOB': 66.36939313071977,
#     'ESOS_ELM': 61.09427307670683,
#     'improved_UOB': 65.7731618108742,
#     'WEOB2': 65.57492866696506,
#     'UOB': 65.50466139707211,
#     'RebalanceStream': 64.56946321898457},
#    'sudden': {'improved_OOB': 66.30073048316208,
#     'WEOB1': 66.15584418825551,
#     'CSMOTE': 65.56451021539363,
#     'OOB': 66.35996620771462,
#     'ESOS_ELM': 60.98885752253691,
#     'improved_UOB': 65.74440197024026,
#     'WEOB2': 65.68043224762849,
#     'UOB': 65.43564837579187,
#     'RebalanceStream': 64.68186621603627},
#    'periodic': {'improved_OOB': 66.29730191596435,
#     'WEOB1': 66.15456688799864,
#     'CSMOTE': 65.50166257818759,
#     'OOB': 66.2496339192404,
#     'ESOS_ELM': 60.36971420794599,
#     'improved_UOB': 65.6801620688219,
#     'WEOB2': 65.54690724990998,
#     'UOB': 65.34982267585237,
#     'RebalanceStream': 64.87350269524818}},
#   4: {'incremental': {'improved_OOB': 66.24187435309014,
#     'WEOB1': 66.15403203597508,
#     'CSMOTE': 65.48258907483778,
#     'OOB': 65.99683191760161,
#     'ESOS_ELM': 60.88436608643519,
#     'improved_UOB': 65.8407553412072,
#     'WEOB2': 65.5948010892192,
#     'UOB': 65.99683191760161,
#     'RebalanceStream': 65.69416378641867},
#    'sudden': {'improved_OOB': 66.13839787180554,
#     'WEOB1': 66.0887843920921,
#     'CSMOTE': 65.37228044275369,
#     'OOB': 65.95708884176311,
#     'ESOS_ELM': 60.830388655735874,
#     'improved_UOB': 65.82926017415514,
#     'WEOB2': 65.59113134758528,
#     'UOB': 65.95708884176311,
#     'RebalanceStream': 65.5206388818976},
#    'periodic': {'improved_OOB': 66.25657999156341,
#     'WEOB1': 66.1493595355654,
#     'CSMOTE': 65.48619171882288,
#     'OOB': 65.92813919003493,
#     'ESOS_ELM': 60.32018097068294,
#     'improved_UOB': 65.75981805052831,
#     'WEOB2': 65.53540617860202,
#     'UOB': 65.92813919003493,
#     'RebalanceStream': 65.81251548094772}}},
#  'minority-share': {1: {'incremental': {'improved_OOB': 66.188071566388,
#     'WEOB1': 66.50401568290758,
#     'CSMOTE': 62.87985510988765,
#     'OOB': 66.30257015968888,
#     'ESOS_ELM': 60.995662413680506,
#     'improved_UOB': 64.92602867982232,
#     'WEOB2': 64.62870231029162,
#     'UOB': 64.92733849695172,
#     'RebalanceStream': 51.58958922078405},
#    'sudden': {'improved_OOB': 66.42866921762786,
#     'WEOB1': 66.61504026123023,
#     'CSMOTE': 64.59410930238302,
#     'OOB': 66.52283782105232,
#     'ESOS_ELM': 60.82546109427233,
#     'improved_UOB': 64.90201323902997,
#     'WEOB2': 64.53170550395251,
#     'UOB': 64.84498407104499,
#     'RebalanceStream': 55.165443585640205},
#    'periodic': {'improved_OOB': 58.64992955731562,
#     'WEOB1': 58.759568879258026,
#     'CSMOTE': 56.925570291702215,
#     'OOB': 58.704736251827185,
#     'ESOS_ELM': 54.64711865062198,
#     'improved_UOB': 57.676288496695314,
#     'WEOB2': 57.62809840139223,
#     'UOB': 57.62628321675403,
#     'RebalanceStream': 50.22614077880404}},
#   2: {'incremental': {'improved_OOB': 66.28638362073136,
#     'WEOB1': 66.4748405813825,
#     'CSMOTE': 64.75173081436037,
#     'OOB': 66.47256034546771,
#     'ESOS_ELM': 60.9252672898855,
#     'improved_UOB': 65.84390957787102,
#     'WEOB2': 65.58649308061953,
#     'UOB': 65.60706127085824,
#     'RebalanceStream': 55.44776415708897},
#    'sudden': {'improved_OOB': 66.68399325678861,
#     'WEOB1': 66.60759419048858,
#     'CSMOTE': 66.24624314101632,
#     'OOB': 66.87528207677953,
#     'ESOS_ELM': 60.908943321196865,
#     'improved_UOB': 65.83135087569484,
#     'WEOB2': 65.56690948902835,
#     'UOB': 65.55998610588736,
#     'RebalanceStream': 61.367237461811214},
#    'periodic': {'improved_OOB': 58.7521017771468,
#     'WEOB1': 58.728302496099765,
#     'CSMOTE': 57.87323958157955,
#     'OOB': 58.93427265865726,
#     'ESOS_ELM': 54.644057010068686,
#     'improved_UOB': 58.13923489265502,
#     'WEOB2': 57.96493679909632,
#     'UOB': 57.95838247773033,
#     'RebalanceStream': 54.19322338510729}},
#   3: {'incremental': {'improved_OOB': 66.23548413266056,
#     'WEOB1': 66.65742924970675,
#     'CSMOTE': 65.96159780048994,
#     'OOB': 66.36099657678724,
#     'ESOS_ELM': 60.97757794971322,
#     'improved_UOB': 66.40150984651765,
#     'WEOB2': 66.11435703613395,
#     'UOB': 66.02210007591313,
#     'RebalanceStream': 62.261433105471006},
#    'sudden': {'improved_OOB': 66.85873413411957,
#     'WEOB1': 66.73432077315724,
#     'CSMOTE': 66.52558362522265,
#     'OOB': 66.84851957791042,
#     'ESOS_ELM': 60.99002934235176,
#     'improved_UOB': 66.37142842449433,
#     'WEOB2': 66.0836771025063,
#     'UOB': 65.94069538554561,
#     'RebalanceStream': 65.07026895779009},
#    'periodic': {'improved_OOB': 58.903306035249116,
#     'WEOB1': 58.84139657467286,
#     'CSMOTE': 58.3001817076737,
#     'OOB': 58.77584916087975,
#     'ESOS_ELM': 54.61085304528351,
#     'improved_UOB': 58.55483650438849,
#     'WEOB2': 58.338285066658514,
#     'UOB': 58.21752070557218,
#     'RebalanceStream': 56.36696712033129}},
#   4: {'incremental': {'improved_OOB': 66.31139439061016,
#     'WEOB1': 66.60419812277279,
#     'CSMOTE': 66.07749913957267,
#     'OOB': 66.05236806797606,
#     'ESOS_ELM': 60.914903700848456,
#     'improved_UOB': 66.42913793350206,
#     'WEOB2': 66.09685490408174,
#     'UOB': 66.0467808597173,
#     'RebalanceStream': 63.590830319459506},
#    'sudden': {'improved_OOB': 66.74752374943276,
#     'WEOB1': 66.6883262778804,
#     'CSMOTE': 66.65735141663717,
#     'OOB': 66.60778934230697,
#     'ESOS_ELM': 60.80851613544379,
#     'improved_UOB': 66.37114619788451,
#     'WEOB2': 66.03988676346913,
#     'UOB': 66.60778934230697,
#     'RebalanceStream': 66.1503913027684},
#    'periodic': {'improved_OOB': 58.628077734693,
#     'WEOB1': 58.76135648950335,
#     'CSMOTE': 58.35332408915493,
#     'OOB': 58.62214167296545,
#     'ESOS_ELM': 54.54543276402865,
#     'improved_UOB': 58.54067921337777,
#     'WEOB2': 58.30259743758275,
#     'UOB': 58.59290097606887,
#     'RebalanceStream': 57.368968287876555}}},
#  'splitting-clusters': {1: {'incremental': {'improved_OOB': 66.94667140901967,
#     'WEOB1': 67.38850294645154,
#     'CSMOTE': 64.61928388830397,
#     'OOB': 67.34258315694845,
#     'ESOS_ELM': 61.58717467612119,
#     'improved_UOB': 67.18574436093404,
#     'WEOB2': 66.74538455304977,
#     'UOB': 66.95352815860348,
#     'RebalanceStream': 61.079343186302104},
#    'sudden': {'improved_OOB': 66.93844590173991,
#     'WEOB1': 66.99417724560747,
#     'CSMOTE': 64.87284410133911,
#     'OOB': 67.25797311567877,
#     'ESOS_ELM': 60.80263792667139,
#     'improved_UOB': 66.34449650701434,
#     'WEOB2': 66.03227789368123,
#     'UOB': 65.57606866808034,
#     'RebalanceStream': 61.93873334543523},
#    'periodic': {'improved_OOB': 68.05606463812117,
#     'WEOB1': 68.24602863262655,
#     'CSMOTE': 67.19511313361478,
#     'OOB': 68.19374214203927,
#     'ESOS_ELM': 62.7210109451353,
#     'improved_UOB': 68.16024301169269,
#     'WEOB2': 68.15373813517003,
#     'UOB': 68.0819587882481,
#     'RebalanceStream': 63.775406626998766}},
#   2: {'incremental': {'improved_OOB': 67.65791001244267,
#     'WEOB1': 67.75038294067805,
#     'CSMOTE': 66.51838315572385,
#     'OOB': 67.73887352274754,
#     'ESOS_ELM': 61.53954787897153,
#     'improved_UOB': 67.58026616130576,
#     'WEOB2': 67.37025310028969,
#     'UOB': 67.59401720811573,
#     'RebalanceStream': 65.02142028399581},
#    'sudden': {'improved_OOB': 67.62529714779919,
#     'WEOB1': 67.5767919373171,
#     'CSMOTE': 66.06921266060208,
#     'OOB': 67.75545250655355,
#     'ESOS_ELM': 60.91013968643773,
#     'improved_UOB': 67.26637093687755,
#     'WEOB2': 66.71698913601924,
#     'UOB': 67.08056564239043,
#     'RebalanceStream': 65.47279626028585},
#    'periodic': {'improved_OOB': 68.39659167894038,
#     'WEOB1': 68.42040117240809,
#     'CSMOTE': 67.83682028248082,
#     'OOB': 68.46076811030704,
#     'ESOS_ELM': 62.73800764635574,
#     'improved_UOB': 68.18408692045702,
#     'WEOB2': 68.22905782040422,
#     'UOB': 68.21356212902461,
#     'RebalanceStream': 66.76452305165206}},
#   3: {'incremental': {'improved_OOB': 67.89781312042227,
#     'WEOB1': 67.88491763669381,
#     'CSMOTE': 67.2667206567378,
#     'OOB': 67.61023609250012,
#     'ESOS_ELM': 61.4608296696814,
#     'improved_UOB': 67.73086057859915,
#     'WEOB2': 67.60500274353231,
#     'UOB': 67.00806070102952,
#     'RebalanceStream': 66.85224709189},
#    'sudden': {'improved_OOB': 67.66525271047398,
#     'WEOB1': 67.64759361423796,
#     'CSMOTE': 67.1948058372158,
#     'OOB': 67.52664594297973,
#     'ESOS_ELM': 61.17129867639967,
#     'improved_UOB': 67.45071232472421,
#     'WEOB2': 67.39927502908904,
#     'UOB': 67.0845847891895,
#     'RebalanceStream': 66.8562733729668},
#    'periodic': {'improved_OOB': 68.52381463055244,
#     'WEOB1': 68.5065340366622,
#     'CSMOTE': 68.11298691906327,
#     'OOB': 68.26101422058396,
#     'ESOS_ELM': 62.687780956715415,
#     'improved_UOB': 68.34226046560278,
#     'WEOB2': 68.36068292708255,
#     'UOB': 68.10491681904396,
#     'RebalanceStream': 67.82088020219429}},
#   4: {'incremental': {'improved_OOB': 67.817888321582,
#     'WEOB1': 67.81373817109895,
#     'CSMOTE': 67.28560628260252,
#     'OOB': 67.71367342751896,
#     'ESOS_ELM': 61.53844941973186,
#     'improved_UOB': 67.75667268891902,
#     'WEOB2': 67.69622834180811,
#     'UOB': 67.07518569061924,
#     'RebalanceStream': 67.5003932081784},
#    'sudden': {'improved_OOB': 67.75684130654824,
#     'WEOB1': 67.76011276164687,
#     'CSMOTE': 67.39962662809447,
#     'OOB': 67.69696517419074,
#     'ESOS_ELM': 60.952961069674735,
#     'improved_UOB': 67.66819228920507,
#     'WEOB2': 67.51577907570585,
#     'UOB': 67.55469146576505,
#     'RebalanceStream': 67.481067282169},
#    'periodic': {'improved_OOB': 68.46795048954547,
#     'WEOB1': 68.5538924848305,
#     'CSMOTE': 68.3620128180601,
#     'OOB': 68.44181526007594,
#     'ESOS_ELM': 62.795797834009285,
#     'improved_UOB': 68.48139277118466,
#     'WEOB2': 68.44129158407256,
#     'UOB': 68.33822770703236,
#     'RebalanceStream': 68.30898705066282}}},
#  'clusters-movement': {1: {'incremental': {'improved_OOB': 65.30459578535665,
#     'WEOB1': 65.35525393448094,
#     'CSMOTE': 59.40571963544638,
#     'OOB': 65.59220484415326,
#     'ESOS_ELM': 61.191206974869104,
#     'improved_UOB': 63.03429045447668,
#     'WEOB2': 61.75582024773771,
#     'UOB': 63.010162645357454,
#     'RebalanceStream': 54.937654098128405},
#    'sudden': {'improved_OOB': 64.25761620768102,
#     'WEOB1': 64.27623703536428,
#     'CSMOTE': 58.174361494256836,
#     'OOB': 65.04064489143953,
#     'ESOS_ELM': 58.68037519720785,
#     'improved_UOB': 61.30193617748174,
#     'WEOB2': 60.62147393678924,
#     'UOB': 60.03352435116402,
#     'RebalanceStream': 53.81195076866595},
#    'periodic': {'improved_OOB': 64.8029160482239,
#     'WEOB1': 65.19868780664021,
#     'CSMOTE': 63.073260027097184,
#     'OOB': 65.48615140690637,
#     'ESOS_ELM': 60.58572641332512,
#     'improved_UOB': 63.4364314692019,
#     'WEOB2': 63.46446923024151,
#     'UOB': 63.127654902892154,
#     'RebalanceStream': 51.9320609321163}},
#   2: {'incremental': {'improved_OOB': 65.92623724041486,
#     'WEOB1': 65.99018556080827,
#     'CSMOTE': 61.619796352869876,
#     'OOB': 66.21371285083492,
#     'ESOS_ELM': 61.11245907755425,
#     'improved_UOB': 65.10052049869321,
#     'WEOB2': 62.99276775296494,
#     'UOB': 64.45947381885802,
#     'RebalanceStream': 60.45860467880092},
#    'sudden': {'improved_OOB': 66.00169702318317,
#     'WEOB1': 65.89036014028821,
#     'CSMOTE': 60.37487859543431,
#     'OOB': 66.26180647836158,
#     'ESOS_ELM': 59.71995661646141,
#     'improved_UOB': 64.40251378848518,
#     'WEOB2': 61.342511385300135,
#     'UOB': 62.993763422338894,
#     'RebalanceStream': 60.20400623937193},
#    'periodic': {'improved_OOB': 65.60645384590802,
#     'WEOB1': 65.44919906930878,
#     'CSMOTE': 64.6884063764649,
#     'OOB': 65.97321147446856,
#     'ESOS_ELM': 60.39933498731948,
#     'improved_UOB': 64.09582494941887,
#     'WEOB2': 64.38109288460602,
#     'UOB': 63.85644970924064,
#     'RebalanceStream': 58.971191523832466}},
#   3: {'incremental': {'improved_OOB': 66.28185919744797,
#     'WEOB1': 66.07333419011283,
#     'CSMOTE': 62.31040255303692,
#     'OOB': 66.38445494595094,
#     'ESOS_ELM': 59.392164040015246,
#     'improved_UOB': 65.2492813521769,
#     'WEOB2': 64.01199732431795,
#     'UOB': 64.57000591439609,
#     'RebalanceStream': 63.60723197783985},
#    'sudden': {'improved_OOB': 65.92402987027319,
#     'WEOB1': 65.82471679164078,
#     'CSMOTE': 61.848498658173376,
#     'OOB': 66.14355318218716,
#     'ESOS_ELM': 59.81844691130611,
#     'improved_UOB': 65.25447314443934,
#     'WEOB2': 61.655531553884074,
#     'UOB': 62.83653642622058,
#     'RebalanceStream': 60.61201689589242},
#    'periodic': {'improved_OOB': 65.91999648206378,
#     'WEOB1': 65.68791115754938,
#     'CSMOTE': 65.31587185621807,
#     'OOB': 66.12671640216578,
#     'ESOS_ELM': 60.54451826815961,
#     'improved_UOB': 65.00676123056803,
#     'WEOB2': 64.8814686052042,
#     'UOB': 64.57199954474022,
#     'RebalanceStream': 63.254365972762386}},
#   4: {'incremental': {'improved_OOB': 66.07261703861889,
#     'WEOB1': 65.9934573253386,
#     'CSMOTE': 63.129462555182066,
#     'OOB': 65.93174382432349,
#     'ESOS_ELM': 60.81769083487295,
#     'improved_UOB': 65.42974429591388,
#     'WEOB2': 63.89960630851702,
#     'UOB': 65.26931847452785,
#     'RebalanceStream': 64.84708573333214},
#    'sudden': {'improved_OOB': 66.09418392277396,
#     'WEOB1': 65.9799839419359,
#     'CSMOTE': 62.37225384241435,
#     'OOB': 65.99030474521213,
#     'ESOS_ELM': 60.681113400128496,
#     'improved_UOB': 65.52751422707027,
#     'WEOB2': 61.293739110688385,
#     'UOB': 64.45862898468769,
#     'RebalanceStream': 64.44805888186711},
#    'periodic': {'improved_OOB': 65.79215363938303,
#     'WEOB1': 65.6640427297417,
#     'CSMOTE': 65.3382469497258,
#     'OOB': 65.62421710969724,
#     'ESOS_ELM': 60.50100577714893,
#     'improved_UOB': 65.05620818000685,
#     'WEOB2': 64.79627428502594,
#     'UOB': 65.05815146827834,
#     'RebalanceStream': 64.66204364744786}}},
#  'borderline': {1: {'incremental': {'improved_OOB': 66.847202599312,
#     'WEOB1': 66.74309515761338,
#     'CSMOTE': 64.28817632295443,
#     'OOB': 66.93702414438027,
#     'ESOS_ELM': 61.212910607231606,
#     'improved_UOB': 64.95916471219553,
#     'WEOB2': 64.5694756472432,
#     'UOB': 64.92109942520224,
#     'RebalanceStream': 55.881637978764346},
#    'sudden': {'improved_OOB': 66.7371981673601,
#     'WEOB1': 66.58722641194825,
#     'CSMOTE': 64.3168129697493,
#     'OOB': 66.72945412892884,
#     'ESOS_ELM': 60.99629458684187,
#     'improved_UOB': 64.8551728716378,
#     'WEOB2': 64.37573556290548,
#     'UOB': 64.69877786162274,
#     'RebalanceStream': 55.824304494576054},
#    'periodic': {'improved_OOB': 67.68065452912569,
#     'WEOB1': 67.33932056599771,
#     'CSMOTE': 64.90923335909471,
#     'OOB': 67.68553626475418,
#     'ESOS_ELM': 61.64668842393941,
#     'improved_UOB': 65.448472082645,
#     'WEOB2': 64.96844508134407,
#     'UOB': 65.36371993937021,
#     'RebalanceStream': 56.80034261627641}},
#   2: {'incremental': {'improved_OOB': 66.97388860992497,
#     'WEOB1': 66.84311894120626,
#     'CSMOTE': 66.21710349450953,
#     'OOB': 67.05407576819422,
#     'ESOS_ELM': 61.23541196531236,
#     'improved_UOB': 66.1010471845253,
#     'WEOB2': 65.71129424284871,
#     'UOB': 65.73576216959353,
#     'RebalanceStream': 62.68051778322464},
#    'sudden': {'improved_OOB': 66.74843885475897,
#     'WEOB1': 66.57498580279488,
#     'CSMOTE': 65.76091314388883,
#     'OOB': 66.82441599158133,
#     'ESOS_ELM': 61.13332923186861,
#     'improved_UOB': 65.72147965034586,
#     'WEOB2': 65.45634520841057,
#     'UOB': 65.4860037742454,
#     'RebalanceStream': 62.211696028775954},
#    'periodic': {'improved_OOB': 67.66911560298209,
#     'WEOB1': 67.40855922876207,
#     'CSMOTE': 66.67871231956539,
#     'OOB': 67.69508747131796,
#     'ESOS_ELM': 61.69523107464141,
#     'improved_UOB': 66.51183925961934,
#     'WEOB2': 66.20870706346889,
#     'UOB': 66.28054483658232,
#     'RebalanceStream': 64.39349594434228}},
#   3: {'incremental': {'improved_OOB': 67.08089872496136,
#     'WEOB1': 66.91353533892756,
#     'CSMOTE': 66.08753158140475,
#     'OOB': 66.93204728730737,
#     'ESOS_ELM': 61.1299097131601,
#     'improved_UOB': 66.5577953362255,
#     'WEOB2': 66.30002435566186,
#     'UOB': 66.13374524353112,
#     'RebalanceStream': 65.9433863048459},
#    'sudden': {'improved_OOB': 66.85176223718153,
#     'WEOB1': 66.67427505396071,
#     'CSMOTE': 66.04715585412897,
#     'OOB': 66.77022149578542,
#     'ESOS_ELM': 61.04819563738423,
#     'improved_UOB': 66.29670617245085,
#     'WEOB2': 66.11297286436022,
#     'UOB': 65.85087499807324,
#     'RebalanceStream': 65.7252183806061},
#    'periodic': {'improved_OOB': 67.73073460112502,
#     'WEOB1': 67.54226415321286,
#     'CSMOTE': 66.90894155194563,
#     'OOB': 67.55836773143452,
#     'ESOS_ELM': 61.46114938577226,
#     'improved_UOB': 67.1615064844622,
#     'WEOB2': 66.76678658019321,
#     'UOB': 66.73809563792659,
#     'RebalanceStream': 66.85261202142142}},
#   4: {'incremental': {'improved_OOB': 66.96619672876419,
#     'WEOB1': 66.87937056325055,
#     'CSMOTE': 66.53648153822976,
#     'OOB': 66.9273135130542,
#     'ESOS_ELM': 61.147387212928535,
#     'improved_UOB': 66.5363417163035,
#     'WEOB2': 66.29335226262536,
#     'UOB': 66.9273135130542,
#     'RebalanceStream': 66.48740086761347},
#    'sudden': {'improved_OOB': 66.7518750882026,
#     'WEOB1': 66.66522479078358,
#     'CSMOTE': 66.48757824750751,
#     'OOB': 66.6883339652369,
#     'ESOS_ELM': 61.10772456362382,
#     'improved_UOB': 66.33879531205858,
#     'WEOB2': 66.0539686078456,
#     'UOB': 66.6883339652369,
#     'RebalanceStream': 66.39020165554214},
#    'periodic': {'improved_OOB': 67.64371803619191,
#     'WEOB1': 67.56493731599843,
#     'CSMOTE': 66.96853929065489,
#     'OOB': 67.58382276865701,
#     'ESOS_ELM': 61.564477555396955,
#     'improved_UOB': 67.20156939447801,
#     'WEOB2': 66.8679444713357,
#     'UOB': 67.58382276865701,
#     'RebalanceStream': 67.28840043143023}}}}

# %%
def stats_of(_dict , not_alg = []):
    values = []
    
    for alg, value in _dict.items():
        use_val = True
        for na in not_alg:
            if na in alg:
                use_val = False
        if use_val:
            values.append(value)
            
    return np.mean(values), np.min(values), np.max(values)

# %%
with open('GMEAN_NOELM_PERC.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    writer.writerow(["drift","unbalance","type","alg","Gmean"])
    for drift, dicts in final_dict.items():
        for unbalance, dtypes in dicts.items():
            for dtype, algs in dtypes.items():
                mean, mi, ma = stats_of(algs, ["ELM"])
                for alg, value in algs.items():
                    if "ELM" in alg:
                        continue
                    print([drift,unbalance,dtype,alg])
                    print(value)
                    writer.writerow([drift,unbalance,dtype,alg,value/mean])
# Out:
# ['sea_P(y)', 1, 'sudden', 'improved_OOB']
# 70.35194043770869
# ['sea_P(y)', 1, 'sudden', 'WEOB1']
# 70.3467839263607
# ['sea_P(y)', 1, 'sudden', 'OOB']
# 70.32735479606795
# ['sea_P(y)', 1, 'sudden', 'improved_UOB']
# 70.28360889906938
# ['sea_P(y)', 1, 'sudden', 'WEOB2']
# 70.21106346302977
# ['sea_P(y)', 1, 'sudden', 'UOB']
# 70.32735479606795
# ['sea_P(y)', 1, 'sudden', 'CSMOTE']
# 70.22543513635313
# ['sea_P(y)', 1, 'sudden', 'RebalanceStream']
# 68.75269709510368
# ['sea_P(y)', 1, 'incremental', 'improved_OOB']
# 70.37893250807234
# ['sea_P(y)', 1, 'incremental', 'WEOB1']
# 70.35681895951737
# ['sea_P(y)', 1, 'incremental', 'OOB']
# 70.33583328899387
# ['sea_P(y)', 1, 'incremental', 'improved_UOB']
# 70.30404622699567
# ['sea_P(y)', 1, 'incremental', 'WEOB2']
# 70.24594742649154
# ['sea_P(y)', 1, 'incremental', 'UOB']
# 70.33583328899387
# ['sea_P(y)', 1, 'incremental', 'CSMOTE']
# 70.2150639171223
# ['sea_P(y)', 1, 'incremental', 'RebalanceStream']
# 70.22553149698658
# ['sea_P(y)', 3, 'incremental', 'improved_OOB']
# 64.66726516871196
# ['sea_P(y)', 3, 'incremental', 'WEOB1']
# 64.68776455295958
# ['sea_P(y)', 3, 'incremental', 'OOB']
# 64.62508213593722
# ['sea_P(y)', 3, 'incremental', 'improved_UOB']
# 64.58282225155952
# ['sea_P(y)', 3, 'incremental', 'WEOB2']
# 64.40379927342454
# ['sea_P(y)', 3, 'incremental', 'UOB']
# 64.59499764956168
# ['sea_P(y)', 3, 'incremental', 'CSMOTE']
# 63.49084195782807
# ['sea_P(y)', 3, 'incremental', 'RebalanceStream']
# 64.2862219055536
# ['sea_P(y)', 3, 'sudden', 'improved_OOB']
# 64.6368984646941
# ['sea_P(y)', 3, 'sudden', 'WEOB1']
# 64.66508664177272
# ['sea_P(y)', 3, 'sudden', 'OOB']
# 64.61829871533901
# ['sea_P(y)', 3, 'sudden', 'improved_UOB']
# 64.59578900783663
# ['sea_P(y)', 3, 'sudden', 'WEOB2']
# 64.352506765577
# ['sea_P(y)', 3, 'sudden', 'UOB']
# 64.58449071397526
# ['sea_P(y)', 3, 'sudden', 'CSMOTE']
# 64.29709589700165
# ['sea_P(y)', 3, 'sudden', 'RebalanceStream']
# 64.27453271025215
# ['sea_P(y)', 2, 'sudden', 'improved_OOB']
# 64.63206987274586
# ['sea_P(y)', 2, 'sudden', 'WEOB1']
# 64.66098248466639
# ['sea_P(y)', 2, 'sudden', 'OOB']
# 64.63253655479865
# ['sea_P(y)', 2, 'sudden', 'improved_UOB']
# 64.57966721824491
# ['sea_P(y)', 2, 'sudden', 'WEOB2']
# 64.36556981717865
# ['sea_P(y)', 2, 'sudden', 'UOB']
# 64.58845694398596
# ['sea_P(y)', 2, 'sudden', 'CSMOTE']
# 64.0546331285078
# ['sea_P(y)', 2, 'sudden', 'RebalanceStream']
# 63.101123460073076
# ['sea_P(y)', 2, 'incremental', 'improved_OOB']
# 64.65866731487436
# ['sea_P(y)', 2, 'incremental', 'WEOB1']
# 64.68082277827105
# ['sea_P(y)', 2, 'incremental', 'OOB']
# 64.62944415175681
# ['sea_P(y)', 2, 'incremental', 'improved_UOB']
# 64.57212479222073
# ['sea_P(y)', 2, 'incremental', 'WEOB2']
# 64.36496512857023
# ['sea_P(y)', 2, 'incremental', 'UOB']
# 64.5698342623623
# ['sea_P(y)', 2, 'incremental', 'CSMOTE']
# 62.49109125835164
# ['sea_P(y)', 2, 'incremental', 'RebalanceStream']
# 64.30799002610239
# ['sea_P(y)', 4, 'incremental', 'improved_OOB']
# 64.65351408472245
# ['sea_P(y)', 4, 'incremental', 'WEOB1']
# 64.68236628796919
# ['sea_P(y)', 4, 'incremental', 'OOB']
# 64.60089044393153
# ['sea_P(y)', 4, 'incremental', 'improved_UOB']
# 64.60630170720034
# ['sea_P(y)', 4, 'incremental', 'WEOB2']
# 64.40907044473684
# ['sea_P(y)', 4, 'incremental', 'UOB']
# 64.56720159702652
# ['sea_P(y)', 4, 'incremental', 'CSMOTE']
# 64.1254178323287
# ['sea_P(y)', 4, 'incremental', 'RebalanceStream']
# 64.28043722909976
# ['sea_P(y)', 4, 'sudden', 'improved_OOB']
# 64.63466517954751
# ['sea_P(y)', 4, 'sudden', 'WEOB1']
# 64.66388563446131
# ['sea_P(y)', 4, 'sudden', 'OOB']
# 64.58533110460186
# ['sea_P(y)', 4, 'sudden', 'improved_UOB']
# 64.5830067841266
# ['sea_P(y)', 4, 'sudden', 'WEOB2']
# 64.37238846420993
# ['sea_P(y)', 4, 'sudden', 'UOB']
# 64.57589343841664
# ['sea_P(y)', 4, 'sudden', 'CSMOTE']
# 64.1251676874541
# ['sea_P(y)', 4, 'sudden', 'RebalanceStream']
# 64.26171181870824
# ['sea_P(y_x)', 1, 'sudden', 'improved_OOB']
# 63.54889262155267
# ['sea_P(y_x)', 1, 'sudden', 'WEOB1']
# 63.37459605872808
# ['sea_P(y_x)', 1, 'sudden', 'OOB']
# 63.867360482744026
# ['sea_P(y_x)', 1, 'sudden', 'improved_UOB']
# 61.98413367823448
# ['sea_P(y_x)', 1, 'sudden', 'WEOB2']
# 61.43358522896673
# ['sea_P(y_x)', 1, 'sudden', 'UOB']
# 62.014441313778164
# ['sea_P(y_x)', 1, 'sudden', 'CSMOTE']
# 61.0480321300498
# ['sea_P(y_x)', 1, 'sudden', 'RebalanceStream']
# 55.95967503866681
# ['sea_P(y_x)', 1, 'incremental', 'improved_OOB']
# 63.390590062854
# ['sea_P(y_x)', 1, 'incremental', 'WEOB1']
# 63.33871261093236
# ['sea_P(y_x)', 1, 'incremental', 'OOB']
# 63.65189038348458
# ['sea_P(y_x)', 1, 'incremental', 'improved_UOB']
# 62.149007062642475
# ['sea_P(y_x)', 1, 'incremental', 'WEOB2']
# 61.71113312324068
# ['sea_P(y_x)', 1, 'incremental', 'UOB']
# 62.308710119952345
# ['sea_P(y_x)', 1, 'incremental', 'CSMOTE']
# 60.92249385958485
# ['sea_P(y_x)', 1, 'incremental', 'RebalanceStream']
# 56.159043481072956
# ['sea_P(y_x)', 3, 'incremental', 'improved_OOB']
# 64.03796350701904
# ['sea_P(y_x)', 3, 'incremental', 'WEOB1']
# 63.9545374247282
# ['sea_P(y_x)', 3, 'incremental', 'OOB']
# 64.17477256120152
# ['sea_P(y_x)', 3, 'incremental', 'improved_UOB']
# 63.52655165470942
# ['sea_P(y_x)', 3, 'incremental', 'WEOB2']
# 62.30077330893486
# ['sea_P(y_x)', 3, 'incremental', 'UOB']
# 63.28667129814139
# ['sea_P(y_x)', 3, 'incremental', 'CSMOTE']
# 63.44295615171192
# ['sea_P(y_x)', 3, 'incremental', 'RebalanceStream']
# 62.47627871677944
# ['sea_P(y_x)', 3, 'sudden', 'improved_OOB']
# 64.00416372956147
# ['sea_P(y_x)', 3, 'sudden', 'WEOB1']
# 63.883551415548574
# ['sea_P(y_x)', 3, 'sudden', 'OOB']
# 64.21475160664808
# ['sea_P(y_x)', 3, 'sudden', 'improved_UOB']
# 63.38994338332768
# ['sea_P(y_x)', 3, 'sudden', 'WEOB2']
# 61.957002688330746
# ['sea_P(y_x)', 3, 'sudden', 'UOB']
# 63.146542419006764
# ['sea_P(y_x)', 3, 'sudden', 'CSMOTE']
# 63.53477261763591
# ['sea_P(y_x)', 3, 'sudden', 'RebalanceStream']
# 62.47396701187141
# ['sea_P(y_x)', 2, 'sudden', 'improved_OOB']
# 64.00450705155751
# ['sea_P(y_x)', 2, 'sudden', 'WEOB1']
# 63.877742299695434
# ['sea_P(y_x)', 2, 'sudden', 'OOB']
# 64.14914692160153
# ['sea_P(y_x)', 2, 'sudden', 'improved_UOB']
# 63.13420838441581
# ['sea_P(y_x)', 2, 'sudden', 'WEOB2']
# 61.81625156771819
# ['sea_P(y_x)', 2, 'sudden', 'UOB']
# 62.88944886569484
# ['sea_P(y_x)', 2, 'sudden', 'CSMOTE']
# 62.79959442303971
# ['sea_P(y_x)', 2, 'sudden', 'RebalanceStream']
# 58.43655576279688
# ['sea_P(y_x)', 2, 'incremental', 'improved_OOB']
# 64.03737124640068
# ['sea_P(y_x)', 2, 'incremental', 'WEOB1']
# 63.914591785923236
# ['sea_P(y_x)', 2, 'incremental', 'OOB']
# 64.3060751062001
# ['sea_P(y_x)', 2, 'incremental', 'improved_UOB']
# 63.20921075154521
# ['sea_P(y_x)', 2, 'incremental', 'WEOB2']
# 62.31004521301975
# ['sea_P(y_x)', 2, 'incremental', 'UOB']
# 62.92722233121181
# ['sea_P(y_x)', 2, 'incremental', 'CSMOTE']
# 62.40054618743922
# ['sea_P(y_x)', 2, 'incremental', 'RebalanceStream']
# 58.78554154673176
# ['sea_P(y_x)', 4, 'incremental', 'improved_OOB']
# 64.01392742057723
# ['sea_P(y_x)', 4, 'incremental', 'WEOB1']
# 63.988546774525844
# ['sea_P(y_x)', 4, 'incremental', 'OOB']
# 64.18460768291088
# ['sea_P(y_x)', 4, 'incremental', 'improved_UOB']
# 63.82714337195652
# ['sea_P(y_x)', 4, 'incremental', 'WEOB2']
# 62.001761451191626
# ['sea_P(y_x)', 4, 'incremental', 'UOB']
# 63.6514760206343
# ['sea_P(y_x)', 4, 'incremental', 'CSMOTE']
# 63.61304295977421
# ['sea_P(y_x)', 4, 'incremental', 'RebalanceStream']
# 63.42356618296925
# ['sea_P(y_x)', 4, 'sudden', 'improved_OOB']
# 63.989133666975114
# ['sea_P(y_x)', 4, 'sudden', 'WEOB1']
# 63.94152232214269
# ['sea_P(y_x)', 4, 'sudden', 'OOB']
# 64.28308252666588
# ['sea_P(y_x)', 4, 'sudden', 'improved_UOB']
# 63.74049345398871
# ['sea_P(y_x)', 4, 'sudden', 'WEOB2']
# 61.484281175874266
# ['sea_P(y_x)', 4, 'sudden', 'UOB']
# 63.784296119017334
# ['sea_P(y_x)', 4, 'sudden', 'CSMOTE']
# 63.81197066930391
# ['sea_P(y_x)', 4, 'sudden', 'RebalanceStream']
# 63.546736978380544
# ['sea_P(x_y)', 1, 'sudden', 'improved_OOB']
# 64.45155987458746
# ['sea_P(x_y)', 1, 'sudden', 'WEOB1']
# 64.68626334012706
# ['sea_P(x_y)', 1, 'sudden', 'OOB']
# 64.56978108288153
# ['sea_P(x_y)', 1, 'sudden', 'improved_UOB']
# 63.537858214903814
# ['sea_P(x_y)', 1, 'sudden', 'WEOB2']
# 62.71346502021631
# ['sea_P(x_y)', 1, 'sudden', 'UOB']
# 63.33519686335281
# ['sea_P(x_y)', 1, 'sudden', 'CSMOTE']
# 62.54255515856006
# ['sea_P(x_y)', 1, 'sudden', 'RebalanceStream']
# 57.508796859533426
# ['sea_P(x_y)', 1, 'incremental', 'improved_OOB']
# 64.41401701932139
# ['sea_P(x_y)', 1, 'incremental', 'WEOB1']
# 64.68236842135505
# ['sea_P(x_y)', 1, 'incremental', 'OOB']
# 64.68070462727323
# ['sea_P(x_y)', 1, 'incremental', 'improved_UOB']
# 63.74403062156599
# ['sea_P(x_y)', 1, 'incremental', 'WEOB2']
# 63.6130501428493
# ['sea_P(x_y)', 1, 'incremental', 'UOB']
# 63.72434516509005
# ['sea_P(x_y)', 1, 'incremental', 'CSMOTE']
# 62.28720019815322
# ['sea_P(x_y)', 1, 'incremental', 'RebalanceStream']
# 57.790783202371394
# ['sea_P(x_y)', 3, 'incremental', 'improved_OOB']
# 64.71079857294083
# ['sea_P(x_y)', 3, 'incremental', 'WEOB1']
# 64.65806689172474
# ['sea_P(x_y)', 3, 'incremental', 'OOB']
# 64.80928150092318
# ['sea_P(x_y)', 3, 'incremental', 'improved_UOB']
# 64.30281372587513
# ['sea_P(x_y)', 3, 'incremental', 'WEOB2']
# 63.71503297744657
# ['sea_P(x_y)', 3, 'incremental', 'UOB']
# 64.01204890021805
# ['sea_P(x_y)', 3, 'incremental', 'CSMOTE']
# 64.50274140467221
# ['sea_P(x_y)', 3, 'incremental', 'RebalanceStream']
# 63.85550375169752
# ['sea_P(x_y)', 3, 'sudden', 'improved_OOB']
# 64.6638295350649
# ['sea_P(x_y)', 3, 'sudden', 'WEOB1']
# 64.56850053163973
# ['sea_P(x_y)', 3, 'sudden', 'OOB']
# 64.8868622852044
# ['sea_P(x_y)', 3, 'sudden', 'improved_UOB']
# 64.23081546300716
# ['sea_P(x_y)', 3, 'sudden', 'WEOB2']
# 64.06906775730633
# ['sea_P(x_y)', 3, 'sudden', 'UOB']
# 64.07453232982297
# ['sea_P(x_y)', 3, 'sudden', 'CSMOTE']
# 64.49828746885689
# ['sea_P(x_y)', 3, 'sudden', 'RebalanceStream']
# 62.899939323163856
# ['sea_P(x_y)', 2, 'sudden', 'improved_OOB']
# 64.606502871951
# ['sea_P(x_y)', 2, 'sudden', 'WEOB1']
# 64.61681737091695
# ['sea_P(x_y)', 2, 'sudden', 'OOB']
# 64.8856315059793
# ['sea_P(x_y)', 2, 'sudden', 'improved_UOB']
# 64.27879645359462
# ['sea_P(x_y)', 2, 'sudden', 'WEOB2']
# 63.64490766416949
# ['sea_P(x_y)', 2, 'sudden', 'UOB']
# 64.1256793023388
# ['sea_P(x_y)', 2, 'sudden', 'CSMOTE']
# 62.704027200919754
# ['sea_P(x_y)', 2, 'sudden', 'RebalanceStream']
# 62.35238653429199
# ['sea_P(x_y)', 2, 'incremental', 'improved_OOB']
# 64.72670304805885
# ['sea_P(x_y)', 2, 'incremental', 'WEOB1']
# 64.738541451972
# ['sea_P(x_y)', 2, 'incremental', 'OOB']
# 64.8543771487874
# ['sea_P(x_y)', 2, 'incremental', 'improved_UOB']
# 64.22207887171643
# ['sea_P(x_y)', 2, 'incremental', 'WEOB2']
# 63.606985100612896
# ['sea_P(x_y)', 2, 'incremental', 'UOB']
# 64.05433996049575
# ['sea_P(x_y)', 2, 'incremental', 'CSMOTE']
# 63.365476406111426
# ['sea_P(x_y)', 2, 'incremental', 'RebalanceStream']
# 63.248278358091305
# ['sea_P(x_y)', 4, 'incremental', 'improved_OOB']
# 64.50834949836045
# ['sea_P(x_y)', 4, 'incremental', 'WEOB1']
# 64.45210375327176
# ['sea_P(x_y)', 4, 'incremental', 'OOB']
# 64.61270090855828
# ['sea_P(x_y)', 4, 'incremental', 'improved_UOB']
# 64.28569471423812
# ['sea_P(x_y)', 4, 'incremental', 'WEOB2']
# 63.31820549499165
# ['sea_P(x_y)', 4, 'incremental', 'UOB']
# 63.741756811259926
# ['sea_P(x_y)', 4, 'incremental', 'CSMOTE']
# 64.4630724709406
# ['sea_P(x_y)', 4, 'incremental', 'RebalanceStream']
# 64.26318972283403
# ['sea_P(x_y)', 4, 'sudden', 'improved_OOB']
# 64.53613840787742
# ['sea_P(x_y)', 4, 'sudden', 'WEOB1']
# 64.48800681213663
# ['sea_P(x_y)', 4, 'sudden', 'OOB']
# 64.87327849749587
# ['sea_P(x_y)', 4, 'sudden', 'improved_UOB']
# 64.275923607541
# ['sea_P(x_y)', 4, 'sudden', 'WEOB2']
# 64.02276092279774
# ['sea_P(x_y)', 4, 'sudden', 'UOB']
# 63.96318752088323
# ['sea_P(x_y)', 4, 'sudden', 'CSMOTE']
# 64.48747065871729
# ['sea_P(x_y)', 4, 'sudden', 'RebalanceStream']
# 64.08815821555008
# ['sine_P(y)', 4, 'incremental', 'improved_OOB']
# 70.40739719825709
# ['sine_P(y)', 4, 'incremental', 'WEOB1']
# 70.40139315245825
# ['sine_P(y)', 4, 'incremental', 'OOB']
# 70.35740360068534
# ['sine_P(y)', 4, 'incremental', 'improved_UOB']
# 70.3401675434582
# ['sine_P(y)', 4, 'incremental', 'WEOB2']
# 70.32583325260615
# ['sine_P(y)', 4, 'incremental', 'UOB']
# 70.35740360068534
# ['sine_P(y)', 4, 'incremental', 'CSMOTE']
# 70.23195682581878
# ['sine_P(y)', 4, 'incremental', 'RebalanceStream']
# 70.21797504600305
# ['sine_P(y)', 4, 'sudden', 'improved_OOB']
# 70.38608293976185
# ['sine_P(y)', 4, 'sudden', 'WEOB1']
# 70.38552894288361
# ['sine_P(y)', 4, 'sudden', 'OOB']
# 70.34231360008266
# ['sine_P(y)', 4, 'sudden', 'improved_UOB']
# 70.32622991752399
# ['sine_P(y)', 4, 'sudden', 'WEOB2']
# 70.30346378625703
# ['sine_P(y)', 4, 'sudden', 'UOB']
# 70.34231360008266
# ['sine_P(y)', 4, 'sudden', 'CSMOTE']
# 70.22444345535584
# ['sine_P(y)', 4, 'sudden', 'RebalanceStream']
# 70.21240411262262
# ['sine_P(y)', 3, 'sudden', 'improved_OOB']
# 70.38338266813015
# ['sine_P(y)', 3, 'sudden', 'WEOB1']
# 70.36151901756821
# ['sine_P(y)', 3, 'sudden', 'OOB']
# 70.26861419065791
# ['sine_P(y)', 3, 'sudden', 'improved_UOB']
# 70.22524195395758
# ['sine_P(y)', 3, 'sudden', 'WEOB2']
# 70.17325246240259
# ['sine_P(y)', 3, 'sudden', 'UOB']
# 70.26861419065791
# ['sine_P(y)', 3, 'sudden', 'CSMOTE']
# 70.0928403052749
# ['sine_P(y)', 3, 'sudden', 'RebalanceStream']
# 69.6024341017642
# ['sine_P(y)', 3, 'incremental', 'improved_OOB']
# 70.38872265964355
# ['sine_P(y)', 3, 'incremental', 'WEOB1']
# 70.37432714762694
# ['sine_P(y)', 3, 'incremental', 'OOB']
# 70.28889425035447
# ['sine_P(y)', 3, 'incremental', 'improved_UOB']
# 70.2409756946971
# ['sine_P(y)', 3, 'incremental', 'WEOB2']
# 70.18765409468187
# ['sine_P(y)', 3, 'incremental', 'UOB']
# 70.28889425035447
# ['sine_P(y)', 3, 'incremental', 'CSMOTE']
# 70.26799428987394
# ['sine_P(y)', 3, 'incremental', 'RebalanceStream']
# 70.12040141881099
# ['sine_P(y)', 1, 'sudden', 'improved_OOB']
# 70.14380498495623
# ['sine_P(y)', 1, 'sudden', 'WEOB1']
# 70.17449584809401
# ['sine_P(y)', 1, 'sudden', 'OOB']
# 70.10988785593635
# ['sine_P(y)', 1, 'sudden', 'improved_UOB']
# 69.79024367902143
# ['sine_P(y)', 1, 'sudden', 'WEOB2']
# 69.83506268354269
# ['sine_P(y)', 1, 'sudden', 'UOB']
# 69.69341403818115
# ['sine_P(y)', 1, 'sudden', 'CSMOTE']
# 68.74831623941091
# ['sine_P(y)', 1, 'sudden', 'RebalanceStream']
# 67.74605147035535
# ['sine_P(y)', 1, 'incremental', 'improved_OOB']
# 70.18442086728555
# ['sine_P(y)', 1, 'incremental', 'WEOB1']
# 70.21376481982637
# ['sine_P(y)', 1, 'incremental', 'OOB']
# 70.14057977126849
# ['sine_P(y)', 1, 'incremental', 'improved_UOB']
# 69.87343906701253
# ['sine_P(y)', 1, 'incremental', 'WEOB2']
# 69.88675660509111
# ['sine_P(y)', 1, 'incremental', 'UOB']
# 69.82625100436822
# ['sine_P(y)', 1, 'incremental', 'CSMOTE']
# 69.00886987889722
# ['sine_P(y)', 1, 'incremental', 'RebalanceStream']
# 68.46468116646568
# ['sine_P(y)', 2, 'incremental', 'improved_OOB']
# 70.35071972023249
# ['sine_P(y)', 2, 'incremental', 'WEOB1']
# 70.32899195614696
# ['sine_P(y)', 2, 'incremental', 'OOB']
# 70.36901144719772
# ['sine_P(y)', 2, 'incremental', 'improved_UOB']
# 70.1151874545044
# ['sine_P(y)', 2, 'incremental', 'WEOB2']
# 70.03297150779474
# ['sine_P(y)', 2, 'incremental', 'UOB']
# 70.07760967468087
# ['sine_P(y)', 2, 'incremental', 'CSMOTE']
# 69.78482182092344
# ['sine_P(y)', 2, 'incremental', 'RebalanceStream']
# 69.06255289708803
# ['sine_P(y)', 2, 'sudden', 'improved_OOB']
# 70.3397625621727
# ['sine_P(y)', 2, 'sudden', 'WEOB1']
# 70.32683808191896
# ['sine_P(y)', 2, 'sudden', 'OOB']
# 70.36621982572902
# ['sine_P(y)', 2, 'sudden', 'improved_UOB']
# 70.11266879272235
# ['sine_P(y)', 2, 'sudden', 'WEOB2']
# 70.02291155408605
# ['sine_P(y)', 2, 'sudden', 'UOB']
# 70.07535874366587
# ['sine_P(y)', 2, 'sudden', 'CSMOTE']
# 69.4841854494205
# ['sine_P(y)', 2, 'sudden', 'RebalanceStream']
# 69.06114205350137
# ['sine_P(y_x)', 4, 'incremental', 'improved_OOB']
# 68.59553342150991
# ['sine_P(y_x)', 4, 'incremental', 'WEOB1']
# 68.61008602231355
# ['sine_P(y_x)', 4, 'incremental', 'OOB']
# 68.53587496909363
# ['sine_P(y_x)', 4, 'incremental', 'improved_UOB']
# 68.50161256117687
# ['sine_P(y_x)', 4, 'incremental', 'WEOB2']
# 58.4916038710238
# ['sine_P(y_x)', 4, 'incremental', 'UOB']
# 68.2027188094709
# ['sine_P(y_x)', 4, 'incremental', 'CSMOTE']
# 68.0480317920366
# ['sine_P(y_x)', 4, 'incremental', 'RebalanceStream']
# 68.16975250631046
# ['sine_P(y_x)', 4, 'sudden', 'improved_OOB']
# 69.93298490994212
# ['sine_P(y_x)', 4, 'sudden', 'WEOB1']
# 69.92375018538732
# ['sine_P(y_x)', 4, 'sudden', 'OOB']
# 69.7587131831034
# ['sine_P(y_x)', 4, 'sudden', 'improved_UOB']
# 69.68243483004635
# ['sine_P(y_x)', 4, 'sudden', 'WEOB2']
# 64.08284118159713
# ['sine_P(y_x)', 4, 'sudden', 'UOB']
# 69.7587131831034
# ['sine_P(y_x)', 4, 'sudden', 'CSMOTE']
# 69.24814481438966
# ['sine_P(y_x)', 4, 'sudden', 'RebalanceStream']
# 69.74737480690206
# ['sine_P(y_x)', 3, 'sudden', 'improved_OOB']
# 69.9036260684112
# ['sine_P(y_x)', 3, 'sudden', 'WEOB1']
# 69.82091456066723
# ['sine_P(y_x)', 3, 'sudden', 'OOB']
# 69.90702219902799
# ['sine_P(y_x)', 3, 'sudden', 'improved_UOB']
# 69.58078842405612
# ['sine_P(y_x)', 3, 'sudden', 'WEOB2']
# 63.34833617151967
# ['sine_P(y_x)', 3, 'sudden', 'UOB']
# 69.41037993845052
# ['sine_P(y_x)', 3, 'sudden', 'CSMOTE']
# 68.89597778197347
# ['sine_P(y_x)', 3, 'sudden', 'RebalanceStream']
# 69.4442038657794
# ['sine_P(y_x)', 3, 'incremental', 'improved_OOB']
# 68.66002663400113
# ['sine_P(y_x)', 3, 'incremental', 'WEOB1']
# 68.6199183437869
# ['sine_P(y_x)', 3, 'incremental', 'OOB']
# 68.53084374916634
# ['sine_P(y_x)', 3, 'incremental', 'improved_UOB']
# 68.3604121130867
# ['sine_P(y_x)', 3, 'incremental', 'WEOB2']
# 59.146351889172266
# ['sine_P(y_x)', 3, 'incremental', 'UOB']
# 68.12843679302229
# ['sine_P(y_x)', 3, 'incremental', 'CSMOTE']
# 67.60391396198045
# ['sine_P(y_x)', 3, 'incremental', 'RebalanceStream']
# 67.95151698660496
# ['sine_P(y_x)', 1, 'sudden', 'improved_OOB']
# 69.57487656219105
# ['sine_P(y_x)', 1, 'sudden', 'WEOB1']
# 69.62849768942536
# ['sine_P(y_x)', 1, 'sudden', 'OOB']
# 69.59299009228428
# ['sine_P(y_x)', 1, 'sudden', 'improved_UOB']
# 67.62426876846123
# ['sine_P(y_x)', 1, 'sudden', 'WEOB2']
# 57.07454087884595
# ['sine_P(y_x)', 1, 'sudden', 'UOB']
# 66.54521874119715
# ['sine_P(y_x)', 1, 'sudden', 'CSMOTE']
# 65.64973992242585
# ['sine_P(y_x)', 1, 'sudden', 'RebalanceStream']
# 67.58244906998064
# ['sine_P(y_x)', 1, 'incremental', 'improved_OOB']
# 68.13716292034697
# ['sine_P(y_x)', 1, 'incremental', 'WEOB1']
# 68.20133878552824
# ['sine_P(y_x)', 1, 'incremental', 'OOB']
# 68.21585163721019
# ['sine_P(y_x)', 1, 'incremental', 'improved_UOB']
# 66.64112656951508
# ['sine_P(y_x)', 1, 'incremental', 'WEOB2']
# 54.083256010429444
# ['sine_P(y_x)', 1, 'incremental', 'UOB']
# 66.25668354688892
# ['sine_P(y_x)', 1, 'incremental', 'CSMOTE']
# 64.83150986568225
# ['sine_P(y_x)', 1, 'incremental', 'RebalanceStream']
# 64.10740900618967
# ['sine_P(y_x)', 2, 'incremental', 'improved_OOB']
# 68.54082055289254
# ['sine_P(y_x)', 2, 'incremental', 'WEOB1']
# 68.49456310186943
# ['sine_P(y_x)', 2, 'incremental', 'OOB']
# 68.62873412712284
# ['sine_P(y_x)', 2, 'incremental', 'improved_UOB']
# 68.03459630239777
# ['sine_P(y_x)', 2, 'incremental', 'WEOB2']
# 56.01097016423587
# ['sine_P(y_x)', 2, 'incremental', 'UOB']
# 68.02761961941715
# ['sine_P(y_x)', 2, 'incremental', 'CSMOTE']
# 66.82025334521606
# ['sine_P(y_x)', 2, 'incremental', 'RebalanceStream']
# 66.08837000088349
# ['sine_P(y_x)', 2, 'sudden', 'improved_OOB']
# 69.83214516369438
# ['sine_P(y_x)', 2, 'sudden', 'WEOB1']
# 69.81130274339355
# ['sine_P(y_x)', 2, 'sudden', 'OOB']
# 69.97478795188472
# ['sine_P(y_x)', 2, 'sudden', 'improved_UOB']
# 68.86077814415466
# ['sine_P(y_x)', 2, 'sudden', 'WEOB2']
# 56.32467009808211
# ['sine_P(y_x)', 2, 'sudden', 'UOB']
# 68.6127836548033
# ['sine_P(y_x)', 2, 'sudden', 'CSMOTE']
# 68.03537526110287
# ['sine_P(y_x)', 2, 'sudden', 'RebalanceStream']
# 68.81015520641344
# ['sine_P(x_y)', 4, 'incremental', 'improved_OOB']
# 70.41003315224181
# ['sine_P(x_y)', 4, 'incremental', 'WEOB1']
# 70.38886759385375
# ['sine_P(x_y)', 4, 'incremental', 'OOB']
# 70.39859358386032
# ['sine_P(x_y)', 4, 'incremental', 'improved_UOB']
# 70.28820910441878
# ['sine_P(x_y)', 4, 'incremental', 'WEOB2']
# 70.23177167871985
# ['sine_P(x_y)', 4, 'incremental', 'UOB']
# 70.39859358386033
# ['sine_P(x_y)', 4, 'incremental', 'CSMOTE']
# 70.22891975070885
# ['sine_P(x_y)', 4, 'incremental', 'RebalanceStream']
# 70.08548806693531
# ['sine_P(x_y)', 4, 'sudden', 'improved_OOB']
# 70.41624253310604
# ['sine_P(x_y)', 4, 'sudden', 'WEOB1']
# 70.39413885326687
# ['sine_P(x_y)', 4, 'sudden', 'OOB']
# 70.40915997077278
# ['sine_P(x_y)', 4, 'sudden', 'improved_UOB']
# 70.29929327034867
# ['sine_P(x_y)', 4, 'sudden', 'WEOB2']
# 70.27750967966463
# ['sine_P(x_y)', 4, 'sudden', 'UOB']
# 70.40915997077278
# ['sine_P(x_y)', 4, 'sudden', 'CSMOTE']
# 70.2417241956787
# ['sine_P(x_y)', 4, 'sudden', 'RebalanceStream']
# 70.13839299046957
# ['sine_P(x_y)', 3, 'sudden', 'improved_OOB']
# 70.37207705623985
# ['sine_P(x_y)', 3, 'sudden', 'WEOB1']
# 70.38846608195345
# ['sine_P(x_y)', 3, 'sudden', 'OOB']
# 70.40098411320177
# ['sine_P(x_y)', 3, 'sudden', 'improved_UOB']
# 70.25645339459155
# ['sine_P(x_y)', 3, 'sudden', 'WEOB2']
# 70.21835240141368
# ['sine_P(x_y)', 3, 'sudden', 'UOB']
# 70.1590560991533
# ['sine_P(x_y)', 3, 'sudden', 'CSMOTE']
# 70.2107693712301
# ['sine_P(x_y)', 3, 'sudden', 'RebalanceStream']
# 70.03901882173543
# ['sine_P(x_y)', 3, 'incremental', 'improved_OOB']
# 70.35460750850152
# ['sine_P(x_y)', 3, 'incremental', 'WEOB1']
# 70.38943141390959
# ['sine_P(x_y)', 3, 'incremental', 'OOB']
# 70.39545430725352
# ['sine_P(x_y)', 3, 'incremental', 'improved_UOB']
# 70.2477136421746
# ['sine_P(x_y)', 3, 'incremental', 'WEOB2']
# 70.20205984049622
# ['sine_P(x_y)', 3, 'incremental', 'UOB']
# 70.13434259538573
# ['sine_P(x_y)', 3, 'incremental', 'CSMOTE']
# 70.22274824208098
# ['sine_P(x_y)', 3, 'incremental', 'RebalanceStream']
# 69.84061038655162
# ['sine_P(x_y)', 1, 'sudden', 'improved_OOB']
# 70.08604996032076
# ['sine_P(x_y)', 1, 'sudden', 'WEOB1']
# 70.19339333895172
# ['sine_P(x_y)', 1, 'sudden', 'OOB']
# 70.0861117253787
# ['sine_P(x_y)', 1, 'sudden', 'improved_UOB']
# 70.00861462694209
# ['sine_P(x_y)', 1, 'sudden', 'WEOB2']
# 69.8195909666778
# ['sine_P(x_y)', 1, 'sudden', 'UOB']
# 69.90378843317458
# ['sine_P(x_y)', 1, 'sudden', 'CSMOTE']
# 68.58806653752461
# ['sine_P(x_y)', 1, 'sudden', 'RebalanceStream']
# 69.06053046757015
# ['sine_P(x_y)', 1, 'incremental', 'improved_OOB']
# 70.10139768812886
# ['sine_P(x_y)', 1, 'incremental', 'WEOB1']
# 70.20790253404968
# ['sine_P(x_y)', 1, 'incremental', 'OOB']
# 70.1255444367439
# ['sine_P(x_y)', 1, 'incremental', 'improved_UOB']
# 70.06545681233055
# ['sine_P(x_y)', 1, 'incremental', 'WEOB2']
# 69.85395266097191
# ['sine_P(x_y)', 1, 'incremental', 'UOB']
# 69.95996926435326
# ['sine_P(x_y)', 1, 'incremental', 'CSMOTE']
# 68.59060246320038
# ['sine_P(x_y)', 1, 'incremental', 'RebalanceStream']
# 69.10225534592428
# ['sine_P(x_y)', 2, 'incremental', 'improved_OOB']
# 70.35273505966595
# ['sine_P(x_y)', 2, 'incremental', 'WEOB1']
# 70.36847085849608
# ['sine_P(x_y)', 2, 'incremental', 'OOB']
# 70.37717215787652
# ['sine_P(x_y)', 2, 'incremental', 'improved_UOB']
# 70.1758369770337
# ['sine_P(x_y)', 2, 'incremental', 'WEOB2']
# 70.14729428137979
# ['sine_P(x_y)', 2, 'incremental', 'UOB']
# 70.08179688236888
# ['sine_P(x_y)', 2, 'incremental', 'CSMOTE']
# 69.70861750472656
# ['sine_P(x_y)', 2, 'incremental', 'RebalanceStream']
# 69.84485577272508
# ['sine_P(x_y)', 2, 'sudden', 'improved_OOB']
# 70.35665802131493
# ['sine_P(x_y)', 2, 'sudden', 'WEOB1']
# 70.38132599725523
# ['sine_P(x_y)', 2, 'sudden', 'OOB']
# 70.37649910377755
# ['sine_P(x_y)', 2, 'sudden', 'improved_UOB']
# 70.17438225167874
# ['sine_P(x_y)', 2, 'sudden', 'WEOB2']
# 70.15811843092912
# ['sine_P(x_y)', 2, 'sudden', 'UOB']
# 70.0861833121186
# ['sine_P(x_y)', 2, 'sudden', 'CSMOTE']
# 69.87705728340052
# ['sine_P(x_y)', 2, 'sudden', 'RebalanceStream']
# 69.85589122620468
# ['jitter', 1, 'incremental', 'improved_OOB']
# 65.54680798951384
# ['jitter', 1, 'incremental', 'WEOB1']
# 65.97873469088998
# ['jitter', 1, 'incremental', 'CSMOTE']
# 63.12492595289929
# ['jitter', 1, 'incremental', 'OOB']
# 65.73554498836094
# ['jitter', 1, 'incremental', 'improved_UOB']
# 64.57847189331599
# ['jitter', 1, 'incremental', 'WEOB2']
# 64.46000559134856
# ['jitter', 1, 'incremental', 'UOB']
# 64.47643472569294
# ['jitter', 1, 'incremental', 'RebalanceStream']
# 54.52086864093758
# ['jitter', 1, 'sudden', 'improved_OOB']
# 68.06786687849583
# ['jitter', 1, 'sudden', 'WEOB1']
# 68.07209927270017
# ['jitter', 1, 'sudden', 'CSMOTE']
# 65.08266301936467
# ['jitter', 1, 'sudden', 'OOB']
# 68.06853102909277
# ['jitter', 1, 'sudden', 'improved_UOB']
# 66.22416208604338
# ['jitter', 1, 'sudden', 'WEOB2']
# 65.2869211400174
# ['jitter', 1, 'sudden', 'UOB']
# 65.76155416824315
# ['jitter', 1, 'sudden', 'RebalanceStream']
# 60.415199554566605
# ['jitter', 1, 'periodic', 'improved_OOB']
# 65.54680798951384
# ['jitter', 1, 'periodic', 'WEOB1']
# 65.97873469088998
# ['jitter', 1, 'periodic', 'CSMOTE']
# 63.12492595289929
# ['jitter', 1, 'periodic', 'OOB']
# 65.73554498836094
# ['jitter', 1, 'periodic', 'improved_UOB']
# 64.57847189331599
# ['jitter', 1, 'periodic', 'WEOB2']
# 64.46000559134856
# ['jitter', 1, 'periodic', 'UOB']
# 64.47643472569294
# ['jitter', 1, 'periodic', 'RebalanceStream']
# 54.52086864093758
# ['jitter', 2, 'incremental', 'improved_OOB']
# 66.37410959483205
# ['jitter', 2, 'incremental', 'WEOB1']
# 66.37507539279667
# ['jitter', 2, 'incremental', 'CSMOTE']
# 64.31770050017465
# ['jitter', 2, 'incremental', 'OOB']
# 66.70391390343386
# ['jitter', 2, 'incremental', 'improved_UOB']
# 64.31285158276901
# ['jitter', 2, 'incremental', 'WEOB2']
# 64.93659595523494
# ['jitter', 2, 'incremental', 'UOB']
# 64.77258011359257
# ['jitter', 2, 'incremental', 'RebalanceStream']
# 61.78640761419864
# ['jitter', 2, 'sudden', 'improved_OOB']
# 68.0404451274816
# ['jitter', 2, 'sudden', 'WEOB1']
# 67.93069810131354
# ['jitter', 2, 'sudden', 'CSMOTE']
# 65.78083132704782
# ['jitter', 2, 'sudden', 'OOB']
# 68.2122324659563
# ['jitter', 2, 'sudden', 'improved_UOB']
# 66.8420604459244
# ['jitter', 2, 'sudden', 'WEOB2']
# 65.94533355127781
# ['jitter', 2, 'sudden', 'UOB']
# 66.54982335991981
# ['jitter', 2, 'sudden', 'RebalanceStream']
# 64.9962737106864
# ['jitter', 2, 'periodic', 'improved_OOB']
# 66.37410959483205
# ['jitter', 2, 'periodic', 'WEOB1']
# 66.37507539279667
# ['jitter', 2, 'periodic', 'CSMOTE']
# 64.31770050017465
# ['jitter', 2, 'periodic', 'OOB']
# 66.70391390343386
# ['jitter', 2, 'periodic', 'improved_UOB']
# 64.31285158276901
# ['jitter', 2, 'periodic', 'WEOB2']
# 64.93659595523494
# ['jitter', 2, 'periodic', 'UOB']
# 64.77258011359257
# ['jitter', 2, 'periodic', 'RebalanceStream']
# 61.78640761419864
# ['jitter', 3, 'incremental', 'improved_OOB']
# 66.97973718941998
# ['jitter', 3, 'incremental', 'WEOB1']
# 66.84248486462924
# ['jitter', 3, 'incremental', 'CSMOTE']
# 65.36687476450018
# ['jitter', 3, 'incremental', 'OOB']
# 67.01713606972557
# ['jitter', 3, 'incremental', 'improved_UOB']
# 66.42094533493739
# ['jitter', 3, 'incremental', 'WEOB2']
# 65.75702455872575
# ['jitter', 3, 'incremental', 'UOB']
# 66.05422080217008
# ['jitter', 3, 'incremental', 'RebalanceStream']
# 65.26323204117492
# ['jitter', 3, 'sudden', 'improved_OOB']
# 68.20218564095885
# ['jitter', 3, 'sudden', 'WEOB1']
# 68.0385978866633
# ['jitter', 3, 'sudden', 'CSMOTE']
# 66.06723311928644
# ['jitter', 3, 'sudden', 'OOB']
# 68.22517175712309
# ['jitter', 3, 'sudden', 'improved_UOB']
# 67.5330278661522
# ['jitter', 3, 'sudden', 'WEOB2']
# 66.20077483461891
# ['jitter', 3, 'sudden', 'UOB']
# 67.09211430335344
# ['jitter', 3, 'sudden', 'RebalanceStream']
# 67.05606296701583
# ['jitter', 3, 'periodic', 'improved_OOB']
# 66.97973718941998
# ['jitter', 3, 'periodic', 'WEOB1']
# 66.84248486462924
# ['jitter', 3, 'periodic', 'CSMOTE']
# 65.36687476450018
# ['jitter', 3, 'periodic', 'OOB']
# 67.01713606972557
# ['jitter', 3, 'periodic', 'improved_UOB']
# 66.42094533493739
# ['jitter', 3, 'periodic', 'WEOB2']
# 65.75702455872575
# ['jitter', 3, 'periodic', 'UOB']
# 66.05422080217008
# ['jitter', 3, 'periodic', 'RebalanceStream']
# 65.26323204117492
# ['jitter', 4, 'incremental', 'improved_OOB']
# 66.79947661018363
# ['jitter', 4, 'incremental', 'WEOB1']
# 66.61458125777997
# ['jitter', 4, 'incremental', 'CSMOTE']
# 65.33087751350595
# ['jitter', 4, 'incremental', 'OOB']
# 66.37953059670906
# ['jitter', 4, 'incremental', 'improved_UOB']
# 65.7530821384556
# ['jitter', 4, 'incremental', 'WEOB2']
# 65.49539600972443
# ['jitter', 4, 'incremental', 'UOB']
# 66.37953059670906
# ['jitter', 4, 'incremental', 'RebalanceStream']
# 65.60781885595068
# ['jitter', 4, 'sudden', 'improved_OOB']
# 67.98993642631335
# ['jitter', 4, 'sudden', 'WEOB1']
# 67.90509473115539
# ['jitter', 4, 'sudden', 'CSMOTE']
# 66.20563980068945
# ['jitter', 4, 'sudden', 'OOB']
# 67.85814911722971
# ['jitter', 4, 'sudden', 'improved_UOB']
# 67.58651033401733
# ['jitter', 4, 'sudden', 'WEOB2']
# 65.92273020822009
# ['jitter', 4, 'sudden', 'UOB']
# 67.85814911722971
# ['jitter', 4, 'sudden', 'RebalanceStream']
# 67.69902030171428
# ['jitter', 4, 'periodic', 'improved_OOB']
# 66.79947661018363
# ['jitter', 4, 'periodic', 'WEOB1']
# 66.61458125777997
# ['jitter', 4, 'periodic', 'CSMOTE']
# 65.33087751350595
# ['jitter', 4, 'periodic', 'OOB']
# 66.37953059670906
# ['jitter', 4, 'periodic', 'improved_UOB']
# 65.7530821384556
# ['jitter', 4, 'periodic', 'WEOB2']
# 65.49539600972443
# ['jitter', 4, 'periodic', 'UOB']
# 66.37953059670906
# ['jitter', 4, 'periodic', 'RebalanceStream']
# 65.60781885595068
# ['disappearing-minority', 1, 'incremental', 'improved_OOB']
# 58.78151664725533
# ['disappearing-minority', 1, 'incremental', 'WEOB1']
# 58.773002320121954
# ['disappearing-minority', 1, 'incremental', 'CSMOTE']
# 57.306728632821624
# ['disappearing-minority', 1, 'incremental', 'OOB']
# 58.79682227017228
# ['disappearing-minority', 1, 'incremental', 'improved_UOB']
# 57.65061089999735
# ['disappearing-minority', 1, 'incremental', 'WEOB2']
# 57.58652705925501
# ['disappearing-minority', 1, 'incremental', 'UOB']
# 57.578783103297575
# ['disappearing-minority', 1, 'incremental', 'RebalanceStream']
# 50.47313637322053
# ['disappearing-minority', 1, 'sudden', 'improved_OOB']
# 57.81232262070282
# ['disappearing-minority', 1, 'sudden', 'WEOB1']
# 57.880923766505745
# ['disappearing-minority', 1, 'sudden', 'CSMOTE']
# 56.771651143525766
# ['disappearing-minority', 1, 'sudden', 'OOB']
# 57.828094090124104
# ['disappearing-minority', 1, 'sudden', 'improved_UOB']
# 56.86483470532373
# ['disappearing-minority', 1, 'sudden', 'WEOB2']
# 56.82222562969432
# ['disappearing-minority', 1, 'sudden', 'UOB']
# 56.79376504751548
# ['disappearing-minority', 1, 'sudden', 'RebalanceStream']
# 50.12478065079558
# ['disappearing-minority', 1, 'periodic', 'improved_OOB']
# 65.83513709965686
# ['disappearing-minority', 1, 'periodic', 'WEOB1']
# 66.22386658931262
# ['disappearing-minority', 1, 'periodic', 'CSMOTE']
# 64.17885236629414
# ['disappearing-minority', 1, 'periodic', 'OOB']
# 65.91640158383123
# ['disappearing-minority', 1, 'periodic', 'improved_UOB']
# 64.90313488635567
# ['disappearing-minority', 1, 'periodic', 'WEOB2']
# 64.56765979179735
# ['disappearing-minority', 1, 'periodic', 'UOB']
# 64.83022626232743
# ['disappearing-minority', 1, 'periodic', 'RebalanceStream']
# 54.940454941477775
# ['disappearing-minority', 2, 'incremental', 'improved_OOB']
# 58.7700763062021
# ['disappearing-minority', 2, 'incremental', 'WEOB1']
# 58.71902979332473
# ['disappearing-minority', 2, 'incremental', 'CSMOTE']
# 58.19451660464396
# ['disappearing-minority', 2, 'incremental', 'OOB']
# 58.9424306141972
# ['disappearing-minority', 2, 'incremental', 'improved_UOB']
# 58.09461443069567
# ['disappearing-minority', 2, 'incremental', 'WEOB2']
# 57.921276797504014
# ['disappearing-minority', 2, 'incremental', 'UOB']
# 57.893131870001206
# ['disappearing-minority', 2, 'incremental', 'RebalanceStream']
# 55.182160903623455
# ['disappearing-minority', 2, 'sudden', 'improved_OOB']
# 57.882143916833016
# ['disappearing-minority', 2, 'sudden', 'WEOB1']
# 57.84409554948536
# ['disappearing-minority', 2, 'sudden', 'CSMOTE']
# 57.64906367377923
# ['disappearing-minority', 2, 'sudden', 'OOB']
# 58.05646675282243
# ['disappearing-minority', 2, 'sudden', 'improved_UOB']
# 57.22357001640121
# ['disappearing-minority', 2, 'sudden', 'WEOB2']
# 57.07476583535767
# ['disappearing-minority', 2, 'sudden', 'UOB']
# 57.05634508811162
# ['disappearing-minority', 2, 'sudden', 'RebalanceStream']
# 54.773655601765654
# ['disappearing-minority', 2, 'periodic', 'improved_OOB']
# 66.30230226824486
# ['disappearing-minority', 2, 'periodic', 'WEOB1']
# 66.4422719669192
# ['disappearing-minority', 2, 'periodic', 'CSMOTE']
# 65.31749175898786
# ['disappearing-minority', 2, 'periodic', 'OOB']
# 66.52219729220519
# ['disappearing-minority', 2, 'periodic', 'improved_UOB']
# 65.87223227973416
# ['disappearing-minority', 2, 'periodic', 'WEOB2']
# 65.59014691972516
# ['disappearing-minority', 2, 'periodic', 'UOB']
# 65.56883666561876
# ['disappearing-minority', 2, 'periodic', 'RebalanceStream']
# 57.58909876923847
# ['disappearing-minority', 3, 'incremental', 'improved_OOB']
# 58.90356356955367
# ['disappearing-minority', 3, 'incremental', 'WEOB1']
# 58.80482422362955
# ['disappearing-minority', 3, 'incremental', 'CSMOTE']
# 58.54216320330696
# ['disappearing-minority', 3, 'incremental', 'OOB']
# 58.914089254395094
# ['disappearing-minority', 3, 'incremental', 'improved_UOB']
# 58.48585689190385
# ['disappearing-minority', 3, 'incremental', 'WEOB2']
# 58.29074306566895
# ['disappearing-minority', 3, 'incremental', 'UOB']
# 58.144574922356604
# ['disappearing-minority', 3, 'incremental', 'RebalanceStream']
# 57.25897351243693
# ['disappearing-minority', 3, 'sudden', 'improved_OOB']
# 58.028668632581095
# ['disappearing-minority', 3, 'sudden', 'WEOB1']
# 57.92295340949939
# ['disappearing-minority', 3, 'sudden', 'CSMOTE']
# 57.87261264464621
# ['disappearing-minority', 3, 'sudden', 'OOB']
# 58.03536320362688
# ['disappearing-minority', 3, 'sudden', 'improved_UOB']
# 57.6258455821944
# ['disappearing-minority', 3, 'sudden', 'WEOB2']
# 57.41443828673319
# ['disappearing-minority', 3, 'sudden', 'UOB']
# 57.27803449648353
# ['disappearing-minority', 3, 'sudden', 'RebalanceStream']
# 56.98624218659139
# ['disappearing-minority', 3, 'periodic', 'improved_OOB']
# 66.47791607188654
# ['disappearing-minority', 3, 'periodic', 'WEOB1']
# 66.62637052059765
# ['disappearing-minority', 3, 'periodic', 'CSMOTE']
# 65.93490344305687
# ['disappearing-minority', 3, 'periodic', 'OOB']
# 66.51452773083028
# ['disappearing-minority', 3, 'periodic', 'improved_UOB']
# 66.31675103555384
# ['disappearing-minority', 3, 'periodic', 'WEOB2']
# 66.05556946380325
# ['disappearing-minority', 3, 'periodic', 'UOB']
# 65.9324629709075
# ['disappearing-minority', 3, 'periodic', 'RebalanceStream']
# 62.2304774092785
# ['disappearing-minority', 4, 'incremental', 'improved_OOB']
# 58.82774232058453
# ['disappearing-minority', 4, 'incremental', 'WEOB1']
# 58.7471742942465
# ['disappearing-minority', 4, 'incremental', 'CSMOTE']
# 58.55749522878828
# ['disappearing-minority', 4, 'incremental', 'OOB']
# 58.705638182144504
# ['disappearing-minority', 4, 'incremental', 'improved_UOB']
# 58.46409984659855
# ['disappearing-minority', 4, 'incremental', 'WEOB2']
# 58.26274761718129
# ['disappearing-minority', 4, 'incremental', 'UOB']
# 58.70544995922014
# ['disappearing-minority', 4, 'incremental', 'RebalanceStream']
# 57.830251887161054
# ['disappearing-minority', 4, 'sudden', 'improved_OOB']
# 57.93929981631777
# ['disappearing-minority', 4, 'sudden', 'WEOB1']
# 57.879085250729545
# ['disappearing-minority', 4, 'sudden', 'CSMOTE']
# 57.95542585415969
# ['disappearing-minority', 4, 'sudden', 'OOB']
# 57.799172315539316
# ['disappearing-minority', 4, 'sudden', 'improved_UOB']
# 57.624427039882825
# ['disappearing-minority', 4, 'sudden', 'WEOB2']
# 57.39429204385302
# ['disappearing-minority', 4, 'sudden', 'UOB']
# 57.799172315539316
# ['disappearing-minority', 4, 'sudden', 'RebalanceStream']
# 57.61366915811235
# ['disappearing-minority', 4, 'periodic', 'improved_OOB']
# 66.46870563536501
# ['disappearing-minority', 4, 'periodic', 'WEOB1']
# 66.5907552896251
# ['disappearing-minority', 4, 'periodic', 'CSMOTE']
# 66.08325583118506
# ['disappearing-minority', 4, 'periodic', 'OOB']
# 66.36913581609112
# ['disappearing-minority', 4, 'periodic', 'improved_UOB']
# 66.35807844463922
# ['disappearing-minority', 4, 'periodic', 'WEOB2']
# 66.08475904915704
# ['disappearing-minority', 4, 'periodic', 'UOB']
# 65.81641432051029
# ['disappearing-minority', 4, 'periodic', 'RebalanceStream']
# 65.22322660208374
# ['appearing-minority', 1, 'incremental', 'improved_OOB']
# 58.33129744975289
# ['appearing-minority', 1, 'incremental', 'WEOB1']
# 58.69942755855087
# ['appearing-minority', 1, 'incremental', 'CSMOTE']
# 57.24298772940339
# ['appearing-minority', 1, 'incremental', 'OOB']
# 58.56038790208331
# ['appearing-minority', 1, 'incremental', 'improved_UOB']
# 57.834985240474374
# ['appearing-minority', 1, 'incremental', 'WEOB2']
# 57.68109576375863
# ['appearing-minority', 1, 'incremental', 'UOB']
# 57.56807907256738
# ['appearing-minority', 1, 'incremental', 'RebalanceStream']
# 52.14473376792995
# ['appearing-minority', 1, 'sudden', 'improved_OOB']
# 57.800665208436726
# ['appearing-minority', 1, 'sudden', 'WEOB1']
# 57.93917875459706
# ['appearing-minority', 1, 'sudden', 'CSMOTE']
# 56.695878412411595
# ['appearing-minority', 1, 'sudden', 'OOB']
# 58.06924396756134
# ['appearing-minority', 1, 'sudden', 'improved_UOB']
# 56.83618808981028
# ['appearing-minority', 1, 'sudden', 'WEOB2']
# 56.705767719330915
# ['appearing-minority', 1, 'sudden', 'UOB']
# 56.54750566225289
# ['appearing-minority', 1, 'sudden', 'RebalanceStream']
# 50.91912665419018
# ['appearing-minority', 1, 'periodic', 'improved_OOB']
# 51.34712449379024
# ['appearing-minority', 1, 'periodic', 'WEOB1']
# 51.49561110463246
# ['appearing-minority', 1, 'periodic', 'CSMOTE']
# 51.25877161376354
# ['appearing-minority', 1, 'periodic', 'OOB']
# 51.346407912474305
# ['appearing-minority', 1, 'periodic', 'improved_UOB']
# 51.41654519654744
# ['appearing-minority', 1, 'periodic', 'WEOB2']
# 51.41218804291721
# ['appearing-minority', 1, 'periodic', 'UOB']
# 50.99921332408148
# ['appearing-minority', 1, 'periodic', 'RebalanceStream']
# 51.00510301180678
# ['appearing-minority', 2, 'incremental', 'improved_OOB']
# 59.018056402590936
# ['appearing-minority', 2, 'incremental', 'WEOB1']
# 59.20485211387771
# ['appearing-minority', 2, 'incremental', 'CSMOTE']
# 58.012176852540094
# ['appearing-minority', 2, 'incremental', 'OOB']
# 59.21394062781682
# ['appearing-minority', 2, 'incremental', 'improved_UOB']
# 58.38310941846644
# ['appearing-minority', 2, 'incremental', 'WEOB2']
# 58.16049576315005
# ['appearing-minority', 2, 'incremental', 'UOB']
# 58.87613886312355
# ['appearing-minority', 2, 'incremental', 'RebalanceStream']
# 54.17645627588662
# ['appearing-minority', 2, 'sudden', 'improved_OOB']
# 58.308499506956615
# ['appearing-minority', 2, 'sudden', 'WEOB1']
# 58.240219911185214
# ['appearing-minority', 2, 'sudden', 'CSMOTE']
# 57.48465930301503
# ['appearing-minority', 2, 'sudden', 'OOB']
# 58.31392777998967
# ['appearing-minority', 2, 'sudden', 'improved_UOB']
# 57.36015396077615
# ['appearing-minority', 2, 'sudden', 'WEOB2']
# 57.16129102173254
# ['appearing-minority', 2, 'sudden', 'UOB']
# 57.39022431682704
# ['appearing-minority', 2, 'sudden', 'RebalanceStream']
# 54.29666423914114
# ['appearing-minority', 2, 'periodic', 'improved_OOB']
# 51.54403672443514
# ['appearing-minority', 2, 'periodic', 'WEOB1']
# 51.61332072013221
# ['appearing-minority', 2, 'periodic', 'CSMOTE']
# 51.39506174332172
# ['appearing-minority', 2, 'periodic', 'OOB']
# 51.584672820267336
# ['appearing-minority', 2, 'periodic', 'improved_UOB']
# 51.43804337155323
# ['appearing-minority', 2, 'periodic', 'WEOB2']
# 51.43214105741504
# ['appearing-minority', 2, 'periodic', 'UOB']
# 51.3170940770739
# ['appearing-minority', 2, 'periodic', 'RebalanceStream']
# 51.20719280303943
# ['appearing-minority', 3, 'incremental', 'improved_OOB']
# 59.32718208757012
# ['appearing-minority', 3, 'incremental', 'WEOB1']
# 59.25954592441743
# ['appearing-minority', 3, 'incremental', 'CSMOTE']
# 58.68121875358016
# ['appearing-minority', 3, 'incremental', 'OOB']
# 59.45120981199917
# ['appearing-minority', 3, 'incremental', 'improved_UOB']
# 58.86054289687528
# ['appearing-minority', 3, 'incremental', 'WEOB2']
# 58.541521175162906
# ['appearing-minority', 3, 'incremental', 'UOB']
# 58.783182924230914
# ['appearing-minority', 3, 'incremental', 'RebalanceStream']
# 57.591067579067534
# ['appearing-minority', 3, 'sudden', 'improved_OOB']
# 58.301767672089476
# ['appearing-minority', 3, 'sudden', 'WEOB1']
# 58.246377787078515
# ['appearing-minority', 3, 'sudden', 'CSMOTE']
# 58.07087279574686
# ['appearing-minority', 3, 'sudden', 'OOB']
# 58.22323389650019
# ['appearing-minority', 3, 'sudden', 'improved_UOB']
# 57.501965174835085
# ['appearing-minority', 3, 'sudden', 'WEOB2']
# 57.29859702412011
# ['appearing-minority', 3, 'sudden', 'UOB']
# 57.64462356910322
# ['appearing-minority', 3, 'sudden', 'RebalanceStream']
# 56.700917714994674
# ['appearing-minority', 3, 'periodic', 'improved_OOB']
# 51.644734694660215
# ['appearing-minority', 3, 'periodic', 'WEOB1']
# 51.63318332907416
# ['appearing-minority', 3, 'periodic', 'CSMOTE']
# 51.410055785746636
# ['appearing-minority', 3, 'periodic', 'OOB']
# 51.6909378873671
# ['appearing-minority', 3, 'periodic', 'improved_UOB']
# 51.46770515401181
# ['appearing-minority', 3, 'periodic', 'WEOB2']
# 51.44541667198483
# ['appearing-minority', 3, 'periodic', 'UOB']
# 51.44564346593438
# ['appearing-minority', 3, 'periodic', 'RebalanceStream']
# 51.29898172219699
# ['appearing-minority', 4, 'incremental', 'improved_OOB']
# 59.38721383181852
# ['appearing-minority', 4, 'incremental', 'WEOB1']
# 59.37383279528198
# ['appearing-minority', 4, 'incremental', 'CSMOTE']
# 58.69108632247687
# ['appearing-minority', 4, 'incremental', 'OOB']
# 59.484959277631525
# ['appearing-minority', 4, 'incremental', 'improved_UOB']
# 59.03556799271589
# ['appearing-minority', 4, 'incremental', 'WEOB2']
# 58.9156423564635
# ['appearing-minority', 4, 'incremental', 'UOB']
# 59.06141505601189
# ['appearing-minority', 4, 'incremental', 'RebalanceStream']
# 58.458958664652734
# ['appearing-minority', 4, 'sudden', 'improved_OOB']
# 58.29709680589701
# ['appearing-minority', 4, 'sudden', 'WEOB1']
# 58.19205046817141
# ['appearing-minority', 4, 'sudden', 'CSMOTE']
# 57.92810782669794
# ['appearing-minority', 4, 'sudden', 'OOB']
# 58.19263929174459
# ['appearing-minority', 4, 'sudden', 'improved_UOB']
# 57.54910599263852
# ['appearing-minority', 4, 'sudden', 'WEOB2']
# 57.305372460034654
# ['appearing-minority', 4, 'sudden', 'UOB']
# 57.67366525661915
# ['appearing-minority', 4, 'sudden', 'RebalanceStream']
# 57.35028899627413
# ['appearing-minority', 4, 'periodic', 'improved_OOB']
# 51.634303163973506
# ['appearing-minority', 4, 'periodic', 'WEOB1']
# 51.596398931809176
# ['appearing-minority', 4, 'periodic', 'CSMOTE']
# 51.43871180670586
# ['appearing-minority', 4, 'periodic', 'OOB']
# 51.63162283798529
# ['appearing-minority', 4, 'periodic', 'improved_UOB']
# 51.50075814020251
# ['appearing-minority', 4, 'periodic', 'WEOB2']
# 51.45388630117905
# ['appearing-minority', 4, 'periodic', 'UOB']
# 51.43408177164529
# ['appearing-minority', 4, 'periodic', 'RebalanceStream']
# 50.98082108613586
# ['appearing-clusters', 1, 'incremental', 'improved_OOB']
# 67.33603414957295
# ['appearing-clusters', 1, 'incremental', 'WEOB1']
# 67.59485642265005
# ['appearing-clusters', 1, 'incremental', 'CSMOTE']
# 66.20156798566568
# ['appearing-clusters', 1, 'incremental', 'OOB']
# 67.70393741368402
# ['appearing-clusters', 1, 'incremental', 'improved_UOB']
# 67.30974533508973
# ['appearing-clusters', 1, 'incremental', 'WEOB2']
# 66.718707308034
# ['appearing-clusters', 1, 'incremental', 'UOB']
# 67.21483903082148
# ['appearing-clusters', 1, 'incremental', 'RebalanceStream']
# 62.835546048824234
# ['appearing-clusters', 1, 'sudden', 'improved_OOB']
# 67.60891207312916
# ['appearing-clusters', 1, 'sudden', 'WEOB1']
# 67.64921550885296
# ['appearing-clusters', 1, 'sudden', 'CSMOTE']
# 66.25003612010536
# ['appearing-clusters', 1, 'sudden', 'OOB']
# 67.62124742339435
# ['appearing-clusters', 1, 'sudden', 'improved_UOB']
# 67.28489872148899
# ['appearing-clusters', 1, 'sudden', 'WEOB2']
# 66.3217795727713
# ['appearing-clusters', 1, 'sudden', 'UOB']
# 67.1305999173028
# ['appearing-clusters', 1, 'sudden', 'RebalanceStream']
# 62.81365013232911
# ['appearing-clusters', 1, 'periodic', 'improved_OOB']
# 69.28727245343258
# ['appearing-clusters', 1, 'periodic', 'WEOB1']
# 69.26982103489897
# ['appearing-clusters', 1, 'periodic', 'CSMOTE']
# 68.59020083204396
# ['appearing-clusters', 1, 'periodic', 'OOB']
# 69.2913314538531
# ['appearing-clusters', 1, 'periodic', 'improved_UOB']
# 68.97842610185774
# ['appearing-clusters', 1, 'periodic', 'WEOB2']
# 68.83547771741755
# ['appearing-clusters', 1, 'periodic', 'UOB']
# 68.90789055622326
# ['appearing-clusters', 1, 'periodic', 'RebalanceStream']
# 64.119624470187
# ['appearing-clusters', 2, 'incremental', 'improved_OOB']
# 68.1520114095134
# ['appearing-clusters', 2, 'incremental', 'WEOB1']
# 68.09826337321104
# ['appearing-clusters', 2, 'incremental', 'CSMOTE']
# 67.37353711594442
# ['appearing-clusters', 2, 'incremental', 'OOB']
# 68.23458809986388
# ['appearing-clusters', 2, 'incremental', 'improved_UOB']
# 67.76485031532111
# ['appearing-clusters', 2, 'incremental', 'WEOB2']
# 67.57856425213632
# ['appearing-clusters', 2, 'incremental', 'UOB']
# 67.64929689907919
# ['appearing-clusters', 2, 'incremental', 'RebalanceStream']
# 66.52275770165889
# ['appearing-clusters', 2, 'sudden', 'improved_OOB']
# 68.02839664426776
# ['appearing-clusters', 2, 'sudden', 'WEOB1']
# 68.04734867748788
# ['appearing-clusters', 2, 'sudden', 'CSMOTE']
# 67.09079567609663
# ['appearing-clusters', 2, 'sudden', 'OOB']
# 68.13619106757918
# ['appearing-clusters', 2, 'sudden', 'improved_UOB']
# 67.76877273634719
# ['appearing-clusters', 2, 'sudden', 'WEOB2']
# 67.47670744735606
# ['appearing-clusters', 2, 'sudden', 'UOB']
# 67.57299967298532
# ['appearing-clusters', 2, 'sudden', 'RebalanceStream']
# 65.88798286383135
# ['appearing-clusters', 2, 'periodic', 'improved_OOB']
# 69.41766595464676
# ['appearing-clusters', 2, 'periodic', 'WEOB1']
# 69.35862148596469
# ['appearing-clusters', 2, 'periodic', 'CSMOTE']
# 69.23521651871008
# ['appearing-clusters', 2, 'periodic', 'OOB']
# 69.41447654574617
# ['appearing-clusters', 2, 'periodic', 'improved_UOB']
# 69.21677709673169
# ['appearing-clusters', 2, 'periodic', 'WEOB2']
# 69.06911756883116
# ['appearing-clusters', 2, 'periodic', 'UOB']
# 69.08532088237384
# ['appearing-clusters', 2, 'periodic', 'RebalanceStream']
# 68.39868427444947
# ['appearing-clusters', 3, 'incremental', 'improved_OOB']
# 68.19920457086933
# ['appearing-clusters', 3, 'incremental', 'WEOB1']
# 68.16312037932401
# ['appearing-clusters', 3, 'incremental', 'CSMOTE']
# 67.65166484279504
# ['appearing-clusters', 3, 'incremental', 'OOB']
# 68.25912254731779
# ['appearing-clusters', 3, 'incremental', 'improved_UOB']
# 67.96976578105092
# ['appearing-clusters', 3, 'incremental', 'WEOB2']
# 67.93658806772218
# ['appearing-clusters', 3, 'incremental', 'UOB']
# 68.01898610548633
# ['appearing-clusters', 3, 'incremental', 'RebalanceStream']
# 67.54049461129416
# ['appearing-clusters', 3, 'sudden', 'improved_OOB']
# 68.05094361263528
# ['appearing-clusters', 3, 'sudden', 'WEOB1']
# 68.01093296257082
# ['appearing-clusters', 3, 'sudden', 'CSMOTE']
# 67.5246477480404
# ['appearing-clusters', 3, 'sudden', 'OOB']
# 68.1101958065544
# ['appearing-clusters', 3, 'sudden', 'improved_UOB']
# 67.86287328178966
# ['appearing-clusters', 3, 'sudden', 'WEOB2']
# 67.74677081325453
# ['appearing-clusters', 3, 'sudden', 'UOB']
# 67.96181002175273
# ['appearing-clusters', 3, 'sudden', 'RebalanceStream']
# 67.50894376494622
# ['appearing-clusters', 3, 'periodic', 'improved_OOB']
# 69.32944832957256
# ['appearing-clusters', 3, 'periodic', 'WEOB1']
# 69.2793555469469
# ['appearing-clusters', 3, 'periodic', 'CSMOTE']
# 69.26387183379384
# ['appearing-clusters', 3, 'periodic', 'OOB']
# 69.3136856494198
# ['appearing-clusters', 3, 'periodic', 'improved_UOB']
# 69.18624579703081
# ['appearing-clusters', 3, 'periodic', 'WEOB2']
# 69.15083560300764
# ['appearing-clusters', 3, 'periodic', 'UOB']
# 69.3136856494198
# ['appearing-clusters', 3, 'periodic', 'RebalanceStream']
# 69.07685300562619
# ['appearing-clusters', 4, 'incremental', 'improved_OOB']
# 68.19612809841736
# ['appearing-clusters', 4, 'incremental', 'WEOB1']
# 68.15314889076595
# ['appearing-clusters', 4, 'incremental', 'CSMOTE']
# 67.84368795034109
# ['appearing-clusters', 4, 'incremental', 'OOB']
# 68.2901301932044
# ['appearing-clusters', 4, 'incremental', 'improved_UOB']
# 68.07775579657927
# ['appearing-clusters', 4, 'incremental', 'WEOB2']
# 68.02671078649998
# ['appearing-clusters', 4, 'incremental', 'UOB']
# 68.20189973558664
# ['appearing-clusters', 4, 'incremental', 'RebalanceStream']
# 68.1018484475222
# ['appearing-clusters', 4, 'sudden', 'improved_OOB']
# 68.07852387190806
# ['appearing-clusters', 4, 'sudden', 'WEOB1']
# 68.05149422255177
# ['appearing-clusters', 4, 'sudden', 'CSMOTE']
# 67.76094289978712
# ['appearing-clusters', 4, 'sudden', 'OOB']
# 68.20621384763923
# ['appearing-clusters', 4, 'sudden', 'improved_UOB']
# 67.9662213906253
# ['appearing-clusters', 4, 'sudden', 'WEOB2']
# 67.91958529920814
# ['appearing-clusters', 4, 'sudden', 'UOB']
# 68.1146193405034
# ['appearing-clusters', 4, 'sudden', 'RebalanceStream']
# 67.79793602507915
# ['appearing-clusters', 4, 'periodic', 'improved_OOB']
# 69.28361297481624
# ['appearing-clusters', 4, 'periodic', 'WEOB1']
# 69.26277995236612
# ['appearing-clusters', 4, 'periodic', 'CSMOTE']
# 69.28706315492846
# ['appearing-clusters', 4, 'periodic', 'OOB']
# 69.33484819737518
# ...
# 65.47279626028585
# ['splitting-clusters', 2, 'periodic', 'improved_OOB']
# 68.39659167894038
# ['splitting-clusters', 2, 'periodic', 'WEOB1']
# 68.42040117240809
# ['splitting-clusters', 2, 'periodic', 'CSMOTE']
# 67.83682028248082
# ['splitting-clusters', 2, 'periodic', 'OOB']
# 68.46076811030704
# ['splitting-clusters', 2, 'periodic', 'improved_UOB']
# 68.18408692045702
# ['splitting-clusters', 2, 'periodic', 'WEOB2']
# 68.22905782040422
# ['splitting-clusters', 2, 'periodic', 'UOB']
# 68.21356212902461
# ['splitting-clusters', 2, 'periodic', 'RebalanceStream']
# 66.76452305165206
# ['splitting-clusters', 3, 'incremental', 'improved_OOB']
# 67.89781312042227
# ['splitting-clusters', 3, 'incremental', 'WEOB1']
# 67.88491763669381
# ['splitting-clusters', 3, 'incremental', 'CSMOTE']
# 67.2667206567378
# ['splitting-clusters', 3, 'incremental', 'OOB']
# 67.61023609250012
# ['splitting-clusters', 3, 'incremental', 'improved_UOB']
# 67.73086057859915
# ['splitting-clusters', 3, 'incremental', 'WEOB2']
# 67.60500274353231
# ['splitting-clusters', 3, 'incremental', 'UOB']
# 67.00806070102952
# ['splitting-clusters', 3, 'incremental', 'RebalanceStream']
# 66.85224709189
# ['splitting-clusters', 3, 'sudden', 'improved_OOB']
# 67.66525271047398
# ['splitting-clusters', 3, 'sudden', 'WEOB1']
# 67.64759361423796
# ['splitting-clusters', 3, 'sudden', 'CSMOTE']
# 67.1948058372158
# ['splitting-clusters', 3, 'sudden', 'OOB']
# 67.52664594297973
# ['splitting-clusters', 3, 'sudden', 'improved_UOB']
# 67.45071232472421
# ['splitting-clusters', 3, 'sudden', 'WEOB2']
# 67.39927502908904
# ['splitting-clusters', 3, 'sudden', 'UOB']
# 67.0845847891895
# ['splitting-clusters', 3, 'sudden', 'RebalanceStream']
# 66.8562733729668
# ['splitting-clusters', 3, 'periodic', 'improved_OOB']
# 68.52381463055244
# ['splitting-clusters', 3, 'periodic', 'WEOB1']
# 68.5065340366622
# ['splitting-clusters', 3, 'periodic', 'CSMOTE']
# 68.11298691906327
# ['splitting-clusters', 3, 'periodic', 'OOB']
# 68.26101422058396
# ['splitting-clusters', 3, 'periodic', 'improved_UOB']
# 68.34226046560278
# ['splitting-clusters', 3, 'periodic', 'WEOB2']
# 68.36068292708255
# ['splitting-clusters', 3, 'periodic', 'UOB']
# 68.10491681904396
# ['splitting-clusters', 3, 'periodic', 'RebalanceStream']
# 67.82088020219429
# ['splitting-clusters', 4, 'incremental', 'improved_OOB']
# 67.817888321582
# ['splitting-clusters', 4, 'incremental', 'WEOB1']
# 67.81373817109895
# ['splitting-clusters', 4, 'incremental', 'CSMOTE']
# 67.28560628260252
# ['splitting-clusters', 4, 'incremental', 'OOB']
# 67.71367342751896
# ['splitting-clusters', 4, 'incremental', 'improved_UOB']
# 67.75667268891902
# ['splitting-clusters', 4, 'incremental', 'WEOB2']
# 67.69622834180811
# ['splitting-clusters', 4, 'incremental', 'UOB']
# 67.07518569061924
# ['splitting-clusters', 4, 'incremental', 'RebalanceStream']
# 67.5003932081784
# ['splitting-clusters', 4, 'sudden', 'improved_OOB']
# 67.75684130654824
# ['splitting-clusters', 4, 'sudden', 'WEOB1']
# 67.76011276164687
# ['splitting-clusters', 4, 'sudden', 'CSMOTE']
# 67.39962662809447
# ['splitting-clusters', 4, 'sudden', 'OOB']
# 67.69696517419074
# ['splitting-clusters', 4, 'sudden', 'improved_UOB']
# 67.66819228920507
# ['splitting-clusters', 4, 'sudden', 'WEOB2']
# 67.51577907570585
# ['splitting-clusters', 4, 'sudden', 'UOB']
# 67.55469146576505
# ['splitting-clusters', 4, 'sudden', 'RebalanceStream']
# 67.481067282169
# ['splitting-clusters', 4, 'periodic', 'improved_OOB']
# 68.46795048954547
# ['splitting-clusters', 4, 'periodic', 'WEOB1']
# 68.5538924848305
# ['splitting-clusters', 4, 'periodic', 'CSMOTE']
# 68.3620128180601
# ['splitting-clusters', 4, 'periodic', 'OOB']
# 68.44181526007594
# ['splitting-clusters', 4, 'periodic', 'improved_UOB']
# 68.48139277118466
# ['splitting-clusters', 4, 'periodic', 'WEOB2']
# 68.44129158407256
# ['splitting-clusters', 4, 'periodic', 'UOB']
# 68.33822770703236
# ['splitting-clusters', 4, 'periodic', 'RebalanceStream']
# 68.30898705066282
# ['clusters-movement', 1, 'incremental', 'improved_OOB']
# 65.30459578535665
# ['clusters-movement', 1, 'incremental', 'WEOB1']
# 65.35525393448094
# ['clusters-movement', 1, 'incremental', 'CSMOTE']
# 59.40571963544638
# ['clusters-movement', 1, 'incremental', 'OOB']
# 65.59220484415326
# ['clusters-movement', 1, 'incremental', 'improved_UOB']
# 63.03429045447668
# ['clusters-movement', 1, 'incremental', 'WEOB2']
# 61.75582024773771
# ['clusters-movement', 1, 'incremental', 'UOB']
# 63.010162645357454
# ['clusters-movement', 1, 'incremental', 'RebalanceStream']
# 54.937654098128405
# ['clusters-movement', 1, 'sudden', 'improved_OOB']
# 64.25761620768102
# ['clusters-movement', 1, 'sudden', 'WEOB1']
# 64.27623703536428
# ['clusters-movement', 1, 'sudden', 'CSMOTE']
# 58.174361494256836
# ['clusters-movement', 1, 'sudden', 'OOB']
# 65.04064489143953
# ['clusters-movement', 1, 'sudden', 'improved_UOB']
# 61.30193617748174
# ['clusters-movement', 1, 'sudden', 'WEOB2']
# 60.62147393678924
# ['clusters-movement', 1, 'sudden', 'UOB']
# 60.03352435116402
# ['clusters-movement', 1, 'sudden', 'RebalanceStream']
# 53.81195076866595
# ['clusters-movement', 1, 'periodic', 'improved_OOB']
# 64.8029160482239
# ['clusters-movement', 1, 'periodic', 'WEOB1']
# 65.19868780664021
# ['clusters-movement', 1, 'periodic', 'CSMOTE']
# 63.073260027097184
# ['clusters-movement', 1, 'periodic', 'OOB']
# 65.48615140690637
# ['clusters-movement', 1, 'periodic', 'improved_UOB']
# 63.4364314692019
# ['clusters-movement', 1, 'periodic', 'WEOB2']
# 63.46446923024151
# ['clusters-movement', 1, 'periodic', 'UOB']
# 63.127654902892154
# ['clusters-movement', 1, 'periodic', 'RebalanceStream']
# 51.9320609321163
# ['clusters-movement', 2, 'incremental', 'improved_OOB']
# 65.92623724041486
# ['clusters-movement', 2, 'incremental', 'WEOB1']
# 65.99018556080827
# ['clusters-movement', 2, 'incremental', 'CSMOTE']
# 61.619796352869876
# ['clusters-movement', 2, 'incremental', 'OOB']
# 66.21371285083492
# ['clusters-movement', 2, 'incremental', 'improved_UOB']
# 65.10052049869321
# ['clusters-movement', 2, 'incremental', 'WEOB2']
# 62.99276775296494
# ['clusters-movement', 2, 'incremental', 'UOB']
# 64.45947381885802
# ['clusters-movement', 2, 'incremental', 'RebalanceStream']
# 60.45860467880092
# ['clusters-movement', 2, 'sudden', 'improved_OOB']
# 66.00169702318317
# ['clusters-movement', 2, 'sudden', 'WEOB1']
# 65.89036014028821
# ['clusters-movement', 2, 'sudden', 'CSMOTE']
# 60.37487859543431
# ['clusters-movement', 2, 'sudden', 'OOB']
# 66.26180647836158
# ['clusters-movement', 2, 'sudden', 'improved_UOB']
# 64.40251378848518
# ['clusters-movement', 2, 'sudden', 'WEOB2']
# 61.342511385300135
# ['clusters-movement', 2, 'sudden', 'UOB']
# 62.993763422338894
# ['clusters-movement', 2, 'sudden', 'RebalanceStream']
# 60.20400623937193
# ['clusters-movement', 2, 'periodic', 'improved_OOB']
# 65.60645384590802
# ['clusters-movement', 2, 'periodic', 'WEOB1']
# 65.44919906930878
# ['clusters-movement', 2, 'periodic', 'CSMOTE']
# 64.6884063764649
# ['clusters-movement', 2, 'periodic', 'OOB']
# 65.97321147446856
# ['clusters-movement', 2, 'periodic', 'improved_UOB']
# 64.09582494941887
# ['clusters-movement', 2, 'periodic', 'WEOB2']
# 64.38109288460602
# ['clusters-movement', 2, 'periodic', 'UOB']
# 63.85644970924064
# ['clusters-movement', 2, 'periodic', 'RebalanceStream']
# 58.971191523832466
# ['clusters-movement', 3, 'incremental', 'improved_OOB']
# 66.28185919744797
# ['clusters-movement', 3, 'incremental', 'WEOB1']
# 66.07333419011283
# ['clusters-movement', 3, 'incremental', 'CSMOTE']
# 62.31040255303692
# ['clusters-movement', 3, 'incremental', 'OOB']
# 66.38445494595094
# ['clusters-movement', 3, 'incremental', 'improved_UOB']
# 65.2492813521769
# ['clusters-movement', 3, 'incremental', 'WEOB2']
# 64.01199732431795
# ['clusters-movement', 3, 'incremental', 'UOB']
# 64.57000591439609
# ['clusters-movement', 3, 'incremental', 'RebalanceStream']
# 63.60723197783985
# ['clusters-movement', 3, 'sudden', 'improved_OOB']
# 65.92402987027319
# ['clusters-movement', 3, 'sudden', 'WEOB1']
# 65.82471679164078
# ['clusters-movement', 3, 'sudden', 'CSMOTE']
# 61.848498658173376
# ['clusters-movement', 3, 'sudden', 'OOB']
# 66.14355318218716
# ['clusters-movement', 3, 'sudden', 'improved_UOB']
# 65.25447314443934
# ['clusters-movement', 3, 'sudden', 'WEOB2']
# 61.655531553884074
# ['clusters-movement', 3, 'sudden', 'UOB']
# 62.83653642622058
# ['clusters-movement', 3, 'sudden', 'RebalanceStream']
# 60.61201689589242
# ['clusters-movement', 3, 'periodic', 'improved_OOB']
# 65.91999648206378
# ['clusters-movement', 3, 'periodic', 'WEOB1']
# 65.68791115754938
# ['clusters-movement', 3, 'periodic', 'CSMOTE']
# 65.31587185621807
# ['clusters-movement', 3, 'periodic', 'OOB']
# 66.12671640216578
# ['clusters-movement', 3, 'periodic', 'improved_UOB']
# 65.00676123056803
# ['clusters-movement', 3, 'periodic', 'WEOB2']
# 64.8814686052042
# ['clusters-movement', 3, 'periodic', 'UOB']
# 64.57199954474022
# ['clusters-movement', 3, 'periodic', 'RebalanceStream']
# 63.254365972762386
# ['clusters-movement', 4, 'incremental', 'improved_OOB']
# 66.07261703861889
# ['clusters-movement', 4, 'incremental', 'WEOB1']
# 65.9934573253386
# ['clusters-movement', 4, 'incremental', 'CSMOTE']
# 63.129462555182066
# ['clusters-movement', 4, 'incremental', 'OOB']
# 65.93174382432349
# ['clusters-movement', 4, 'incremental', 'improved_UOB']
# 65.42974429591388
# ['clusters-movement', 4, 'incremental', 'WEOB2']
# 63.89960630851702
# ['clusters-movement', 4, 'incremental', 'UOB']
# 65.26931847452785
# ['clusters-movement', 4, 'incremental', 'RebalanceStream']
# 64.84708573333214
# ['clusters-movement', 4, 'sudden', 'improved_OOB']
# 66.09418392277396
# ['clusters-movement', 4, 'sudden', 'WEOB1']
# 65.9799839419359
# ['clusters-movement', 4, 'sudden', 'CSMOTE']
# 62.37225384241435
# ['clusters-movement', 4, 'sudden', 'OOB']
# 65.99030474521213
# ['clusters-movement', 4, 'sudden', 'improved_UOB']
# 65.52751422707027
# ['clusters-movement', 4, 'sudden', 'WEOB2']
# 61.293739110688385
# ['clusters-movement', 4, 'sudden', 'UOB']
# 64.45862898468769
# ['clusters-movement', 4, 'sudden', 'RebalanceStream']
# 64.44805888186711
# ['clusters-movement', 4, 'periodic', 'improved_OOB']
# 65.79215363938303
# ['clusters-movement', 4, 'periodic', 'WEOB1']
# 65.6640427297417
# ['clusters-movement', 4, 'periodic', 'CSMOTE']
# 65.3382469497258
# ['clusters-movement', 4, 'periodic', 'OOB']
# 65.62421710969724
# ['clusters-movement', 4, 'periodic', 'improved_UOB']
# 65.05620818000685
# ['clusters-movement', 4, 'periodic', 'WEOB2']
# 64.79627428502594
# ['clusters-movement', 4, 'periodic', 'UOB']
# 65.05815146827834
# ['clusters-movement', 4, 'periodic', 'RebalanceStream']
# 64.66204364744786
# ['borderline', 1, 'incremental', 'improved_OOB']
# 66.847202599312
# ['borderline', 1, 'incremental', 'WEOB1']
# 66.74309515761338
# ['borderline', 1, 'incremental', 'CSMOTE']
# 64.28817632295443
# ['borderline', 1, 'incremental', 'OOB']
# 66.93702414438027
# ['borderline', 1, 'incremental', 'improved_UOB']
# 64.95916471219553
# ['borderline', 1, 'incremental', 'WEOB2']
# 64.5694756472432
# ['borderline', 1, 'incremental', 'UOB']
# 64.92109942520224
# ['borderline', 1, 'incremental', 'RebalanceStream']
# 55.881637978764346
# ['borderline', 1, 'sudden', 'improved_OOB']
# 66.7371981673601
# ['borderline', 1, 'sudden', 'WEOB1']
# 66.58722641194825
# ['borderline', 1, 'sudden', 'CSMOTE']
# 64.3168129697493
# ['borderline', 1, 'sudden', 'OOB']
# 66.72945412892884
# ['borderline', 1, 'sudden', 'improved_UOB']
# 64.8551728716378
# ['borderline', 1, 'sudden', 'WEOB2']
# 64.37573556290548
# ['borderline', 1, 'sudden', 'UOB']
# 64.69877786162274
# ['borderline', 1, 'sudden', 'RebalanceStream']
# 55.824304494576054
# ['borderline', 1, 'periodic', 'improved_OOB']
# 67.68065452912569
# ['borderline', 1, 'periodic', 'WEOB1']
# 67.33932056599771
# ['borderline', 1, 'periodic', 'CSMOTE']
# 64.90923335909471
# ['borderline', 1, 'periodic', 'OOB']
# 67.68553626475418
# ['borderline', 1, 'periodic', 'improved_UOB']
# 65.448472082645
# ['borderline', 1, 'periodic', 'WEOB2']
# 64.96844508134407
# ['borderline', 1, 'periodic', 'UOB']
# 65.36371993937021
# ['borderline', 1, 'periodic', 'RebalanceStream']
# 56.80034261627641
# ['borderline', 2, 'incremental', 'improved_OOB']
# 66.97388860992497
# ['borderline', 2, 'incremental', 'WEOB1']
# 66.84311894120626
# ['borderline', 2, 'incremental', 'CSMOTE']
# 66.21710349450953
# ['borderline', 2, 'incremental', 'OOB']
# 67.05407576819422
# ['borderline', 2, 'incremental', 'improved_UOB']
# 66.1010471845253
# ['borderline', 2, 'incremental', 'WEOB2']
# 65.71129424284871
# ['borderline', 2, 'incremental', 'UOB']
# 65.73576216959353
# ['borderline', 2, 'incremental', 'RebalanceStream']
# 62.68051778322464
# ['borderline', 2, 'sudden', 'improved_OOB']
# 66.74843885475897
# ['borderline', 2, 'sudden', 'WEOB1']
# 66.57498580279488
# ['borderline', 2, 'sudden', 'CSMOTE']
# 65.76091314388883
# ['borderline', 2, 'sudden', 'OOB']
# 66.82441599158133
# ['borderline', 2, 'sudden', 'improved_UOB']
# 65.72147965034586
# ['borderline', 2, 'sudden', 'WEOB2']
# 65.45634520841057
# ['borderline', 2, 'sudden', 'UOB']
# 65.4860037742454
# ['borderline', 2, 'sudden', 'RebalanceStream']
# 62.211696028775954
# ['borderline', 2, 'periodic', 'improved_OOB']
# 67.66911560298209
# ['borderline', 2, 'periodic', 'WEOB1']
# 67.40855922876207
# ['borderline', 2, 'periodic', 'CSMOTE']
# 66.67871231956539
# ['borderline', 2, 'periodic', 'OOB']
# 67.69508747131796
# ['borderline', 2, 'periodic', 'improved_UOB']
# 66.51183925961934
# ['borderline', 2, 'periodic', 'WEOB2']
# 66.20870706346889
# ['borderline', 2, 'periodic', 'UOB']
# 66.28054483658232
# ['borderline', 2, 'periodic', 'RebalanceStream']
# 64.39349594434228
# ['borderline', 3, 'incremental', 'improved_OOB']
# 67.08089872496136
# ['borderline', 3, 'incremental', 'WEOB1']
# 66.91353533892756
# ['borderline', 3, 'incremental', 'CSMOTE']
# 66.08753158140475
# ['borderline', 3, 'incremental', 'OOB']
# 66.93204728730737
# ['borderline', 3, 'incremental', 'improved_UOB']
# 66.5577953362255
# ['borderline', 3, 'incremental', 'WEOB2']
# 66.30002435566186
# ['borderline', 3, 'incremental', 'UOB']
# 66.13374524353112
# ['borderline', 3, 'incremental', 'RebalanceStream']
# 65.9433863048459
# ['borderline', 3, 'sudden', 'improved_OOB']
# 66.85176223718153
# ['borderline', 3, 'sudden', 'WEOB1']
# 66.67427505396071
# ['borderline', 3, 'sudden', 'CSMOTE']
# 66.04715585412897
# ['borderline', 3, 'sudden', 'OOB']
# 66.77022149578542
# ['borderline', 3, 'sudden', 'improved_UOB']
# 66.29670617245085
# ['borderline', 3, 'sudden', 'WEOB2']
# 66.11297286436022
# ['borderline', 3, 'sudden', 'UOB']
# 65.85087499807324
# ['borderline', 3, 'sudden', 'RebalanceStream']
# 65.7252183806061
# ['borderline', 3, 'periodic', 'improved_OOB']
# 67.73073460112502
# ['borderline', 3, 'periodic', 'WEOB1']
# 67.54226415321286
# ['borderline', 3, 'periodic', 'CSMOTE']
# 66.90894155194563
# ['borderline', 3, 'periodic', 'OOB']
# 67.55836773143452
# ['borderline', 3, 'periodic', 'improved_UOB']
# 67.1615064844622
# ['borderline', 3, 'periodic', 'WEOB2']
# 66.76678658019321
# ['borderline', 3, 'periodic', 'UOB']
# 66.73809563792659
# ['borderline', 3, 'periodic', 'RebalanceStream']
# 66.85261202142142
# ['borderline', 4, 'incremental', 'improved_OOB']
# 66.96619672876419
# ['borderline', 4, 'incremental', 'WEOB1']
# 66.87937056325055
# ['borderline', 4, 'incremental', 'CSMOTE']
# 66.53648153822976
# ['borderline', 4, 'incremental', 'OOB']
# 66.9273135130542
# ['borderline', 4, 'incremental', 'improved_UOB']
# 66.5363417163035
# ['borderline', 4, 'incremental', 'WEOB2']
# 66.29335226262536
# ['borderline', 4, 'incremental', 'UOB']
# 66.9273135130542
# ['borderline', 4, 'incremental', 'RebalanceStream']
# 66.48740086761347
# ['borderline', 4, 'sudden', 'improved_OOB']
# 66.7518750882026
# ['borderline', 4, 'sudden', 'WEOB1']
# 66.66522479078358
# ['borderline', 4, 'sudden', 'CSMOTE']
# 66.48757824750751
# ['borderline', 4, 'sudden', 'OOB']
# 66.6883339652369
# ['borderline', 4, 'sudden', 'improved_UOB']
# 66.33879531205858
# ['borderline', 4, 'sudden', 'WEOB2']
# 66.0539686078456
# ['borderline', 4, 'sudden', 'UOB']
# 66.6883339652369
# ['borderline', 4, 'sudden', 'RebalanceStream']
# 66.39020165554214
# ['borderline', 4, 'periodic', 'improved_OOB']
# 67.64371803619191
# ['borderline', 4, 'periodic', 'WEOB1']
# 67.56493731599843
# ['borderline', 4, 'periodic', 'CSMOTE']
# 66.96853929065489
# ['borderline', 4, 'periodic', 'OOB']
# 67.58382276865701
# ['borderline', 4, 'periodic', 'improved_UOB']
# 67.20156939447801
# ['borderline', 4, 'periodic', 'WEOB2']
# 66.8679444713357
# ['borderline', 4, 'periodic', 'UOB']
# 67.58382276865701
# ['borderline', 4, 'periodic', 'RebalanceStream']
# 67.28840043143023

# %%
with open('GMEAN_prova.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    writer.writerow(["drift","unbalance","type","alg","Gmean","Gmean_Mean","Gmean_Perc"])
    for drift, dicts in final_dict.items():
        for unbalance, dtypes in dicts.items():
            for dtype, algs in dtypes.items():
                mean, mi, ma = stats_of(algs)
                for alg, value in algs.items():
                    
                    print([drift,unbalance,dtype,alg])
                    print(value)
                    print(value - mean)
                    writer.writerow([drift,unbalance,dtype,alg,value,value - mean,value/mean])
# Out:
# ['sea_P(y)', 1, 'sudden', 'improved_OOB']
# 70.35194043770869
# 0.7794698002827971
# ['sea_P(y)', 1, 'sudden', 'WEOB1']
# 70.3467839263607
# 0.7743132889348061
# ['sea_P(y)', 1, 'sudden', 'OOB']
# 70.32735479606795
# 0.7548841586420565
# ['sea_P(y)', 1, 'sudden', 'ESOS_ELM']
# 65.32599718707182
# -4.246473450354074
# ['sea_P(y)', 1, 'sudden', 'improved_UOB']
# 70.28360889906938
# 0.7111382616434838
# ['sea_P(y)', 1, 'sudden', 'WEOB2']
# 70.21106346302977
# 0.6385928256038795
# ['sea_P(y)', 1, 'sudden', 'UOB']
# 70.32735479606795
# 0.7548841586420565
# ['sea_P(y)', 1, 'sudden', 'CSMOTE']
# 70.22543513635313
# 0.6529644989272327
# ['sea_P(y)', 1, 'sudden', 'RebalanceStream']
# 68.75269709510368
# -0.8197735423222099
# ['sea_P(y)', 1, 'incremental', 'improved_OOB']
# 70.37893250807234
# 0.6089832535399466
# ['sea_P(y)', 1, 'incremental', 'WEOB1']
# 70.35681895951737
# 0.5868697049849771
# ['sea_P(y)', 1, 'incremental', 'OOB']
# 70.33583328899387
# 0.565884034461476
# ['sea_P(y)', 1, 'incremental', 'ESOS_ELM']
# 65.53153617761798
# -4.238413076914412
# ['sea_P(y)', 1, 'incremental', 'improved_UOB']
# 70.30404622699567
# 0.5340969724632743
# ['sea_P(y)', 1, 'incremental', 'WEOB2']
# 70.24594742649154
# 0.47599817195914795
# ['sea_P(y)', 1, 'incremental', 'UOB']
# 70.33583328899387
# 0.565884034461476
# ['sea_P(y)', 1, 'incremental', 'CSMOTE']
# 70.2150639171223
# 0.4451146625899014
# ['sea_P(y)', 1, 'incremental', 'RebalanceStream']
# 70.22553149698658
# 0.45558224245418444
# ['sea_P(y)', 3, 'incremental', 'improved_OOB']
# 64.66726516871196
# 0.6139157628931287
# ['sea_P(y)', 3, 'incremental', 'WEOB1']
# 64.68776455295958
# 0.6344151471407429
# ['sea_P(y)', 3, 'incremental', 'OOB']
# 64.62508213593722
# 0.5717327301183843
# ['sea_P(y)', 3, 'incremental', 'ESOS_ELM']
# 61.141349756833336
# -2.9119996489855
# ['sea_P(y)', 3, 'incremental', 'improved_UOB']
# 64.58282225155952
# 0.5294728457406848
# ['sea_P(y)', 3, 'incremental', 'WEOB2']
# 64.40379927342454
# 0.35044986760570396
# ['sea_P(y)', 3, 'incremental', 'UOB']
# 64.59499764956168
# 0.5416482437428414
# ['sea_P(y)', 3, 'incremental', 'CSMOTE']
# 63.49084195782807
# -0.5625074479907681
# ['sea_P(y)', 3, 'incremental', 'RebalanceStream']
# 64.2862219055536
# 0.23287249973476776
# ['sea_P(y)', 3, 'sudden', 'improved_OOB']
# 64.6368984646941
# 0.5196919862524396
# ['sea_P(y)', 3, 'sudden', 'WEOB1']
# 64.66508664177272
# 0.5478801633310582
# ['sea_P(y)', 3, 'sudden', 'OOB']
# 64.61829871533901
# 0.5010922368973496
# ['sea_P(y)', 3, 'sudden', 'ESOS_ELM']
# 61.03015938952633
# -3.0870470889153268
# ['sea_P(y)', 3, 'sudden', 'improved_UOB']
# 64.59578900783663
# 0.4785825293949699
# ['sea_P(y)', 3, 'sudden', 'WEOB2']
# 64.352506765577
# 0.23530028713534534
# ['sea_P(y)', 3, 'sudden', 'UOB']
# 64.58449071397526
# 0.4672842355335973
# ['sea_P(y)', 3, 'sudden', 'CSMOTE']
# 64.29709589700165
# 0.17988941855999485
# ['sea_P(y)', 3, 'sudden', 'RebalanceStream']
# 64.27453271025215
# 0.15732623181048666
# ['sea_P(y)', 2, 'sudden', 'improved_OOB']
# 64.63206987274586
# 0.6772367116103837
# ['sea_P(y)', 2, 'sudden', 'WEOB1']
# 64.66098248466639
# 0.7061493235309158
# ['sea_P(y)', 2, 'sudden', 'OOB']
# 64.63253655479865
# 0.6777033936631724
# ['sea_P(y)', 2, 'sudden', 'ESOS_ELM']
# 60.97845897001802
# -2.9763741911174577
# ['sea_P(y)', 2, 'sudden', 'improved_UOB']
# 64.57966721824491
# 0.6248340571094317
# ['sea_P(y)', 2, 'sudden', 'WEOB2']
# 64.36556981717865
# 0.4107366560431771
# ['sea_P(y)', 2, 'sudden', 'UOB']
# 64.58845694398596
# 0.6336237828504849
# ['sea_P(y)', 2, 'sudden', 'CSMOTE']
# 64.0546331285078
# 0.0997999673723271
# ['sea_P(y)', 2, 'sudden', 'RebalanceStream']
# 63.101123460073076
# -0.8537097010623995
# ['sea_P(y)', 2, 'incremental', 'improved_OOB']
# 64.65866731487436
# 0.7251277248125234
# ['sea_P(y)', 2, 'incremental', 'WEOB1']
# 64.68082277827105
# 0.7472831882092095
# ['sea_P(y)', 2, 'incremental', 'OOB']
# 64.62944415175681
# 0.6959045616949737
# ['sea_P(y)', 2, 'incremental', 'ESOS_ELM']
# 61.12691659804703
# -2.806622992014809
# ['sea_P(y)', 2, 'incremental', 'improved_UOB']
# 64.57212479222073
# 0.6385852021588931
# ['sea_P(y)', 2, 'incremental', 'WEOB2']
# 64.36496512857023
# 0.4314255385083925
# ['sea_P(y)', 2, 'incremental', 'UOB']
# 64.5698342623623
# 0.6362946723004654
# ['sea_P(y)', 2, 'incremental', 'CSMOTE']
# 62.49109125835164
# -1.442448331710203
# ['sea_P(y)', 2, 'incremental', 'RebalanceStream']
# 64.30799002610239
# 0.3744504360405472
# ['sea_P(y)', 4, 'incremental', 'improved_OOB']
# 64.65351408472245
# 0.5354680265798919
# ['sea_P(y)', 4, 'incremental', 'WEOB1']
# 64.68236628796919
# 0.5643202298266345
# ['sea_P(y)', 4, 'incremental', 'OOB']
# 64.60089044393153
# 0.4828443857889795
# ['sea_P(y)', 4, 'incremental', 'ESOS_ELM']
# 61.13721489626764
# -2.98083116187491
# ['sea_P(y)', 4, 'incremental', 'improved_UOB']
# 64.60630170720034
# 0.4882556490577912
# ['sea_P(y)', 4, 'incremental', 'WEOB2']
# 64.40907044473684
# 0.2910243865942874
# ['sea_P(y)', 4, 'incremental', 'UOB']
# 64.56720159702652
# 0.4491555388839714
# ['sea_P(y)', 4, 'incremental', 'CSMOTE']
# 64.1254178323287
# 0.007371774186140101
# ['sea_P(y)', 4, 'incremental', 'RebalanceStream']
# 64.28043722909976
# 0.162391170957207
# ['sea_P(y)', 4, 'sudden', 'improved_OOB']
# 64.63466517954751
# 0.5452093664941629
# ['sea_P(y)', 4, 'sudden', 'WEOB1']
# 64.66388563446131
# 0.5744298214079606
# ['sea_P(y)', 4, 'sudden', 'OOB']
# 64.58533110460186
# 0.49587529154851495
# ['sea_P(y)', 4, 'sudden', 'ESOS_ELM']
# 61.00305220595396
# -3.0864036070993848
# ['sea_P(y)', 4, 'sudden', 'improved_UOB']
# 64.5830067841266
# 0.4935509710732475
# ['sea_P(y)', 4, 'sudden', 'WEOB2']
# 64.37238846420993
# 0.2829326511565853
# ['sea_P(y)', 4, 'sudden', 'UOB']
# 64.57589343841664
# 0.48643762536329405
# ['sea_P(y)', 4, 'sudden', 'CSMOTE']
# 64.1251676874541
# 0.035711874400746524
# ['sea_P(y)', 4, 'sudden', 'RebalanceStream']
# 64.26171181870824
# 0.1722560056548872
# ['sea_P(y_x)', 1, 'sudden', 'improved_OOB']
# 63.54889262155267
# 2.0691079620230255
# ['sea_P(y_x)', 1, 'sudden', 'WEOB1']
# 63.37459605872808
# 1.8948113991984386
# ['sea_P(y_x)', 1, 'sudden', 'OOB']
# 63.867360482744026
# 2.3875758232143838
# ['sea_P(y_x)', 1, 'sudden', 'ESOS_ELM']
# 60.087345383046
# -1.3924392764836426
# ['sea_P(y_x)', 1, 'sudden', 'improved_UOB']
# 61.98413367823448
# 0.5043490187048363
# ['sea_P(y_x)', 1, 'sudden', 'WEOB2']
# 61.43358522896673
# -0.046199430562914756
# ['sea_P(y_x)', 1, 'sudden', 'UOB']
# 62.014441313778164
# 0.534656654248522
# ['sea_P(y_x)', 1, 'sudden', 'CSMOTE']
# 61.0480321300498
# -0.4317525294798443
# ['sea_P(y_x)', 1, 'sudden', 'RebalanceStream']
# 55.95967503866681
# -5.520109620862833
# ['sea_P(y_x)', 1, 'incremental', 'improved_OOB']
# 63.390590062854
# 1.8654564377440224
# ['sea_P(y_x)', 1, 'incremental', 'WEOB1']
# 63.33871261093236
# 1.8135789858223816
# ['sea_P(y_x)', 1, 'incremental', 'OOB']
# 63.65189038348458
# 2.126756758374597
# ['sea_P(y_x)', 1, 'incremental', 'ESOS_ELM']
# 60.09462192222558
# -1.4305117028844023
# ['sea_P(y_x)', 1, 'incremental', 'improved_UOB']
# 62.149007062642475
# 0.6238734375324952
# ['sea_P(y_x)', 1, 'incremental', 'WEOB2']
# 61.71113312324068
# 0.18599949813069827
# ['sea_P(y_x)', 1, 'incremental', 'UOB']
# 62.308710119952345
# 0.7835764948423645
# ['sea_P(y_x)', 1, 'incremental', 'CSMOTE']
# 60.92249385958485
# -0.602639765525133
# ['sea_P(y_x)', 1, 'incremental', 'RebalanceStream']
# 56.159043481072956
# -5.366090144037024
# ['sea_P(y_x)', 3, 'incremental', 'improved_OOB']
# 64.03796350701904
# 0.9794535308409777
# ['sea_P(y_x)', 3, 'incremental', 'WEOB1']
# 63.9545374247282
# 0.8960274485501358
# ['sea_P(y_x)', 3, 'incremental', 'OOB']
# 64.17477256120152
# 1.1162625850234562
# ['sea_P(y_x)', 3, 'incremental', 'ESOS_ELM']
# 60.32608516237677
# -2.7324248138012948
# ['sea_P(y_x)', 3, 'incremental', 'improved_UOB']
# 63.52655165470942
# 0.4680416785313568
# ['sea_P(y_x)', 3, 'incremental', 'WEOB2']
# 62.30077330893486
# -0.7577366672432078
# ['sea_P(y_x)', 3, 'incremental', 'UOB']
# 63.28667129814139
# 0.22816132196332717
# ['sea_P(y_x)', 3, 'incremental', 'CSMOTE']
# 63.44295615171192
# 0.38444617553385285
# ['sea_P(y_x)', 3, 'incremental', 'RebalanceStream']
# 62.47627871677944
# -0.5822312593986254
# ['sea_P(y_x)', 3, 'sudden', 'improved_OOB']
# 64.00416372956147
# 1.026350451792041
# ['sea_P(y_x)', 3, 'sudden', 'WEOB1']
# 63.883551415548574
# 0.9057381377791458
# ['sea_P(y_x)', 3, 'sudden', 'OOB']
# 64.21475160664808
# 1.2369383288786509
# ['sea_P(y_x)', 3, 'sudden', 'ESOS_ELM']
# 60.19562462799426
# -2.782188649775165
# ['sea_P(y_x)', 3, 'sudden', 'improved_UOB']
# 63.38994338332768
# 0.4121301055582549
# ['sea_P(y_x)', 3, 'sudden', 'WEOB2']
# 61.957002688330746
# -1.0208105894386819
# ['sea_P(y_x)', 3, 'sudden', 'UOB']
# 63.146542419006764
# 0.1687291412373355
# ['sea_P(y_x)', 3, 'sudden', 'CSMOTE']
# 63.53477261763591
# 0.5569593398664807
# ['sea_P(y_x)', 3, 'sudden', 'RebalanceStream']
# 62.47396701187141
# -0.5038462658980194
# ['sea_P(y_x)', 2, 'sudden', 'improved_OOB']
# 64.00450705155751
# 1.651819407590672
# ['sea_P(y_x)', 2, 'sudden', 'WEOB1']
# 63.877742299695434
# 1.5250546557285958
# ['sea_P(y_x)', 2, 'sudden', 'OOB']
# 64.14914692160153
# 1.796459277634689
# ['sea_P(y_x)', 2, 'sudden', 'ESOS_ELM']
# 60.066733519181675
# -2.285954124785164
# ['sea_P(y_x)', 2, 'sudden', 'improved_UOB']
# 63.13420838441581
# 0.7815207404489684
# ['sea_P(y_x)', 2, 'sudden', 'WEOB2']
# 61.81625156771819
# -0.5364360762486484
# ['sea_P(y_x)', 2, 'sudden', 'UOB']
# 62.88944886569484
# 0.5367612217279998
# ['sea_P(y_x)', 2, 'sudden', 'CSMOTE']
# 62.79959442303971
# 0.4469067790728687
# ['sea_P(y_x)', 2, 'sudden', 'RebalanceStream']
# 58.43655576279688
# -3.91613188116996
# ['sea_P(y_x)', 2, 'incremental', 'improved_OOB']
# 64.03737124640068
# 1.5728085875818536
# ['sea_P(y_x)', 2, 'incremental', 'WEOB1']
# 63.914591785923236
# 1.4500291271044077
# ['sea_P(y_x)', 2, 'incremental', 'OOB']
# 64.3060751062001
# 1.8415124473812696
# ['sea_P(y_x)', 2, 'incremental', 'ESOS_ELM']
# 60.29045976089765
# -2.1741028979211805
# ['sea_P(y_x)', 2, 'incremental', 'improved_UOB']
# 63.20921075154521
# 0.7446480927263792
# ['sea_P(y_x)', 2, 'incremental', 'WEOB2']
# 62.31004521301975
# -0.15451744579907967
# ['sea_P(y_x)', 2, 'incremental', 'UOB']
# 62.92722233121181
# 0.4626596723929808
# ['sea_P(y_x)', 2, 'incremental', 'CSMOTE']
# 62.40054618743922
# -0.06401647137960964
# ['sea_P(y_x)', 2, 'incremental', 'RebalanceStream']
# 58.78554154673176
# -3.679021112087071
# ['sea_P(y_x)', 4, 'incremental', 'improved_OOB']
# 64.01392742057723
# 0.7862354060629855
# ['sea_P(y_x)', 4, 'incremental', 'WEOB1']
# 63.988546774525844
# 0.7608547600115969
# ['sea_P(y_x)', 4, 'incremental', 'OOB']
# 64.18460768291088
# 0.9569156683966327
# ['sea_P(y_x)', 4, 'incremental', 'ESOS_ELM']
# 60.34515626608832
# -2.88253574842593
# ['sea_P(y_x)', 4, 'incremental', 'improved_UOB']
# 63.82714337195652
# 0.5994513574422697
# ['sea_P(y_x)', 4, 'incremental', 'WEOB2']
# 62.001761451191626
# -1.2259305633226205
# ['sea_P(y_x)', 4, 'incremental', 'UOB']
# 63.6514760206343
# 0.4237840061200515
# ['sea_P(y_x)', 4, 'incremental', 'CSMOTE']
# 63.61304295977421
# 0.38535094525996527
# ['sea_P(y_x)', 4, 'incremental', 'RebalanceStream']
# 63.42356618296925
# 0.19587416845500627
# ['sea_P(y_x)', 4, 'sudden', 'improved_OOB']
# 63.989133666975114
# 0.7794028338429655
# ['sea_P(y_x)', 4, 'sudden', 'WEOB1']
# 63.94152232214269
# 0.7317914890105399
# ['sea_P(y_x)', 4, 'sudden', 'OOB']
# 64.28308252666588
# 1.0733516935337306
# ['sea_P(y_x)', 4, 'sudden', 'ESOS_ELM']
# 60.306060585840896
# -2.9036702472912523
# ['sea_P(y_x)', 4, 'sudden', 'improved_UOB']
# 63.74049345398871
# 0.5307626208565637
# ['sea_P(y_x)', 4, 'sudden', 'WEOB2']
# 61.484281175874266
# -1.725449657257883
# ['sea_P(y_x)', 4, 'sudden', 'UOB']
# 63.784296119017334
# 0.5745652858851855
# ['sea_P(y_x)', 4, 'sudden', 'CSMOTE']
# 63.81197066930391
# 0.602239836171762
# ['sea_P(y_x)', 4, 'sudden', 'RebalanceStream']
# 63.546736978380544
# 0.33700614524839523
# ['sea_P(x_y)', 1, 'sudden', 'improved_OOB']
# 64.45155987458746
# 1.7266506209371926
# ['sea_P(x_y)', 1, 'sudden', 'WEOB1']
# 64.68626334012706
# 1.9613540864767884
# ['sea_P(x_y)', 1, 'sudden', 'OOB']
# 64.56978108288153
# 1.8448718292312662
# ['sea_P(x_y)', 1, 'sudden', 'ESOS_ELM']
# 61.17870686868997
# -1.5462023849602957
# ['sea_P(x_y)', 1, 'sudden', 'improved_UOB']
# 63.537858214903814
# 0.8129489612535465
# ['sea_P(x_y)', 1, 'sudden', 'WEOB2']
# 62.71346502021631
# -0.01144423343395573
# ['sea_P(x_y)', 1, 'sudden', 'UOB']
# 63.33519686335281
# 0.6102876097025458
# ['sea_P(x_y)', 1, 'sudden', 'CSMOTE']
# 62.54255515856006
# -0.18235409509020428
# ['sea_P(x_y)', 1, 'sudden', 'RebalanceStream']
# 57.508796859533426
# -5.216112394116841
# ['sea_P(x_y)', 1, 'incremental', 'improved_OOB']
# 64.41401701932139
# 1.4814285215248901
# ['sea_P(x_y)', 1, 'incremental', 'WEOB1']
# 64.68236842135505
# 1.749779923558549
# ['sea_P(x_y)', 1, 'incremental', 'OOB']
# 64.68070462727323
# 1.7481161294767276
# ['sea_P(x_y)', 1, 'incremental', 'ESOS_ELM']
# 61.45679708218891
# -1.4757914156075884
# ['sea_P(x_y)', 1, 'incremental', 'improved_UOB']
# 63.74403062156599
# 0.8114421237694884
# ['sea_P(x_y)', 1, 'incremental', 'WEOB2']
# 63.6130501428493
# 0.6804616450528016
# ['sea_P(x_y)', 1, 'incremental', 'UOB']
# 63.72434516509005
# 0.7917566672935479
# ['sea_P(x_y)', 1, 'incremental', 'CSMOTE']
# 62.28720019815322
# -0.6453882996432796
# ['sea_P(x_y)', 1, 'incremental', 'RebalanceStream']
# 57.790783202371394
# -5.141805295425108
# ['sea_P(x_y)', 3, 'incremental', 'improved_OOB']
# 64.71079857294083
# 0.7035485088284474
# ['sea_P(x_y)', 3, 'incremental', 'WEOB1']
# 64.65806689172474
# 0.6508168276123598
# ['sea_P(x_y)', 3, 'incremental', 'OOB']
# 64.80928150092318
# 0.8020314368107933
# ['sea_P(x_y)', 3, 'incremental', 'ESOS_ELM']
# 61.49896285151325
# -2.508287212599136
# ['sea_P(x_y)', 3, 'incremental', 'improved_UOB']
# 64.30281372587513
# 0.29556366176274196
# ['sea_P(x_y)', 3, 'incremental', 'WEOB2']
# 63.71503297744657
# -0.2922170866658149
# ['sea_P(x_y)', 3, 'incremental', 'UOB']
# 64.01204890021805
# 0.004798836105663895
# ['sea_P(x_y)', 3, 'incremental', 'CSMOTE']
# 64.50274140467221
# 0.49549134055982336
# ['sea_P(x_y)', 3, 'incremental', 'RebalanceStream']
# 63.85550375169752
# -0.1517463124148648
# ['sea_P(x_y)', 3, 'sudden', 'improved_OOB']
# 64.6638295350649
# 0.8126535998602904
# ['sea_P(x_y)', 3, 'sudden', 'WEOB1']
# 64.56850053163973
# 0.7173245964351125
# ['sea_P(x_y)', 3, 'sudden', 'OOB']
# 64.8868622852044
# 1.0356863499997857
# ['sea_P(x_y)', 3, 'sudden', 'ESOS_ELM']
# 60.76874872277531
# -3.082427212429309
# ['sea_P(x_y)', 3, 'sudden', 'improved_UOB']
# 64.23081546300716
# 0.37963952780254573
# ['sea_P(x_y)', 3, 'sudden', 'WEOB2']
# 64.06906775730633
# 0.21789182210171276
# ['sea_P(x_y)', 3, 'sudden', 'UOB']
# 64.07453232982297
# 0.22335639461835655
# ['sea_P(x_y)', 3, 'sudden', 'CSMOTE']
# 64.49828746885689
# 0.6471115336522715
# ['sea_P(x_y)', 3, 'sudden', 'RebalanceStream']
# 62.899939323163856
# -0.9512366120407592
# ['sea_P(x_y)', 2, 'sudden', 'improved_OOB']
# 64.606502871951
# 1.0622381338134446
# ['sea_P(x_y)', 2, 'sudden', 'WEOB1']
# 64.61681737091695
# 1.0725526327793986
# ['sea_P(x_y)', 2, 'sudden', 'OOB']
# 64.8856315059793
# 1.3413667678417553
# ['sea_P(x_y)', 2, 'sudden', 'ESOS_ELM']
# 60.68363373907598
# -2.86063099906157
# ['sea_P(x_y)', 2, 'sudden', 'improved_UOB']
# 64.27879645359462
# 0.7345317154570736
# ['sea_P(x_y)', 2, 'sudden', 'WEOB2']
# 63.64490766416949
# 0.10064292603193792
# ['sea_P(x_y)', 2, 'sudden', 'UOB']
# 64.1256793023388
# 0.5814145642012463
# ['sea_P(x_y)', 2, 'sudden', 'CSMOTE']
# 62.704027200919754
# -0.8402375372177957
# ['sea_P(x_y)', 2, 'sudden', 'RebalanceStream']
# 62.35238653429199
# -1.1918782038455618
# ['sea_P(x_y)', 2, 'incremental', 'improved_OOB']
# 64.72670304805885
# 0.9170405414563518
# ['sea_P(x_y)', 2, 'incremental', 'WEOB1']
# 64.738541451972
# 0.9288789453694974
# ['sea_P(x_y)', 2, 'incremental', 'OOB']
# 64.8543771487874
# 1.044714642184907
# ['sea_P(x_y)', 2, 'incremental', 'ESOS_ELM']
# 61.47018221357642
# -2.339480293026078
# ['sea_P(x_y)', 2, 'incremental', 'improved_UOB']
# 64.22207887171643
# 0.4124163651139341
# ['sea_P(x_y)', 2, 'incremental', 'WEOB2']
# 63.606985100612896
# -0.20267740598960415
# ['sea_P(x_y)', 2, 'incremental', 'UOB']
# 64.05433996049575
# 0.24467745389325302
# ['sea_P(x_y)', 2, 'incremental', 'CSMOTE']
# 63.365476406111426
# -0.44418610049107343
# ['sea_P(x_y)', 2, 'incremental', 'RebalanceStream']
# 63.248278358091305
# -0.5613841485111948
# ['sea_P(x_y)', 4, 'incremental', 'improved_OOB']
# 64.50834949836045
# 0.6191023407707021
# ['sea_P(x_y)', 4, 'incremental', 'WEOB1']
# 64.45210375327176
# 0.562856595682014
# ['sea_P(x_y)', 4, 'incremental', 'OOB']
# 64.61270090855828
# 0.7234537509685381
# ['sea_P(x_y)', 4, 'incremental', 'ESOS_ELM']
# 61.35815104385284
# -2.5310961137369006
# ['sea_P(x_y)', 4, 'incremental', 'improved_UOB']
# 64.28569471423812
# 0.3964475566483756
# ['sea_P(x_y)', 4, 'incremental', 'WEOB2']
# 63.31820549499165
# -0.5710416625980912
# ['sea_P(x_y)', 4, 'incremental', 'UOB']
# 63.741756811259926
# -0.1474903463298176
# ['sea_P(x_y)', 4, 'incremental', 'CSMOTE']
# 64.4630724709406
# 0.5738253133508593
# ['sea_P(x_y)', 4, 'incremental', 'RebalanceStream']
# 64.26318972283403
# 0.3739425652442847
# ['sea_P(x_y)', 4, 'sudden', 'improved_OOB']
# 64.53613840787742
# 0.6049175445886164
# ['sea_P(x_y)', 4, 'sudden', 'WEOB1']
# 64.48800681213663
# 0.556785948847832
# ['sea_P(x_y)', 4, 'sudden', 'OOB']
# 64.87327849749587
# 0.9420576342070746
# ['sea_P(x_y)', 4, 'sudden', 'ESOS_ELM']
# 60.64606312660002
# -3.285157736688781
# ['sea_P(x_y)', 4, 'sudden', 'improved_UOB']
# 64.275923607541
# 0.3447027442522028
# ['sea_P(x_y)', 4, 'sudden', 'WEOB2']
# 64.02276092279774
# 0.09154005950894373
# ['sea_P(x_y)', 4, 'sudden', 'UOB']
# 63.96318752088323
# 0.03196665759443107
# ['sea_P(x_y)', 4, 'sudden', 'CSMOTE']
# 64.48747065871729
# 0.5562497954284851
# ['sea_P(x_y)', 4, 'sudden', 'RebalanceStream']
# 64.08815821555008
# 0.1569373522612807
# ['sine_P(y)', 4, 'incremental', 'improved_OOB']
# 70.40739719825709
# 0.5958133417084781
# ['sine_P(y)', 4, 'incremental', 'WEOB1']
# 70.40139315245825
# 0.5898092959096459
# ['sine_P(y)', 4, 'incremental', 'OOB']
# 70.35740360068534
# 0.5458197441367361
# ['sine_P(y)', 4, 'incremental', 'ESOS_ELM']
# 65.66472448896522
# -4.146859367583389
# ['sine_P(y)', 4, 'incremental', 'improved_UOB']
# 70.3401675434582
# 0.5285836869095846
# ['sine_P(y)', 4, 'incremental', 'WEOB2']
# 70.32583325260615
# 0.5142493960575365
# ['sine_P(y)', 4, 'incremental', 'UOB']
# 70.35740360068534
# 0.5458197441367361
# ['sine_P(y)', 4, 'incremental', 'CSMOTE']
# 70.23195682581878
# 0.42037296927017564
# ['sine_P(y)', 4, 'incremental', 'RebalanceStream']
# 70.21797504600305
# 0.406391189454439
# ['sine_P(y)', 4, 'sudden', 'improved_OOB']
# 70.38608293976185
# 0.6095064698887427
# ['sine_P(y)', 4, 'sudden', 'WEOB1']
# 70.38552894288361
# 0.608952473010504
# ['sine_P(y)', 4, 'sudden', 'OOB']
# 70.34231360008266
# 0.5657371302095555
# ['sine_P(y)', 4, 'sudden', 'ESOS_ELM']
# 65.46640787428781
# -4.310168595585296
# ['sine_P(y)', 4, 'sudden', 'improved_UOB']
# 70.32622991752399
# 0.5496534476508828
# ['sine_P(y)', 4, 'sudden', 'WEOB2']
# 70.30346378625703
# 0.5268873163839203
# ['sine_P(y)', 4, 'sudden', 'UOB']
# 70.34231360008266
# 0.5657371302095555
# ['sine_P(y)', 4, 'sudden', 'CSMOTE']
# 70.22444345535584
# 0.44786698548273307
# ['sine_P(y)', 4, 'sudden', 'RebalanceStream']
# 70.21240411262262
# 0.4358276427495156
# ['sine_P(y)', 3, 'sudden', 'improved_OOB']
# 70.38338266813015
# 0.7385602558540114
# ['sine_P(y)', 3, 'sudden', 'WEOB1']
# 70.36151901756821
# 0.7166966052920714
# ['sine_P(y)', 3, 'sudden', 'OOB']
# 70.26861419065791
# 0.6237917783817721
# ['sine_P(y)', 3, 'sudden', 'ESOS_ELM']
# 65.42750282007185
# -4.217319592204291
# ['sine_P(y)', 3, 'sudden', 'improved_UOB']
# 70.22524195395758
# 0.5804195416814366
# ['sine_P(y)', 3, 'sudden', 'WEOB2']
# 70.17325246240259
# 0.5284300501264454
# ['sine_P(y)', 3, 'sudden', 'UOB']
# 70.26861419065791
# 0.6237917783817721
# ['sine_P(y)', 3, 'sudden', 'CSMOTE']
# 70.0928403052749
# 0.44801789299876305
# ['sine_P(y)', 3, 'sudden', 'RebalanceStream']
# 69.6024341017642
# -0.0423883105119387
# ['sine_P(y)', 3, 'incremental', 'improved_OOB']
# 70.38872265964355
# 0.6382287309481001
# ['sine_P(y)', 3, 'incremental', 'WEOB1']
# 70.37432714762694
# 0.6238332189314946
# ['sine_P(y)', 3, 'incremental', 'OOB']
# 70.28889425035447
# 0.5384003216590258
# ['sine_P(y)', 3, 'incremental', 'ESOS_ELM']
# 65.5965815522156
# -4.153912376479852
# ['sine_P(y)', 3, 'incremental', 'improved_UOB']
# 70.2409756946971
# 0.4904817660016505
# ['sine_P(y)', 3, 'incremental', 'WEOB2']
# 70.18765409468187
# 0.4371601659864268
# ['sine_P(y)', 3, 'incremental', 'UOB']
# 70.28889425035447
# 0.5384003216590258
# ['sine_P(y)', 3, 'incremental', 'CSMOTE']
# 70.26799428987394
# 0.5175003611784916
# ['sine_P(y)', 3, 'incremental', 'RebalanceStream']
# 70.12040141881099
# 0.36990749011553703
# ['sine_P(y)', 1, 'sudden', 'improved_OOB']
# 70.14380498495623
# 1.105206656441041
# ['sine_P(y)', 1, 'sudden', 'WEOB1']
# 70.17449584809401
# 1.135897519578819
# ['sine_P(y)', 1, 'sudden', 'OOB']
# 70.10988785593635
# 1.0712895274211576
# ['sine_P(y)', 1, 'sudden', 'ESOS_ELM']
# 65.10610815713855
# -3.9324901713766423
# ['sine_P(y)', 1, 'sudden', 'improved_UOB']
# 69.79024367902143
# 0.7516453505062373
# ['sine_P(y)', 1, 'sudden', 'WEOB2']
# 69.83506268354269
# 0.7964643550274957
# ['sine_P(y)', 1, 'sudden', 'UOB']
# 69.69341403818115
# 0.6548157096659537
# ['sine_P(y)', 1, 'sudden', 'CSMOTE']
# 68.74831623941091
# -0.29028208910428077
# ['sine_P(y)', 1, 'sudden', 'RebalanceStream']
# 67.74605147035535
# -1.292546858159838
# ['sine_P(y)', 1, 'incremental', 'improved_OOB']
# 70.18442086728555
# 0.9631588973692118
# ['sine_P(y)', 1, 'incremental', 'WEOB1']
# 70.21376481982637
# 0.992502849910025
# ['sine_P(y)', 1, 'incremental', 'OOB']
# 70.14057977126849
# 0.9193178013521504
# ['sine_P(y)', 1, 'incremental', 'ESOS_ELM']
# 65.39259454903186
# -3.8286674208844858
# ['sine_P(y)', 1, 'incremental', 'improved_UOB']
# 69.87343906701253
# 0.6521770970961853
# ['sine_P(y)', 1, 'incremental', 'WEOB2']
# 69.88675660509111
# 0.6654946351747668
# ['sine_P(y)', 1, 'incremental', 'UOB']
# 69.82625100436822
# 0.6049890344518758
# ['sine_P(y)', 1, 'incremental', 'CSMOTE']
# 69.00886987889722
# -0.21239209101912593
# ['sine_P(y)', 1, 'incremental', 'RebalanceStream']
# 68.46468116646568
# -0.7565808034506603
# ['sine_P(y)', 2, 'incremental', 'improved_OOB']
# 70.35071972023249
# 0.8335851640787268
# ['sine_P(y)', 2, 'incremental', 'WEOB1']
# 70.32899195614696
# 0.8118573999932011
# ['sine_P(y)', 2, 'incremental', 'OOB']
# 70.36901144719772
# 0.8518768910439576
# ['sine_P(y)', 2, 'incremental', 'ESOS_ELM']
# 65.5323445268153
# -3.9847900293384697
# ['sine_P(y)', 2, 'incremental', 'improved_UOB']
# 70.1151874545044
# 0.5980528983506304
# ['sine_P(y)', 2, 'incremental', 'WEOB2']
# 70.03297150779474
# 0.5158369516409778
# ['sine_P(y)', 2, 'incremental', 'UOB']
# 70.07760967468087
# 0.5604751185271084
# ['sine_P(y)', 2, 'incremental', 'CSMOTE']
# 69.78482182092344
# 0.26768726476967686
# ['sine_P(y)', 2, 'incremental', 'RebalanceStream']
# 69.06255289708803
# -0.4545816590657381
# ['sine_P(y)', 2, 'sudden', 'improved_OOB']
# 70.3397625621727
# 0.8838102339721843
# ['sine_P(y)', 2, 'sudden', 'WEOB1']
# 70.32683808191896
# 0.8708857537184542
# ['sine_P(y)', 2, 'sudden', 'OOB']
# 70.36621982572902
# 0.9102674975285083
# ['sine_P(y)', 2, 'sudden', 'ESOS_ELM']
# 65.31448389058772
# -4.141468437612787
# ['sine_P(y)', 2, 'sudden', 'improved_UOB']
# 70.11266879272235
# 0.6567164645218355
# ['sine_P(y)', 2, 'sudden', 'WEOB2']
# 70.02291155408605
# 0.5669592258855403
# ['sine_P(y)', 2, 'sudden', 'UOB']
# 70.07535874366587
# 0.6194064154653631
# ['sine_P(y)', 2, 'sudden', 'CSMOTE']
# 69.4841854494205
# 0.02823312121998356
# ['sine_P(y)', 2, 'sudden', 'RebalanceStream']
# 69.06114205350137
# -0.39481027469913954
# ['sine_P(y_x)', 4, 'incremental', 'improved_OOB']
# 68.59553342150991
# 1.7893123286855825
# ['sine_P(y_x)', 4, 'incremental', 'WEOB1']
# 68.61008602231355
# 1.8038649294892224
# ['sine_P(y_x)', 4, 'incremental', 'OOB']
# 68.53587496909363
# 1.7296538762692961
# ['sine_P(y_x)', 4, 'incremental', 'ESOS_ELM']
# 64.10077588248326
# -2.705445210341068
# ['sine_P(y_x)', 4, 'incremental', 'improved_UOB']
# 68.50161256117687
# 1.6953914683525397
# ['sine_P(y_x)', 4, 'incremental', 'WEOB2']
# 58.4916038710238
# -8.314617221800532
# ['sine_P(y_x)', 4, 'incremental', 'UOB']
# 68.2027188094709
# 1.3964977166465644
# ['sine_P(y_x)', 4, 'incremental', 'CSMOTE']
# 68.0480317920366
# 1.241810699212266
# ['sine_P(y_x)', 4, 'incremental', 'RebalanceStream']
# 68.16975250631046
# 1.363531413486129
# ['sine_P(y_x)', 4, 'sudden', 'improved_OOB']
# 69.93298490994212
# 1.6006750976085584
# ['sine_P(y_x)', 4, 'sudden', 'WEOB1']
# 69.92375018538732
# 1.5914403730537572
# ['sine_P(y_x)', 4, 'sudden', 'OOB']
# 69.7587131831034
# 1.4264033707698331
# ['sine_P(y_x)', 4, 'sudden', 'ESOS_ELM']
# 62.855831216530646
# -5.4764785958029165
# ['sine_P(y_x)', 4, 'sudden', 'improved_UOB']
# 69.68243483004635
# 1.3501250177127844
# ['sine_P(y_x)', 4, 'sudden', 'WEOB2']
# 64.08284118159713
# -4.24946863073643
# ['sine_P(y_x)', 4, 'sudden', 'UOB']
# 69.7587131831034
# 1.4264033707698331
# ['sine_P(y_x)', 4, 'sudden', 'CSMOTE']
# 69.24814481438966
# 0.9158350020560988
# ['sine_P(y_x)', 4, 'sudden', 'RebalanceStream']
# 69.74737480690206
# 1.415064994568496
# ['sine_P(y_x)', 3, 'sudden', 'improved_OOB']
# 69.9036260684112
# 1.6932887234808334
# ['sine_P(y_x)', 3, 'sudden', 'WEOB1']
# 69.82091456066723
# 1.6105772157368676
# ['sine_P(y_x)', 3, 'sudden', 'OOB']
# 69.90702219902799
# 1.6966848540976258
# ['sine_P(y_x)', 3, 'sudden', 'ESOS_ELM']
# 63.58178709448771
# -4.628550250442657
# ['sine_P(y_x)', 3, 'sudden', 'improved_UOB']
# 69.58078842405612
# 1.3704510791257576
# ['sine_P(y_x)', 3, 'sudden', 'WEOB2']
# 63.34833617151967
# -4.862001173410697
# ['sine_P(y_x)', 3, 'sudden', 'UOB']
# 69.41037993845052
# 1.200042593520152
# ['sine_P(y_x)', 3, 'sudden', 'CSMOTE']
# 68.89597778197347
# 0.6856404370431051
# ['sine_P(y_x)', 3, 'sudden', 'RebalanceStream']
# 69.4442038657794
# 1.233866520849034
# ['sine_P(y_x)', 3, 'incremental', 'improved_OOB']
# 68.66002663400113
# 1.9338469610054148
# ['sine_P(y_x)', 3, 'incremental', 'WEOB1']
# 68.6199183437869
# 1.893738670791194
# ['sine_P(y_x)', 3, 'incremental', 'OOB']
# 68.53084374916634
# 1.8046640761706243
# ['sine_P(y_x)', 3, 'incremental', 'ESOS_ELM']
# 63.534196586140375
# -3.1919830868553376
# ['sine_P(y_x)', 3, 'incremental', 'improved_UOB']
# 68.3604121130867
# 1.6342324400909831
# ['sine_P(y_x)', 3, 'incremental', 'WEOB2']
# 59.146351889172266
# -7.579827783823447
# ['sine_P(y_x)', 3, 'incremental', 'UOB']
# 68.12843679302229
# 1.4022571200265759
# ['sine_P(y_x)', 3, 'incremental', 'CSMOTE']
# 67.60391396198045
# 0.8777342889847404
# ['sine_P(y_x)', 3, 'incremental', 'RebalanceStream']
# 67.95151698660496
# 1.225337313609245
# ['sine_P(y_x)', 1, 'sudden', 'improved_OOB']
# 69.57487656219105
# 3.184071603392468
# ['sine_P(y_x)', 1, 'sudden', 'WEOB1']
# 69.62849768942536
# 3.237692730626776
# ['sine_P(y_x)', 1, 'sudden', 'OOB']
# 69.59299009228428
# 3.202185133485699
# ['sine_P(y_x)', 1, 'sudden', 'ESOS_ELM']
# 64.24466290437579
# -2.1461420544227963
# ['sine_P(y_x)', 1, 'sudden', 'improved_UOB']
# 67.62426876846123
# 1.233463809662652
# ['sine_P(y_x)', 1, 'sudden', 'WEOB2']
# 57.07454087884595
# -9.316264079952632
# ['sine_P(y_x)', 1, 'sudden', 'UOB']
# 66.54521874119715
# 0.15441378239856363
# ['sine_P(y_x)', 1, 'sudden', 'CSMOTE']
# 65.64973992242585
# -0.7410650363727314
# ['sine_P(y_x)', 1, 'sudden', 'RebalanceStream']
# 67.58244906998064
# 1.1916441111820575
# ['sine_P(y_x)', 1, 'incremental', 'improved_OOB']
# 68.13716292034697
# 3.186033784343806
# ['sine_P(y_x)', 1, 'incremental', 'WEOB1']
# 68.20133878552824
# 3.2502096495250754
# ['sine_P(y_x)', 1, 'incremental', 'OOB']
# 68.21585163721019
# 3.2647225012070322
# ['sine_P(y_x)', 1, 'incremental', 'ESOS_ELM']
# 64.08582388223773
# -0.8653052537654276
# ['sine_P(y_x)', 1, 'incremental', 'improved_UOB']
# 66.64112656951508
# 1.6899974335119197
# ['sine_P(y_x)', 1, 'incremental', 'WEOB2']
# 54.083256010429444
# -10.867873125573716
# ['sine_P(y_x)', 1, 'incremental', 'UOB']
# 66.25668354688892
# 1.3055544108857617
# ['sine_P(y_x)', 1, 'incremental', 'CSMOTE']
# 64.83150986568225
# -0.11961927032091069
# ['sine_P(y_x)', 1, 'incremental', 'RebalanceStream']
# 64.10740900618967
# -0.8437201298134909
# ['sine_P(y_x)', 2, 'incremental', 'improved_OOB']
# 68.54082055289254
# 2.5005507971605567
# ['sine_P(y_x)', 2, 'incremental', 'WEOB1']
# 68.49456310186943
# 2.4542933461374474
# ['sine_P(y_x)', 2, 'incremental', 'OOB']
# 68.62873412712284
# 2.588464371390856
# ['sine_P(y_x)', 2, 'incremental', 'ESOS_ELM']
# 63.716500587552616
# -2.3237691681793677
# ['sine_P(y_x)', 2, 'incremental', 'improved_UOB']
# 68.03459630239777
# 1.9943265466657891
# ['sine_P(y_x)', 2, 'incremental', 'WEOB2']
# 56.01097016423587
# -10.029299591496112
# ['sine_P(y_x)', 2, 'incremental', 'UOB']
# 68.02761961941715
# 1.9873498636851679
# ['sine_P(y_x)', 2, 'incremental', 'CSMOTE']
# 66.82025334521606
# 0.7799835894840754
# ['sine_P(y_x)', 2, 'incremental', 'RebalanceStream']
# 66.08837000088349
# 0.04810024515150246
# ['sine_P(y_x)', 2, 'sudden', 'improved_OOB']
# 69.83214516369438
# 2.7092993618851295
# ['sine_P(y_x)', 2, 'sudden', 'WEOB1']
# 69.81130274339355
# 2.688456941584306
# ['sine_P(y_x)', 2, 'sudden', 'OOB']
# 69.97478795188472
# 2.851942150075473
# ['sine_P(y_x)', 2, 'sudden', 'ESOS_ELM']
# 63.84361399275416
# -3.2792318090550907
# ['sine_P(y_x)', 2, 'sudden', 'improved_UOB']
# 68.86077814415466
# 1.7379323423454167
# ['sine_P(y_x)', 2, 'sudden', 'WEOB2']
# 56.32467009808211
# -10.79817570372714
# ['sine_P(y_x)', 2, 'sudden', 'UOB']
# 68.6127836548033
# 1.4899378529940464
# ['sine_P(y_x)', 2, 'sudden', 'CSMOTE']
# 68.03537526110287
# 0.9125294592936228
# ['sine_P(y_x)', 2, 'sudden', 'RebalanceStream']
# 68.81015520641344
# 1.6873094046041928
# ['sine_P(x_y)', 4, 'incremental', 'improved_OOB']
# 70.41003315224181
# 0.6664296515250641
# ['sine_P(x_y)', 4, 'incremental', 'WEOB1']
# 70.38886759385375
# 0.6452640931370013
# ['sine_P(x_y)', 4, 'incremental', 'OOB']
# 70.39859358386032
# 0.6549900831435735
# ['sine_P(x_y)', 4, 'incremental', 'ESOS_ELM']
# 65.26195499185161
# -4.481648508865135
# ['sine_P(x_y)', 4, 'incremental', 'improved_UOB']
# 70.28820910441878
# 0.5446056037020384
# ['sine_P(x_y)', 4, 'incremental', 'WEOB2']
# 70.23177167871985
# 0.4881681780031073
# ['sine_P(x_y)', 4, 'incremental', 'UOB']
# 70.39859358386033
# 0.6549900831435878
# ['sine_P(x_y)', 4, 'incremental', 'CSMOTE']
# 70.22891975070885
# 0.48531624999210976
# ['sine_P(x_y)', 4, 'incremental', 'RebalanceStream']
# 70.08548806693531
# 0.34188456621856744
# ['sine_P(x_y)', 4, 'sudden', 'improved_OOB']
# 70.41624253310604
# 0.6350227375406234
# ['sine_P(x_y)', 4, 'sudden', 'WEOB1']
# 70.39413885326687
# 0.612919057701447
# ['sine_P(x_y)', 4, 'sudden', 'OOB']
# 70.40915997077278
# 0.6279401752073568
# ['sine_P(x_y)', 4, 'sudden', 'ESOS_ELM']
# 65.44535669600874
# -4.335863099556676
# ['sine_P(x_y)', 4, 'sudden', 'improved_UOB']
# 70.29929327034867
# 0.5180734747832503
# ['sine_P(x_y)', 4, 'sudden', 'WEOB2']
# 70.27750967966463
# 0.4962898840992125
# ['sine_P(x_y)', 4, 'sudden', 'UOB']
# 70.40915997077278
# 0.6279401752073568
# ['sine_P(x_y)', 4, 'sudden', 'CSMOTE']
# 70.2417241956787
# 0.46050440011327964
# ['sine_P(x_y)', 4, 'sudden', 'RebalanceStream']
# 70.13839299046957
# 0.3571731949041492
# ['sine_P(x_y)', 3, 'sudden', 'improved_OOB']
# 70.37207705623985
# 0.6487282696378713
# ['sine_P(x_y)', 3, 'sudden', 'WEOB1']
# 70.38846608195345
# 0.6651172953514788
# ['sine_P(x_y)', 3, 'sudden', 'OOB']
# 70.40098411320177
# 0.6776353265997983
# ['sine_P(x_y)', 3, 'sudden', 'ESOS_ELM']
# 65.4649617398985
# -4.258387046703476
# ['sine_P(x_y)', 3, 'sudden', 'improved_UOB']
# 70.25645339459155
# 0.5331046079895714
# ['sine_P(x_y)', 3, 'sudden', 'WEOB2']
# 70.21835240141368
# 0.49500361481170785
# ['sine_P(x_y)', 3, 'sudden', 'UOB']
# 70.1590560991533
# 0.43570731255132955
# ['sine_P(x_y)', 3, 'sudden', 'CSMOTE']
# 70.2107693712301
# 0.48742058462812565
# ['sine_P(x_y)', 3, 'sudden', 'RebalanceStream']
# 70.03901882173543
# 0.3156700351334507
# ['sine_P(x_y)', 3, 'incremental', 'improved_OOB']
# 70.35460750850152
# 0.672417218675875
# ['sine_P(x_y)', 3, 'incremental', 'WEOB1']
# 70.38943141390959
# 0.70724112408395
# ['sine_P(x_y)', 3, 'incremental', 'OOB']
# 70.39545430725352
# 0.7132640174278748
# ['sine_P(x_y)', 3, 'incremental', 'ESOS_ELM']
# 65.35274467207688
# -4.32944561774876
# ['sine_P(x_y)', 3, 'incremental', 'improved_UOB']
# 70.2477136421746
# 0.5655233523489613
# ['sine_P(x_y)', 3, 'incremental', 'WEOB2']
# 70.20205984049622
# 0.5198695506705775
# ['sine_P(x_y)', 3, 'incremental', 'UOB']
# 70.13434259538573
# 0.4521523055600909
# ['sine_P(x_y)', 3, 'incremental', 'CSMOTE']
# 70.22274824208098
# 0.540557952255341
# ['sine_P(x_y)', 3, 'incremental', 'RebalanceStream']
# 69.84061038655162
# 0.15842009672597612
# ['sine_P(x_y)', 1, 'sudden', 'improved_OOB']
# 70.08604996032076
# 0.9049736965642552
# ['sine_P(x_y)', 1, 'sudden', 'WEOB1']
# 70.19339333895172
# 1.012317075195213
# ['sine_P(x_y)', 1, 'sudden', 'OOB']
# 70.0861117253787
# 0.905035461622191
# ['sine_P(x_y)', 1, 'sudden', 'ESOS_ELM']
# 64.88354031726814
# -4.297535946488367
# ['sine_P(x_y)', 1, 'sudden', 'improved_UOB']
# 70.00861462694209
# 0.8275383631855817
# ['sine_P(x_y)', 1, 'sudden', 'WEOB2']
# 69.8195909666778
# 0.6385147029212845
# ['sine_P(x_y)', 1, 'sudden', 'UOB']
# 69.90378843317458
# 0.7227121694180738
# ['sine_P(x_y)', 1, 'sudden', 'CSMOTE']
# 68.58806653752461
# -0.5930097262318981
# ['sine_P(x_y)', 1, 'sudden', 'RebalanceStream']
# 69.06053046757015
# -0.12054579618636296
# ['sine_P(x_y)', 1, 'incremental', 'improved_OOB']
# 70.10139768812886
# 0.8606511968348229
# ['sine_P(x_y)', 1, 'incremental', 'WEOB1']
# 70.20790253404968
# 0.9671560427556471
# ['sine_P(x_y)', 1, 'incremental', 'OOB']
# 70.1255444367439
# 0.8847979454498613
# ['sine_P(x_y)', 1, 'incremental', 'ESOS_ELM']
# 65.1596372159435
# -4.081109275350528
# ['sine_P(x_y)', 1, 'incremental', 'improved_UOB']
# 70.06545681233055
# 0.8247103210365196
# ['sine_P(x_y)', 1, 'incremental', 'WEOB2']
# 69.85395266097191
# 0.6132061696778806
# ['sine_P(x_y)', 1, 'incremental', 'UOB']
# 69.95996926435326
# 0.7192227730592293
# ['sine_P(x_y)', 1, 'incremental', 'CSMOTE']
# 68.59060246320038
# -0.6501440280936492
# ['sine_P(x_y)', 1, 'incremental', 'RebalanceStream']
# 69.10225534592428
# -0.1384911453697555
# ['sine_P(x_y)', 2, 'incremental', 'improved_OOB']
# 70.35273505966595
# 0.7644178093254368
# ['sine_P(x_y)', 2, 'incremental', 'WEOB1']
# 70.36847085849608
# 0.7801536081555724
# ['sine_P(x_y)', 2, 'incremental', 'OOB']
# 70.37717215787652
# 0.7888549075360061
# ['sine_P(x_y)', 2, 'incremental', 'ESOS_ELM']
# 65.23807575879212
# -4.350241491548388
# ['sine_P(x_y)', 2, 'incremental', 'improved_UOB']
# 70.1758369770337
# 0.5875197266931877
# ['sine_P(x_y)', 2, 'incremental', 'WEOB2']
# 70.14729428137979
# 0.5589770310392765
# ['sine_P(x_y)', 2, 'incremental', 'UOB']
# 70.08179688236888
# 0.4934796320283681
# ['sine_P(x_y)', 2, 'incremental', 'CSMOTE']
# 69.70861750472656
# 0.12030025438605207
# ['sine_P(x_y)', 2, 'incremental', 'RebalanceStream']
# 69.84485577272508
# 0.25653852238457375
# ['sine_P(x_y)', 2, 'sudden', 'improved_OOB']
# 70.35665802131493
# 0.7273319055775715
# ['sine_P(x_y)', 2, 'sudden', 'WEOB1']
# 70.38132599725523
# 0.7519998815178752
# ['sine_P(x_y)', 2, 'sudden', 'OOB']
# 70.37649910377755
# 0.7471729880401909
# ['sine_P(x_y)', 2, 'sudden', 'ESOS_ELM']
# 65.3978194149569
# -4.231506700780457
# ['sine_P(x_y)', 2, 'sudden', 'improved_UOB']
# 70.17438225167874
# 0.5450561359413797
# ['sine_P(x_y)', 2, 'sudden', 'WEOB2']
# 70.15811843092912
# 0.5287923151917653
# ['sine_P(x_y)', 2, 'sudden', 'UOB']
# 70.0861833121186
# 0.4568571963812502
# ['sine_P(x_y)', 2, 'sudden', 'CSMOTE']
# 69.87705728340052
# 0.2477311676631615
# ['sine_P(x_y)', 2, 'sudden', 'RebalanceStream']
# 69.85589122620468
# 0.22656511046731964
# ['jitter', 1, 'incremental', 'improved_OOB']
# 65.54680798951384
# 2.3190545657854926
# ['jitter', 1, 'incremental', 'WEOB1']
# 65.97873469088998
# 2.7509812671616345
# ['jitter', 1, 'incremental', 'CSMOTE']
# 63.12492595289929
# -0.1028274708290553
# ['jitter', 1, 'incremental', 'OOB']
# 65.73554498836094
# 2.5077915646325977
# ['jitter', 1, 'incremental', 'ESOS_ELM']
# 60.627986340595996
# -2.599767083132349
# ['jitter', 1, 'incremental', 'improved_UOB']
# 64.57847189331599
# 1.3507184695876475
# ['jitter', 1, 'incremental', 'WEOB2']
# 64.46000559134856
# 1.2322521676202172
# ['jitter', 1, 'incremental', 'UOB']
# 64.47643472569294
# 1.248681301964595
# ['jitter', 1, 'incremental', 'RebalanceStream']
# 54.52086864093758
# -8.706884782790766
# ['jitter', 1, 'sudden', 'improved_OOB']
# 68.06786687849583
# 2.4590056202481065
# ['jitter', 1, 'sudden', 'WEOB1']
# 68.07209927270017
# 2.4632380144524433
# ['jitter', 1, 'sudden', 'CSMOTE']
# 65.08266301936467
# -0.5261982388830546
# ['jitter', 1, 'sudden', 'OOB']
# 68.06853102909277
# 2.4596697708450392
# ['jitter', 1, 'sudden', 'ESOS_ELM']
# 63.500754175705694
# -2.108107082542034
# ['jitter', 1, 'sudden', 'improved_UOB']
# 66.22416208604338
# 0.6153008277956502
# ['jitter', 1, 'sudden', 'WEOB2']
# 65.2869211400174
# -0.3219401182303301
# ['jitter', 1, 'sudden', 'UOB']
# 65.76155416824315
# 0.15269290999542307
# ['jitter', 1, 'sudden', 'RebalanceStream']
# 60.415199554566605
# -5.193661703681123
# ['jitter', 1, 'periodic', 'improved_OOB']
# 65.54680798951384
# 2.3487611098224264
# ['jitter', 1, 'periodic', 'WEOB1']
# 65.97873469088998
# 2.7806878111985682
# ['jitter', 1, 'periodic', 'CSMOTE']
# 63.12492595289929
# -0.07312092679212157
# ['jitter', 1, 'periodic', 'OOB']
# 65.73554498836094
# 2.5374981086695314
# ['jitter', 1, 'periodic', 'ESOS_ELM']
# 60.36062744426353
# -2.8374194354278828
# ['jitter', 1, 'periodic', 'improved_UOB']
# 64.57847189331599
# 1.3804250136245813
# ['jitter', 1, 'periodic', 'WEOB2']
# 64.46000559134856
# 1.261958711657151
# ['jitter', 1, 'periodic', 'UOB']
# 64.47643472569294
# 1.2783878460015288
# ['jitter', 1, 'periodic', 'RebalanceStream']
# 54.52086864093758
# -8.677178238753832
# ['jitter', 2, 'incremental', 'improved_OOB']
# 66.37410959483205
# 1.8857127736782644
# ['jitter', 2, 'incremental', 'WEOB1']
# 66.37507539279667
# 1.8866785716428893
# ['jitter', 2, 'incremental', 'CSMOTE']
# 64.31770050017465
# -0.17069632097913257
# ['jitter', 2, 'incremental', 'OOB']
# 66.70391390343386
# 2.2155170822800727
# ['jitter', 2, 'incremental', 'ESOS_ELM']
# 60.81633673335158
# -3.6720600878022083
# ['jitter', 2, 'incremental', 'improved_UOB']
# 64.31285158276901
# -0.1755452383847711
# ['jitter', 2, 'incremental', 'WEOB2']
# 64.93659595523494
# 0.4481991340811504
# ['jitter', 2, 'incremental', 'UOB']
# 64.77258011359257
# 0.28418329243878304
# ['jitter', 2, 'incremental', 'RebalanceStream']
# 61.78640761419864
# -2.7019892069551474
# ['jitter', 2, 'sudden', 'improved_OOB']
# 68.0404451274816
# 1.6362677764304578
# ['jitter', 2, 'sudden', 'WEOB1']
# 67.93069810131354
# 1.5265207502623923
# ['jitter', 2, 'sudden', 'CSMOTE']
# 65.78083132704782
# -0.6233460240033253
# ['jitter', 2, 'sudden', 'OOB']
# 68.2122324659563
# 1.8080551149051587
# ['jitter', 2, 'sudden', 'ESOS_ELM']
# 63.33989806985255
# -3.064279281198594
# ['jitter', 2, 'sudden', 'improved_UOB']
# 66.8420604459244
# 0.43788309487325705
# ['jitter', 2, 'sudden', 'WEOB2']
# 65.94533355127781
# -0.45884379977333367
# ['jitter', 2, 'sudden', 'UOB']
# 66.54982335991981
# 0.14564600886866685
# ['jitter', 2, 'sudden', 'RebalanceStream']
# 64.9962737106864
# -1.4079036403647507
# ['jitter', 2, 'periodic', 'improved_OOB']
# 66.37410959483205
# 1.8883166227609536
# ['jitter', 2, 'periodic', 'WEOB1']
# 66.37507539279667
# 1.8892824207255785
# ['jitter', 2, 'periodic', 'CSMOTE']
# 64.31770050017465
# -0.16809247189644339
# ['jitter', 2, 'periodic', 'OOB']
# 66.70391390343386
# 2.218120931362762
# ['jitter', 2, 'periodic', 'ESOS_ELM']
# 60.79290209160746
# -3.6928908804636364
# ['jitter', 2, 'periodic', 'improved_UOB']
# 64.31285158276901
# -0.17294138930208192
# ['jitter', 2, 'periodic', 'WEOB2']
# 64.93659595523494
# 0.4508029831638396
# ['jitter', 2, 'periodic', 'UOB']
# 64.77258011359257
# 0.2867871415214722
# ['jitter', 2, 'periodic', 'RebalanceStream']
# 61.78640761419864
# -2.6993853578724583
# ['jitter', 3, 'incremental', 'improved_OOB']
# 66.97973718941998
# 1.2303316333933196
# ['jitter', 3, 'incremental', 'WEOB1']
# 66.84248486462924
# 1.093079308602583
# ['jitter', 3, 'incremental', 'CSMOTE']
# 65.36687476450018
# -0.3825307915264773
# ['jitter', 3, 'incremental', 'OOB']
# 67.01713606972557
# 1.2677305136989077
# ['jitter', 3, 'incremental', 'ESOS_ELM']
# 62.04299437895683
# -3.706411177069832
# ['jitter', 3, 'incremental', 'improved_UOB']
# 66.42094533493739
# 0.6715397789107271
# ['jitter', 3, 'incremental', 'WEOB2']
# 65.75702455872575
# 0.007619002699087218
# ['jitter', 3, 'incremental', 'UOB']
# 66.05422080217008
# 0.3048152461434199
# ['jitter', 3, 'incremental', 'RebalanceStream']
# 65.26323204117492
# -0.48617351485174254
# ['jitter', 3, 'sudden', 'improved_OOB']
# 68.20218564095885
# 1.335262195393284
# ['jitter', 3, 'sudden', 'WEOB1']
# 68.0385978866633
# 1.1716744410977356
# ['jitter', 3, 'sudden', 'CSMOTE']
# 66.06723311928644
# -0.7996903262791193
# ['jitter', 3, 'sudden', 'OOB']
# 68.22517175712309
# 1.3582483115575315
# ['jitter', 3, 'sudden', 'ESOS_ELM']
# 63.38714263491804
# -3.4797808106475188
# ['jitter', 3, 'sudden', 'improved_UOB']
# 67.5330278661522
# 0.6661044205866347
# ['jitter', 3, 'sudden', 'WEOB2']
# 66.20077483461891
# -0.6661486109466495
# ['jitter', 3, 'sudden', 'UOB']
# 67.09211430335344
# 0.2251908577878794
# ['jitter', 3, 'sudden', 'RebalanceStream']
# 67.05606296701583
# 0.18913952145027224
# ['jitter', 3, 'periodic', 'improved_OOB']
# 66.97973718941998
# 1.2301781527104794
# ['jitter', 3, 'periodic', 'WEOB1']
# 66.84248486462924
# 1.0929258279197427
# ['jitter', 3, 'periodic', 'CSMOTE']
# 65.36687476450018
# -0.38268427220931756
# ['jitter', 3, 'periodic', 'OOB']
# 67.01713606972557
# 1.2675770330160674
# ['jitter', 3, 'periodic', 'ESOS_ELM']
# 62.044375705102276
# -3.7051833316072234
# ['jitter', 3, 'periodic', 'improved_UOB']
# 66.42094533493739
# 0.6713862982278869
# ['jitter', 3, 'periodic', 'WEOB2']
# 65.75702455872575
# 0.0074655220162469504
# ['jitter', 3, 'periodic', 'UOB']
# 66.05422080217008
# 0.30466176546057966
# ['jitter', 3, 'periodic', 'RebalanceStream']
# 65.26323204117492
# -0.4863269955345828
# ['jitter', 4, 'incremental', 'improved_OOB']
# 66.79947661018363
# 1.2970782233800406
# ['jitter', 4, 'incremental', 'WEOB1']
# 66.61458125777997
# 1.1121828709763832
# ['jitter', 4, 'incremental', 'CSMOTE']
# 65.33087751350595
# -0.17152087329763788
# ['jitter', 4, 'incremental', 'OOB']
# 66.37953059670906
# 0.8771322099054686
# ['jitter', 4, 'incremental', 'ESOS_ELM']
# 61.16129190221403
# -4.3411064845895595
# ['jitter', 4, 'incremental', 'improved_UOB']
# 65.7530821384556
# 0.25068375165200507
# ['jitter', 4, 'incremental', 'WEOB2']
# 65.49539600972443
# -0.007002377079160738
# ['jitter', 4, 'incremental', 'UOB']
# 66.37953059670906
# 0.8771322099054686
# ['jitter', 4, 'incremental', 'RebalanceStream']
# 65.60781885595068
# 0.10542046914709147
# ['jitter', 4, 'sudden', 'improved_OOB']
# 67.98993642631335
# 1.0601922762698166
# ['jitter', 4, 'sudden', 'WEOB1']
# 67.90509473115539
# 0.9753505811118544
# ['jitter', 4, 'sudden', 'CSMOTE']
# 66.20563980068945
# -0.7241043493540786
# ['jitter', 4, 'sudden', 'OOB']
# 67.85814911722971
# 0.9284049671861823
# ['jitter', 4, 'sudden', 'ESOS_ELM']
# 63.34246731382247
# -3.587276836221065
# ['jitter', 4, 'sudden', 'improved_UOB']
# 67.58651033401733
# 0.6567661839738008
# ['jitter', 4, 'sudden', 'WEOB2']
# 65.92273020822009
# -1.0070139418234447
# ['jitter', 4, 'sudden', 'UOB']
# 67.85814911722971
# 0.9284049671861823
# ['jitter', 4, 'sudden', 'RebalanceStream']
# 67.69902030171428
# 0.769276151670752
# ['jitter', 4, 'periodic', 'improved_OOB']
# 66.79947661018363
# 1.314337618378346
# ['jitter', 4, 'periodic', 'WEOB1']
# 66.61458125777997
# 1.1294422659746886
# ['jitter', 4, 'periodic', 'CSMOTE']
# 65.33087751350595
# -0.15426147829933257
# ['jitter', 4, 'periodic', 'OOB']
# 66.37953059670906
# 0.8943916049037739
# ['jitter', 4, 'periodic', 'ESOS_ELM']
# 61.005957347229185
# -4.4791816445761015
# ['jitter', 4, 'periodic', 'improved_UOB']
# 65.7530821384556
# 0.2679431466503104
# ['jitter', 4, 'periodic', 'WEOB2']
# 65.49539600972443
# 0.010257017919144573
# ['jitter', 4, 'periodic', 'UOB']
# 66.37953059670906
# 0.8943916049037739
# ['jitter', 4, 'periodic', 'RebalanceStream']
# 65.60781885595068
# 0.12267986414539678
# ['disappearing-minority', 1, 'incremental', 'improved_OOB']
# 58.78151664725533
# 1.9342391130954084
# ['disappearing-minority', 1, 'incremental', 'WEOB1']
# 58.773002320121954
# 1.9257247859620321
# ['disappearing-minority', 1, 'incremental', 'CSMOTE']
# 57.306728632821624
# 0.4594510986617024
# ['disappearing-minority', 1, 'incremental', 'OOB']
# 58.79682227017228
# 1.9495447360123563
# ['disappearing-minority', 1, 'incremental', 'ESOS_ELM']
# 54.67837050129757
# -2.16890703286235
# ['disappearing-minority', 1, 'incremental', 'improved_UOB']
# 57.65061089999735
# 0.8033333658374318
# ['disappearing-minority', 1, 'incremental', 'WEOB2']
# 57.58652705925501
# 0.7392495250950901
# ['disappearing-minority', 1, 'incremental', 'UOB']
# 57.578783103297575
# 0.7315055691376529
# ['disappearing-minority', 1, 'incremental', 'RebalanceStream']
# 50.47313637322053
# -6.374141160939395
# ['disappearing-minority', 1, 'sudden', 'improved_OOB']
# 57.81232262070282
# 1.7297676935254174
# ['disappearing-minority', 1, 'sudden', 'WEOB1']
# 57.880923766505745
# 1.7983688393283401
# ['disappearing-minority', 1, 'sudden', 'CSMOTE']
# 56.771651143525766
# 0.6890962163483607
# ['disappearing-minority', 1, 'sudden', 'OOB']
# 57.828094090124104
# 1.7455391629466988
# ['disappearing-minority', 1, 'sudden', 'ESOS_ELM']
# 53.84439669040912
# -2.2381582367682853
# ['disappearing-minority', 1, 'sudden', 'improved_UOB']
# 56.86483470532373
# 0.7822797781463251
# ['disappearing-minority', 1, 'sudden', 'WEOB2']
# 56.82222562969432
# 0.7396707025169178
# ['disappearing-minority', 1, 'sudden', 'UOB']
# 56.79376504751548
# 0.7112101203380732
# ['disappearing-minority', 1, 'sudden', 'RebalanceStream']
# 50.12478065079558
# -5.957774276381826
# ['disappearing-minority', 1, 'periodic', 'improved_OOB']
# 65.83513709965686
# 2.2359218394083555
# ['disappearing-minority', 1, 'periodic', 'WEOB1']
# 66.22386658931262
# 2.6246513290641147
# ['disappearing-minority', 1, 'periodic', 'CSMOTE']
# 64.17885236629414
# 0.5796371060456309
# ['disappearing-minority', 1, 'periodic', 'OOB']
# 65.91640158383123
# 2.3171863235827246
# ['disappearing-minority', 1, 'periodic', 'ESOS_ELM']
# 60.99720382118339
# -2.602011439065116
# ['disappearing-minority', 1, 'periodic', 'improved_UOB']
# 64.90313488635567
# 1.3039196261071666
# ['disappearing-minority', 1, 'periodic', 'WEOB2']
# 64.56765979179735
# 0.9684445315488475
# ['disappearing-minority', 1, 'periodic', 'UOB']
# 64.83022626232743
# 1.2310110020789224
# ['disappearing-minority', 1, 'periodic', 'RebalanceStream']
# 54.940454941477775
# -8.658760318770732
# ['disappearing-minority', 2, 'incremental', 'improved_OOB']
# 58.7700763062021
# 1.171507230943206
# ['disappearing-minority', 2, 'incremental', 'WEOB1']
# 58.71902979332473
# 1.1204607180658357
# ['disappearing-minority', 2, 'incremental', 'CSMOTE']
# 58.19451660464396
# 0.5959475293850645
# ['disappearing-minority', 2, 'incremental', 'OOB']
# 58.9424306141972
# 1.343861538938306
# ['disappearing-minority', 2, 'incremental', 'ESOS_ELM']
# 54.669884357137775
# -2.9286847181211186
# ['disappearing-minority', 2, 'incremental', 'improved_UOB']
# 58.09461443069567
# 0.4960453554367774
# ['disappearing-minority', 2, 'incremental', 'WEOB2']
# 57.921276797504014
# 0.32270772224512
# ['disappearing-minority', 2, 'incremental', 'UOB']
# 57.893131870001206
# 0.29456279474231195
# ['disappearing-minority', 2, 'incremental', 'RebalanceStream']
# 55.182160903623455
# -2.416408171635439
# ['disappearing-minority', 2, 'sudden', 'improved_OOB']
# 57.882143916833016
# 1.0658487678499426
# ['disappearing-minority', 2, 'sudden', 'WEOB1']
# 57.84409554948536
# 1.0278004005022865
# ['disappearing-minority', 2, 'sudden', 'CSMOTE']
# 57.64906367377923
# 0.8327685247961583
# ['disappearing-minority', 2, 'sudden', 'OOB']
# 58.05646675282243
# 1.2401716038393573
# ['disappearing-minority', 2, 'sudden', 'ESOS_ELM']
# 53.78654990629146
# -3.029745242691611
# ['disappearing-minority', 2, 'sudden', 'improved_UOB']
# 57.22357001640121
# 0.40727486741813834
# ['disappearing-minority', 2, 'sudden', 'WEOB2']
# 57.07476583535767
# 0.2584706863745936
# ['disappearing-minority', 2, 'sudden', 'UOB']
# 57.05634508811162
# 0.24004993912854644
# ['disappearing-minority', 2, 'sudden', 'RebalanceStream']
# 54.773655601765654
# -2.0426395472174192
# ['disappearing-minority', 2, 'periodic', 'improved_OOB']
# 66.30230226824486
# 1.8124449789655728
# ['disappearing-minority', 2, 'periodic', 'WEOB1']
# 66.4422719669192
# 1.9524146776399078
# ['disappearing-minority', 2, 'periodic', 'CSMOTE']
# 65.31749175898786
# 0.8276344697085705
# ['disappearing-minority', 2, 'periodic', 'OOB']
# 66.52219729220519
# 2.032340002925906
# ['disappearing-minority', 2, 'periodic', 'ESOS_ELM']
# 61.20413768283985
# -3.285719606439436
# ['disappearing-minority', 2, 'periodic', 'improved_UOB']
# 65.87223227973416
# 1.3823749904548777
# ['disappearing-minority', 2, 'periodic', 'WEOB2']
# 65.59014691972516
# 1.1002896304458716
# ['disappearing-minority', 2, 'periodic', 'UOB']
# 65.56883666561876
# 1.0789793763394755
# ['disappearing-minority', 2, 'periodic', 'RebalanceStream']
# 57.58909876923847
# -6.900758520040817
# ['disappearing-minority', 3, 'incremental', 'improved_OOB']
# 58.90356356955367
# 0.9103890953322491
# ['disappearing-minority', 3, 'incremental', 'WEOB1']
# 58.80482422362955
# 0.811649749408133
# ['disappearing-minority', 3, 'incremental', 'CSMOTE']
# 58.54216320330696
# 0.5489887290855435
# ['disappearing-minority', 3, 'incremental', 'OOB']
# 58.914089254395094
# 0.9209147801736748
# ['disappearing-minority', 3, 'incremental', 'ESOS_ELM']
# 54.59378162474119
# -3.399392849480229
# ['disappearing-minority', 3, 'incremental', 'improved_UOB']
# 58.48585689190385
# 0.49268241768243115
# ['disappearing-minority', 3, 'incremental', 'WEOB2']
# 58.29074306566895
# 0.29756859144752923
# ['disappearing-minority', 3, 'incremental', 'UOB']
# 58.144574922356604
# 0.15140044813518472
# ['disappearing-minority', 3, 'incremental', 'RebalanceStream']
# ...
# 65.48615140690637
# 3.1408893806125207
# ['clusters-movement', 1, 'periodic', 'ESOS_ELM']
# 60.58572641332512
# -1.7595356129687332
# ['clusters-movement', 1, 'periodic', 'improved_UOB']
# 63.4364314692019
# 1.091169442908047
# ['clusters-movement', 1, 'periodic', 'WEOB2']
# 63.46446923024151
# 1.11920720394766
# ['clusters-movement', 1, 'periodic', 'UOB']
# 63.127654902892154
# 0.7823928765983013
# ['clusters-movement', 1, 'periodic', 'RebalanceStream']
# 51.9320609321163
# -10.413201094177552
# ['clusters-movement', 2, 'incremental', 'improved_OOB']
# 65.92623724041486
# 2.1624863702149497
# ['clusters-movement', 2, 'incremental', 'WEOB1']
# 65.99018556080827
# 2.2264346906083574
# ['clusters-movement', 2, 'incremental', 'CSMOTE']
# 61.619796352869876
# -2.1439545173300374
# ['clusters-movement', 2, 'incremental', 'OOB']
# 66.21371285083492
# 2.4499619806350097
# ['clusters-movement', 2, 'incremental', 'ESOS_ELM']
# 61.11245907755425
# -2.651291792645665
# ['clusters-movement', 2, 'incremental', 'improved_UOB']
# 65.10052049869321
# 1.3367696284933004
# ['clusters-movement', 2, 'incremental', 'WEOB2']
# 62.99276775296494
# -0.7709831172349766
# ['clusters-movement', 2, 'incremental', 'UOB']
# 64.45947381885802
# 0.6957229486581014
# ['clusters-movement', 2, 'incremental', 'RebalanceStream']
# 60.45860467880092
# -3.305146191398997
# ['clusters-movement', 2, 'sudden', 'improved_OOB']
# 66.00169702318317
# 2.9804199466026375
# ['clusters-movement', 2, 'sudden', 'WEOB1']
# 65.89036014028821
# 2.869083063707677
# ['clusters-movement', 2, 'sudden', 'CSMOTE']
# 60.37487859543431
# -2.646398481146221
# ['clusters-movement', 2, 'sudden', 'OOB']
# 66.26180647836158
# 3.240529401781046
# ['clusters-movement', 2, 'sudden', 'ESOS_ELM']
# 59.71995661646141
# -3.301320460119122
# ['clusters-movement', 2, 'sudden', 'improved_UOB']
# 64.40251378848518
# 1.3812367119046485
# ['clusters-movement', 2, 'sudden', 'WEOB2']
# 61.342511385300135
# -1.6787656912803968
# ['clusters-movement', 2, 'sudden', 'UOB']
# 62.993763422338894
# -0.027513654241637653
# ['clusters-movement', 2, 'sudden', 'RebalanceStream']
# 60.20400623937193
# -2.8172708372086035
# ['clusters-movement', 2, 'periodic', 'improved_OOB']
# 65.60645384590802
# 1.8929910880671628
# ['clusters-movement', 2, 'periodic', 'WEOB1']
# 65.44919906930878
# 1.7357363114679174
# ['clusters-movement', 2, 'periodic', 'CSMOTE']
# 64.6884063764649
# 0.9749436186240388
# ['clusters-movement', 2, 'periodic', 'OOB']
# 65.97321147446856
# 2.2597487166276977
# ['clusters-movement', 2, 'periodic', 'ESOS_ELM']
# 60.39933498731948
# -3.314127770521381
# ['clusters-movement', 2, 'periodic', 'improved_UOB']
# 64.09582494941887
# 0.3823621915780109
# ['clusters-movement', 2, 'periodic', 'WEOB2']
# 64.38109288460602
# 0.667630126765161
# ['clusters-movement', 2, 'periodic', 'UOB']
# 63.85644970924064
# 0.14298695139978435
# ['clusters-movement', 2, 'periodic', 'RebalanceStream']
# 58.971191523832466
# -4.742271234008392
# ['clusters-movement', 3, 'incremental', 'improved_OOB']
# 66.28185919744797
# 2.072889031304115
# ['clusters-movement', 3, 'incremental', 'WEOB1']
# 66.07333419011283
# 1.8643640239689745
# ['clusters-movement', 3, 'incremental', 'CSMOTE']
# 62.31040255303692
# -1.898567613106934
# ['clusters-movement', 3, 'incremental', 'OOB']
# 66.38445494595094
# 2.1754847798070784
# ['clusters-movement', 3, 'incremental', 'ESOS_ELM']
# 59.392164040015246
# -4.816806126128611
# ['clusters-movement', 3, 'incremental', 'improved_UOB']
# 65.2492813521769
# 1.040311186033037
# ['clusters-movement', 3, 'incremental', 'WEOB2']
# 64.01199732431795
# -0.1969728418259109
# ['clusters-movement', 3, 'incremental', 'UOB']
# 64.57000591439609
# 0.3610357482522346
# ['clusters-movement', 3, 'incremental', 'RebalanceStream']
# 63.60723197783985
# -0.6017381883040045
# ['clusters-movement', 3, 'sudden', 'improved_OOB']
# 65.92402987027319
# 2.5998294887157343
# ['clusters-movement', 3, 'sudden', 'WEOB1']
# 65.82471679164078
# 2.5005164100833284
# ['clusters-movement', 3, 'sudden', 'CSMOTE']
# 61.848498658173376
# -1.475701723384077
# ['clusters-movement', 3, 'sudden', 'OOB']
# 66.14355318218716
# 2.8193528006297086
# ['clusters-movement', 3, 'sudden', 'ESOS_ELM']
# 59.81844691130611
# -3.505753470251342
# ['clusters-movement', 3, 'sudden', 'improved_UOB']
# 65.25447314443934
# 1.9302727628818914
# ['clusters-movement', 3, 'sudden', 'WEOB2']
# 61.655531553884074
# -1.668668827673379
# ['clusters-movement', 3, 'sudden', 'UOB']
# 62.83653642622058
# -0.48766395533687046
# ['clusters-movement', 3, 'sudden', 'RebalanceStream']
# 60.61201689589242
# -2.7121834856650366
# ['clusters-movement', 3, 'periodic', 'improved_OOB']
# 65.91999648206378
# 1.3300398687936195
# ['clusters-movement', 3, 'periodic', 'WEOB1']
# 65.68791115754938
# 1.0979545442792187
# ['clusters-movement', 3, 'periodic', 'CSMOTE']
# 65.31587185621807
# 0.7259152429479059
# ['clusters-movement', 3, 'periodic', 'OOB']
# 66.12671640216578
# 1.5367597888956226
# ['clusters-movement', 3, 'periodic', 'ESOS_ELM']
# 60.54451826815961
# -4.045438345110554
# ['clusters-movement', 3, 'periodic', 'improved_UOB']
# 65.00676123056803
# 0.41680461729787055
# ['clusters-movement', 3, 'periodic', 'WEOB2']
# 64.8814686052042
# 0.2915119919340441
# ['clusters-movement', 3, 'periodic', 'UOB']
# 64.57199954474022
# -0.01795706852993817
# ['clusters-movement', 3, 'periodic', 'RebalanceStream']
# 63.254365972762386
# -1.3355906405077747
# ['clusters-movement', 4, 'incremental', 'improved_OOB']
# 66.07261703861889
# 1.4736474396603398
# ['clusters-movement', 4, 'incremental', 'WEOB1']
# 65.9934573253386
# 1.3944877263800493
# ['clusters-movement', 4, 'incremental', 'CSMOTE']
# 63.129462555182066
# -1.4695070437764812
# ['clusters-movement', 4, 'incremental', 'OOB']
# 65.93174382432349
# 1.3327742253649433
# ['clusters-movement', 4, 'incremental', 'ESOS_ELM']
# 60.81769083487295
# -3.7812787640855987
# ['clusters-movement', 4, 'incremental', 'improved_UOB']
# 65.42974429591388
# 0.8307746969553307
# ['clusters-movement', 4, 'incremental', 'WEOB2']
# 63.89960630851702
# -0.699363290441525
# ['clusters-movement', 4, 'incremental', 'UOB']
# 65.26931847452785
# 0.670348875569303
# ['clusters-movement', 4, 'incremental', 'RebalanceStream']
# 64.84708573333214
# 0.24811613437358915
# ['clusters-movement', 4, 'sudden', 'improved_OOB']
# 66.09418392277396
# 2.0002082497985896
# ['clusters-movement', 4, 'sudden', 'WEOB1']
# 65.9799839419359
# 1.8860082689605235
# ['clusters-movement', 4, 'sudden', 'CSMOTE']
# 62.37225384241435
# -1.7217218305610231
# ['clusters-movement', 4, 'sudden', 'OOB']
# 65.99030474521213
# 1.8963290722367532
# ['clusters-movement', 4, 'sudden', 'ESOS_ELM']
# 60.681113400128496
# -3.41286227284688
# ['clusters-movement', 4, 'sudden', 'improved_UOB']
# 65.52751422707027
# 1.4335385540948948
# ['clusters-movement', 4, 'sudden', 'WEOB2']
# 61.293739110688385
# -2.8002365622869902
# ['clusters-movement', 4, 'sudden', 'UOB']
# 64.45862898468769
# 0.36465331171231696
# ['clusters-movement', 4, 'sudden', 'RebalanceStream']
# 64.44805888186711
# 0.35408320889173694
# ['clusters-movement', 4, 'periodic', 'improved_OOB']
# 65.79215363938303
# 1.0707821075546207
# ['clusters-movement', 4, 'periodic', 'WEOB1']
# 65.6640427297417
# 0.9426711979132847
# ['clusters-movement', 4, 'periodic', 'CSMOTE']
# 65.3382469497258
# 0.6168754178973899
# ['clusters-movement', 4, 'periodic', 'OOB']
# 65.62421710969724
# 0.9028455778688311
# ['clusters-movement', 4, 'periodic', 'ESOS_ELM']
# 60.50100577714893
# -4.220365754679477
# ['clusters-movement', 4, 'periodic', 'improved_UOB']
# 65.05620818000685
# 0.33483664817843817
# ['clusters-movement', 4, 'periodic', 'WEOB2']
# 64.79627428502594
# 0.07490275319753437
# ['clusters-movement', 4, 'periodic', 'UOB']
# 65.05815146827834
# 0.3367799364499291
# ['clusters-movement', 4, 'periodic', 'RebalanceStream']
# 64.66204364744786
# -0.0593278843805507
# ['borderline', 1, 'incremental', 'improved_OOB']
# 66.847202599312
# 2.807226310990103
# ['borderline', 1, 'incremental', 'WEOB1']
# 66.74309515761338
# 2.7031188692914867
# ['borderline', 1, 'incremental', 'CSMOTE']
# 64.28817632295443
# 0.24820003463253215
# ['borderline', 1, 'incremental', 'OOB']
# 66.93702414438027
# 2.8970478560583786
# ['borderline', 1, 'incremental', 'ESOS_ELM']
# 61.212910607231606
# -2.827065681090289
# ['borderline', 1, 'incremental', 'improved_UOB']
# 64.95916471219553
# 0.919188423873635
# ['borderline', 1, 'incremental', 'WEOB2']
# 64.5694756472432
# 0.5294993589212993
# ['borderline', 1, 'incremental', 'UOB']
# 64.92109942520224
# 0.8811231368803476
# ['borderline', 1, 'incremental', 'RebalanceStream']
# 55.881637978764346
# -8.15833830955755
# ['borderline', 1, 'sudden', 'improved_OOB']
# 66.7371981673601
# 2.8348673834078397
# ['borderline', 1, 'sudden', 'WEOB1']
# 66.58722641194825
# 2.684895627995985
# ['borderline', 1, 'sudden', 'CSMOTE']
# 64.3168129697493
# 0.4144821857970271
# ['borderline', 1, 'sudden', 'OOB']
# 66.72945412892884
# 2.8271233449765703
# ['borderline', 1, 'sudden', 'ESOS_ELM']
# 60.99629458684187
# -2.906036197110396
# ['borderline', 1, 'sudden', 'improved_UOB']
# 64.8551728716378
# 0.9528420876855392
# ['borderline', 1, 'sudden', 'WEOB2']
# 64.37573556290548
# 0.47340477895320987
# ['borderline', 1, 'sudden', 'UOB']
# 64.69877786162274
# 0.7964470776704786
# ['borderline', 1, 'sudden', 'RebalanceStream']
# 55.824304494576054
# -8.078026289376211
# ['borderline', 1, 'periodic', 'improved_OOB']
# 67.68065452912569
# 3.031497544398192
# ['borderline', 1, 'periodic', 'WEOB1']
# 67.33932056599771
# 2.6901635812702125
# ['borderline', 1, 'periodic', 'CSMOTE']
# 64.90923335909471
# 0.2600763743672161
# ['borderline', 1, 'periodic', 'OOB']
# 67.68553626475418
# 3.0363792800266793
# ['borderline', 1, 'periodic', 'ESOS_ELM']
# 61.64668842393941
# -3.0024685607880883
# ['borderline', 1, 'periodic', 'improved_UOB']
# 65.448472082645
# 0.7993150979174999
# ['borderline', 1, 'periodic', 'WEOB2']
# 64.96844508134407
# 0.31928809661657453
# ['borderline', 1, 'periodic', 'UOB']
# 65.36371993937021
# 0.7145629546427159
# ['borderline', 1, 'periodic', 'RebalanceStream']
# 56.80034261627641
# -7.848814368451087
# ['borderline', 2, 'incremental', 'improved_OOB']
# 66.97388860992497
# 1.5791974811094605
# ['borderline', 2, 'incremental', 'WEOB1']
# 66.84311894120626
# 1.4484278123907472
# ['borderline', 2, 'incremental', 'CSMOTE']
# 66.21710349450953
# 0.8224123656940208
# ['borderline', 2, 'incremental', 'OOB']
# 67.05407576819422
# 1.6593846393787146
# ['borderline', 2, 'incremental', 'ESOS_ELM']
# 61.23541196531236
# -4.15927916350315
# ['borderline', 2, 'incremental', 'improved_UOB']
# 66.1010471845253
# 0.7063560557097901
# ['borderline', 2, 'incremental', 'WEOB2']
# 65.71129424284871
# 0.3166031140331995
# ['borderline', 2, 'incremental', 'UOB']
# 65.73576216959353
# 0.34107104077801864
# ['borderline', 2, 'incremental', 'RebalanceStream']
# 62.68051778322464
# -2.714173345590872
# ['borderline', 2, 'sudden', 'improved_OOB']
# 66.74843885475897
# 1.6464824451289388
# ['borderline', 2, 'sudden', 'WEOB1']
# 66.57498580279488
# 1.4730293931648504
# ['borderline', 2, 'sudden', 'CSMOTE']
# 65.76091314388883
# 0.6589567342587941
# ['borderline', 2, 'sudden', 'OOB']
# 66.82441599158133
# 1.7224595819512984
# ['borderline', 2, 'sudden', 'ESOS_ELM']
# 61.13332923186861
# -3.9686271777614266
# ['borderline', 2, 'sudden', 'improved_UOB']
# 65.72147965034586
# 0.6195232407158215
# ['borderline', 2, 'sudden', 'WEOB2']
# 65.45634520841057
# 0.3543887987805334
# ['borderline', 2, 'sudden', 'UOB']
# 65.4860037742454
# 0.3840473646153697
# ['borderline', 2, 'sudden', 'RebalanceStream']
# 62.211696028775954
# -2.8902603808540803
# ['borderline', 2, 'periodic', 'improved_OOB']
# 67.66911560298209
# 1.6089719583952302
# ['borderline', 2, 'periodic', 'WEOB1']
# 67.40855922876207
# 1.3484155841752141
# ['borderline', 2, 'periodic', 'CSMOTE']
# 66.67871231956539
# 0.6185686749785333
# ['borderline', 2, 'periodic', 'OOB']
# 67.69508747131796
# 1.634943826731103
# ['borderline', 2, 'periodic', 'ESOS_ELM']
# 61.69523107464141
# -4.364912569945446
# ['borderline', 2, 'periodic', 'improved_UOB']
# 66.51183925961934
# 0.45169561503247735
# ['borderline', 2, 'periodic', 'WEOB2']
# 66.20870706346889
# 0.14856341888203417
# ['borderline', 2, 'periodic', 'UOB']
# 66.28054483658232
# 0.22040119199546382
# ['borderline', 2, 'periodic', 'RebalanceStream']
# 64.39349594434228
# -1.6666477002445816
# ['borderline', 3, 'incremental', 'improved_OOB']
# 67.08089872496136
# 1.1832460709585177
# ['borderline', 3, 'incremental', 'WEOB1']
# 66.91353533892756
# 1.0158826849247191
# ['borderline', 3, 'incremental', 'CSMOTE']
# 66.08753158140475
# 0.1898789274019066
# ['borderline', 3, 'incremental', 'OOB']
# 66.93204728730737
# 1.0343946333045295
# ['borderline', 3, 'incremental', 'ESOS_ELM']
# 61.1299097131601
# -4.767742940842737
# ['borderline', 3, 'incremental', 'improved_UOB']
# 66.5577953362255
# 0.6601426822226557
# ['borderline', 3, 'incremental', 'WEOB2']
# 66.30002435566186
# 0.40237170165902114
# ['borderline', 3, 'incremental', 'UOB']
# 66.13374524353112
# 0.23609258952828327
# ['borderline', 3, 'incremental', 'RebalanceStream']
# 65.9433863048459
# 0.04573365084306147
# ['borderline', 3, 'sudden', 'improved_OOB']
# 66.85176223718153
# 1.1431641600780722
# ['borderline', 3, 'sudden', 'WEOB1']
# 66.67427505396071
# 0.9656769768572531
# ['borderline', 3, 'sudden', 'CSMOTE']
# 66.04715585412897
# 0.33855777702551393
# ['borderline', 3, 'sudden', 'OOB']
# 66.77022149578542
# 1.061623418681961
# ['borderline', 3, 'sudden', 'ESOS_ELM']
# 61.04819563738423
# -4.660402439719228
# ['borderline', 3, 'sudden', 'improved_UOB']
# 66.29670617245085
# 0.588108095347394
# ['borderline', 3, 'sudden', 'WEOB2']
# 66.11297286436022
# 0.40437478725675646
# ['borderline', 3, 'sudden', 'UOB']
# 65.85087499807324
# 0.14227692096977762
# ['borderline', 3, 'sudden', 'RebalanceStream']
# 65.7252183806061
# 0.016620303502634215
# ['borderline', 3, 'periodic', 'improved_OOB']
# 67.73073460112502
# 1.2062392514035025
# ['borderline', 3, 'periodic', 'WEOB1']
# 67.54226415321286
# 1.017768803491336
# ['borderline', 3, 'periodic', 'CSMOTE']
# 66.90894155194563
# 0.38444620222411174
# ['borderline', 3, 'periodic', 'OOB']
# 67.55836773143452
# 1.033872381712996
# ['borderline', 3, 'periodic', 'ESOS_ELM']
# 61.46114938577226
# -5.06334596394926
# ['borderline', 3, 'periodic', 'improved_UOB']
# 67.1615064844622
# 0.6370111347406748
# ['borderline', 3, 'periodic', 'WEOB2']
# 66.76678658019321
# 0.2422912304716931
# ['borderline', 3, 'periodic', 'UOB']
# 66.73809563792659
# 0.21360028820507182
# ['borderline', 3, 'periodic', 'RebalanceStream']
# 66.85261202142142
# 0.32811667169990244
# ['borderline', 4, 'incremental', 'improved_OOB']
# 66.96619672876419
# 0.888290293672668
# ['borderline', 4, 'incremental', 'WEOB1']
# 66.87937056325055
# 0.8014641281590258
# ['borderline', 4, 'incremental', 'CSMOTE']
# 66.53648153822976
# 0.45857510313824434
# ['borderline', 4, 'incremental', 'OOB']
# 66.9273135130542
# 0.849407077962681
# ['borderline', 4, 'incremental', 'ESOS_ELM']
# 61.147387212928535
# -4.930519222162985
# ['borderline', 4, 'incremental', 'improved_UOB']
# 66.5363417163035
# 0.4584352812119761
# ['borderline', 4, 'incremental', 'WEOB2']
# 66.29335226262536
# 0.21544582753384134
# ['borderline', 4, 'incremental', 'UOB']
# 66.9273135130542
# 0.849407077962681
# ['borderline', 4, 'incremental', 'RebalanceStream']
# 66.48740086761347
# 0.40949443252195294
# ['borderline', 4, 'sudden', 'improved_OOB']
# 66.7518750882026
# 0.8438710664206468
# ['borderline', 4, 'sudden', 'WEOB1']
# 66.66522479078358
# 0.7572207690016342
# ['borderline', 4, 'sudden', 'CSMOTE']
# 66.48757824750751
# 0.5795742257255654
# ['borderline', 4, 'sudden', 'OOB']
# 66.6883339652369
# 0.7803299434549444
# ['borderline', 4, 'sudden', 'ESOS_ELM']
# 61.10772456362382
# -4.80027945815813
# ['borderline', 4, 'sudden', 'improved_UOB']
# 66.33879531205858
# 0.43079129027663043
# ['borderline', 4, 'sudden', 'WEOB2']
# 66.0539686078456
# 0.1459645860636556
# ['borderline', 4, 'sudden', 'UOB']
# 66.6883339652369
# 0.7803299434549444
# ['borderline', 4, 'sudden', 'RebalanceStream']
# 66.39020165554214
# 0.48219763376019387
# ['borderline', 4, 'periodic', 'improved_OOB']
# 67.64371803619191
# 0.9473589214363329
# ['borderline', 4, 'periodic', 'WEOB1']
# 67.56493731599843
# 0.8685782012428547
# ['borderline', 4, 'periodic', 'CSMOTE']
# 66.96853929065489
# 0.2721801758993081
# ['borderline', 4, 'periodic', 'OOB']
# 67.58382276865701
# 0.8874636539014347
# ['borderline', 4, 'periodic', 'ESOS_ELM']
# 61.564477555396955
# -5.131881559358625
# ['borderline', 4, 'periodic', 'improved_UOB']
# 67.20156939447801
# 0.5052102797224336
# ['borderline', 4, 'periodic', 'WEOB2']
# 66.8679444713357
# 0.17158535658012397
# ['borderline', 4, 'periodic', 'UOB']
# 67.58382276865701
# 0.8874636539014347
# ['borderline', 4, 'periodic', 'RebalanceStream']
# 67.28840043143023
# 0.5920413166746528

# %% [markdown]
# # REALS

# %%
real_dict = {}
real_dict["KDDCup"] = {}
real_dict["PAKDD"] = {}
real_dict["Elec"] = {}

for i in real_dict.keys():
    path = f"Results_union/Real/{i}"
    for alg in os.listdir(path):
        class0 = []
        if "DS_Store" in alg or "ipynb" in alg:
            continue
        class1 = []
        if alg not in real_dict[i]:
            real_dict[i][alg] = []
        
            
        for exp in os.listdir(path + "/" + alg): 
            if "err" not in exp or "DS_Store" in exp:
                continue
                
            data = import_csv(path + "/" + alg + "/"+ exp)
            val = []
            start = False
                
            for data_row in data:
                if data_row[1] == "learning evaluation instances":
                    start = True
                    continue
                if not start:
                    continue

                try:
                    val.append(float(data_row[13]))
                except:
                    if data_row[13] == "?":
                        val.append(50)
                    else:
                        print("ZERO")
                        print(data_row)
                    
                        
                    
                
            try:
                if len(val)>0:
                    real_dict[i][alg].append(np.mean(val))
            except:
                print(f"error with {result}")
                
        
        
        real_dict[i][alg] = np.mean(real_dict[i][alg])

# %%
real_dict
# Out:
# {'KDDCup': {'improved_OOB': 70.13436198045461,
#   'WEOB1': 70.34998488321021,
#   'OOB': 69.60489060875975,
#   'ESOS_ELM': 70.71067811865476,
#   'improved_UOB': 69.1833604584767,
#   'WEOB2': 69.01556124987272,
#   'UOB': 69.32321376120015,
#   'OSHAT': 70.04109120106502,
#   'RebalanceStream': 70.26028630086215},
#  'PAKDD': {'improved_OOB': 54.27216606868876,
#   'WEOB1': 54.99446906377858,
#   'OOB': 54.60671033853637,
#   'ESOS_ELM': 55.986587674649954,
#   'improved_UOB': 54.779638083154325,
#   'WEOB2': 54.9059001195774,
#   'UOB': 54.11448745428176,
#   'OSHAT': 53.51804639832485,
#   'RebalanceStream': 50.07230423641015},
#  'Elec': {'improved_OOB': 66.63018673988167,
#   'WEOB1': 66.07826315706629,
#   'OOB': 67.09087664716381,
#   'ESOS_ELM': 61.499664728738864,
#   'improved_UOB': 64.84626213144934,
#   'WEOB2': 63.927974412077866,
#   'UOB': 65.53469724979941,
#   'OSHAT': 64.61646091071256,
#   'RebalanceStream': 63.76044072211687}}

# %%
with open('GMEAN_real.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    writer.writerow(["ds","alg","Gmean","Gmean_Mean","Gmean_Perc"])
    for ds, dicts in real_dict.items():
        mean, mi, ma = stats_of(dicts)
        for alg, value in dicts.items():
            if alg == "OSHAT":
                alg = "CSMOTE"
            writer.writerow([ds,alg,value,value - mean,value/mean-1])

# %%
dicts
# Out:
# {'improved_OOB': 66.63018673988167,
#  'WEOB1': 66.07826315706629,
#  'OOB': 67.09087664716381,
#  'ESOS_ELM': 61.499664728738864,
#  'improved_UOB': 64.84626213144934,
#  'WEOB2': 63.927974412077866,
#  'UOB': 65.53469724979941,
#  'OSHAT': 64.61646091071256,
#  'RebalanceStream': 63.76044072211687}
